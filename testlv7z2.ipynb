# %%
# import libraries
import math
import os
import pickle
import random
import time
import itertools
import importlib

# import numpy
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
from sklearn import preprocessing

import torch
import scipy
import scipy.io

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", DEVICE)
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# import Koopman Libraries
from core.koopman_core_linear import KoopDNN_linear, KoopmanNet_linear, KoopmanNetCtrl_linear
from core.util import fit_standardizer
from models.koop_model import model_matricies, lift_raw, lift_scaled

# ===== import Frenet-real-state dynamics file =====
import dynamics.cacaNEWlv2 as cacaNEWlv2

importlib.reload(cacaNEWlv2)
from dynamics.cacaNEWlv2 import FK_solver, single_vehicle_data_gen_multi

# control
from control_files.nmpc_osqp_adapt import NonlinearMPCController
from dynamics.learned_models_control.linear_dynamics import linear_Dynamics


# ===== helper for Frenet path =====
def build_test_frenet_path_from_xy(x_ref_path, y_ref_path):
    dx_seg = np.diff(x_ref_path)
    dy_seg = np.diff(y_ref_path)
    ds_seg = np.sqrt(dx_seg ** 2 + dy_seg ** 2)
    s_ref = np.concatenate(([0.0], np.cumsum(ds_seg)))

    dx = np.gradient(x_ref_path)
    dy = np.gradient(y_ref_path)
    psi_ref = np.unwrap(np.arctan2(dy, dx))

    ds = np.gradient(s_ref)
    curvature_ref = np.gradient(psi_ref) / np.maximum(ds, 1e-8)
    curvature_ref = np.nan_to_num(curvature_ref)

    return s_ref, psi_ref, curvature_ref


# ===== Frenet -> Cartesian for plotting =====
def frenet_to_global(s_arr, ey_arr, s_ref_path, x_ref_path, y_ref_path, psi_ref_path):
    x_center = np.interp(s_arr, s_ref_path, x_ref_path)
    y_center = np.interp(s_arr, s_ref_path, y_ref_path)
    psi_center = np.interp(s_arr, s_ref_path, psi_ref_path)

    x_global = x_center - ey_arr * np.sin(psi_center)
    y_global = y_center + ey_arr * np.cos(psi_center)
    return x_global, y_global


def to_numpy(x):
    if hasattr(x, "detach"):
        return x.detach().cpu().numpy()
    return np.array(x)


def scale_state(x_raw, standardizer_x):
    return standardizer_x.transform(np.asarray(x_raw).reshape(1, -1)).flatten()


def scale_state_batch(X_raw, standardizer_x):
    return standardizer_x.transform(np.asarray(X_raw))


def decode_scaled_to_raw(x_scaled, standardizer_x):
    return standardizer_x.inverse_transform(np.asarray(x_scaled).reshape(1, -1)).flatten()


# =============================================================================
# 系统拟合
# =============================================================================
linear = True

# =============================================================================
# 数据生成 (针对 100m 双移线优化：丰富场景 + 物理不变性数据增强)
# =============================================================================
sys_pars_base = {}

# 6 states: x=[s, e_y, e_psi, v_x, v_y, r]
num_states = 6
num_inputs = 2
dt = 0.02

sys_pars_base["num_states"] = num_states
sys_pars_base["num_inputs"] = num_inputs
sys_pars_base["dt"] = dt

# nominal vehicle parameters
sys_pars_base["m"] = 1500.0
sys_pars_base["Iz"] = 2250.0
sys_pars_base["lf"] = 1.2
sys_pars_base["lr"] = 1.6
sys_pars_base["Cf"] = 80000.0
sys_pars_base["Cr"] = 80000.0
sys_pars_base["curvature_ref"] = 0.0
sys_pars_base["uncertainty"] = "NA"
sys_pars_base["amp"] = 0.0

# changed vehicle parameters
sys_pars_new_base = dict(sys_pars_base)
sys_pars_new_base["m"] = 1650.0
sys_pars_new_base["Iz"] = 2400.0
sys_pars_new_base["Cf"] = 70000.0
sys_pars_new_base["Cr"] = 70000.0

sensor_noise = False
SNR_DB = 30
num_snaps = 200

# 1. 构建混合数据集配置，激发出不同强度的纵横向耦合动态
configs = [
    {"vx_ref": 3.0, "delta_max": 0.05, "ax_max": 0.6, "freq": 1.0},
    {"vx_ref": 3.0, "delta_max": 0.15, "ax_max": 1.0, "freq": 0.5},  # 低频大转角，逼近 DLC
    {"vx_ref": 3.0, "delta_max": 0.10, "ax_max": 0.8, "freq": 0.2},  # 更低频，拉大 e_y 侧移
    {"vx_ref": 4.0, "delta_max": 0.10, "ax_max": 0.8, "freq": 0.5},  # 高速覆盖
    {"vx_ref": 2.0, "delta_max": 0.10, "ax_max": 0.8, "freq": 0.5},  # 低速覆盖
]

num_traj_per_batch = 80
X_list, X_changed_list, U_list = [], [], []

print("正在生成覆盖双移线边界条件的多场景数据...")
for cfg in configs:
    sp = dict(sys_pars_base)
    sp.update(cfg)
    sp["U_type"] = "sinusoidal"

    sp_new = dict(sys_pars_new_base)
    sp_new.update(cfg)
    sp_new["U_type"] = "sinusoidal"

    X_b, X_changed_b, U_b = single_vehicle_data_gen_multi(
        num_traj_per_batch, num_snaps, sp, sp_new, sensor_noise, SNR_DB
    )
    X_list.append(X_b)
    X_changed_list.append(X_changed_b)
    U_list.append(U_b)

X = np.concatenate(X_list, axis=0)
X_changed = np.concatenate(X_changed_list, axis=0)
U = np.concatenate(U_list, axis=0)
num_traj = X.shape[0]  # Total 400

# 2. 【核心】数据增强 (Data Augmentation)
# 因为在直道上 (curvature_ref=0) 车辆的动态方程不受绝对纵向距离 s 和横向偏移 e_y 的影响
# 所以我们可以直接随机平移 s 和 e_y，扩大 Standardizer 的分布覆盖面，彻底解决饱和越界问题！
np.random.seed(42)
for i in range(num_traj):
    s_shift = np.random.uniform(0.0, 110.0)  # 覆盖 DLC 的 100m 长度
    ey_shift = np.random.uniform(-2.0, 2.0)  # 覆盖 DLC 的侧向偏差并留出充足泛化裕度

    X[i, :, 0] += s_shift
    X_changed[i, :, 0] += s_shift
    X[i, :, 1] += ey_shift
    X_changed[i, :, 1] += ey_shift

# 打乱数据以防止验证集切分时分布不均
indices = np.random.permutation(num_traj)
X = X[indices]
X_changed = X_changed[indices]
U = U[indices]

num_train = int(0.8 * num_traj)
num_val = num_traj - num_train

# 恢复默认的 sys_pars 用于后续代码流转基准
sys_pars = dict(sys_pars_base)
sys_pars.update({"vx_ref": 3.0, "delta_max": 0.05, "ax_max": 0.6, "freq": 1.0, "U_type": "sinusoidal"})
sys_pars_new = dict(sys_pars_new_base)
sys_pars_new.update({"vx_ref": 3.0, "delta_max": 0.05, "ax_max": 0.6, "freq": 1.0, "U_type": "sinusoidal"})

print("X shape:", X.shape)
print("X_changed shape:", X_changed.shape)
print("U shape:", U.shape)

os.makedirs("saved_data/single_vehicle", exist_ok=True)

np.savez_compressed(
    "saved_data/single_vehicle/offline_dataset.npz",
    X=X,
    X_changed=X_changed,
    U=U
)

with open("saved_data/single_vehicle/offline_dataset_pars.pkl", "wb") as f:
    pickle.dump({
        "sys_pars": sys_pars,
        "sys_pars_new": sys_pars_new,
        "num_traj": num_traj,
        "num_train": num_train,
        "num_val": num_val,
        "num_snaps": num_snaps,
        "sensor_noise": sensor_noise,
        "SNR_DB": SNR_DB
    }, f)

print("离线数据已保存。")

state_labels = ["s", "e_y", "e_psi", "v_x", "v_y", "r"]
input_labels = ["delta", "a_x"]
t_train = np.linspace(0, dt * (num_snaps - 1), num_snaps)

plt.figure(figsize=(18, 12))
for j in range(num_traj):
    for i in range(num_states):
        plt.subplot(num_states, 1, i + 1)
        plt.plot(t_train, X[j, :, i], alpha=0.7)
        plt.ylabel(state_labels[i])
        plt.xlabel("t")
plt.suptitle("Original Vehicle Dynamics", fontsize=20)
plt.tight_layout()
plt.show()

plt.figure(figsize=(18, 12))
for j in range(num_traj):
    for i in range(num_states):
        plt.subplot(num_states, 1, i + 1)
        plt.plot(t_train, X_changed[j, :, i], alpha=0.7)
        plt.ylabel(state_labels[i])
        plt.xlabel("t")
plt.suptitle("Changed Vehicle Dynamics", fontsize=20)
plt.tight_layout()
plt.show()

plt.figure(figsize=(18, 6))
for j in range(num_traj):
    for i in range(num_inputs):
        plt.subplot(num_inputs, 1, i + 1)
        plt.plot(t_train[:-1], U[j, :, i], alpha=0.7)
        plt.ylabel(input_labels[i])
        plt.xlabel("t")
plt.suptitle("Control Inputs", fontsize=20)
plt.tight_layout()
plt.show()


# =============================================================================
# Learning Koopman
# =============================================================================
xs_train, us_train = X[:num_train, :, :], U[:num_train, :, :]
xs_val, us_val = X[num_train:, :, :], U[num_train:, :, :]

net_params_lin = {}
net_params_lin["state_dim"] = num_states
net_params_lin["ctrl_dim"] = num_inputs
net_params_lin["encoder_hidden_width"] = 128
# 模型容量适度提升：场景增多变复杂了，给隐变量输出更多维度
net_params_lin["encoder_hidden_depth"] = 4
net_params_lin["encoder_output_dim"] = 24
net_params_lin["optimizer"] = "adam"
net_params_lin["activation_type"] = "tanh"
net_params_lin["lr"] = 1e-4
net_params_lin["epochs"] = 300
net_params_lin["batch_size"] = 256

net_params_lin["eig_loss"] = True
net_params_lin["eig_loss_coeff"] = 0.5
net_params_lin["lifted_loss_penalty"] = 0.5

net_params_lin["l2_reg"] = 1e-5
net_params_lin["l1_reg"] = 1e-7
net_params_lin["first_obs_const"] = True
net_params_lin["override_C"] = True
net_params_lin["dt"] = dt

train = True
standardize = True

os.makedirs("saved_models/single_vehicle/linear", exist_ok=True)

file_koop_linear = (
        "saved_models/single_vehicle/linear/"
        + "Koop_vehicle_Dim"
        + str(net_params_lin["encoder_output_dim"])
        + "_dt_"
        + str(dt)
        + ".pth"
)

print("Model save path:", file_koop_linear)

standardizer_u_kdnn = fit_standardizer(
    us_train, preprocessing.StandardScaler(with_mean=True)
)
standardizer_x_kdnn = fit_standardizer(
    xs_train, preprocessing.StandardScaler(with_mean=True)
)

if train:
    if standardize:
        net = KoopmanNetCtrl_linear(
            net_params_lin,
            standardizer_x=standardizer_x_kdnn,
            standardizer_u=standardizer_u_kdnn,
            device=DEVICE
        )
    else:
        net = KoopmanNetCtrl_linear(
            net_params_lin,
            device=DEVICE
        )

    model_koop_dnn_lin = KoopDNN_linear(net)
    model_koop_dnn_lin.set_datasets(
        xs_train,
        u_train=us_train,
        x_val=xs_val,
        u_val=us_val
    )
    model_koop_dnn_lin.model_pipeline(net_params_lin)
    model_koop_dnn_lin.construct_koopman_model()

    torch.save(model_koop_dnn_lin, file_koop_linear)
else:
    model_koop_dnn_lin = torch.load(file_koop_linear, map_location=DEVICE)
    model_koop_dnn_lin.net.to(DEVICE)
    model_koop_dnn_lin.net.device = DEVICE

train_loss = [l[0] for l in model_koop_dnn_lin.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn_lin.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn_lin.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn_lin.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn_lin.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn_lin.val_loss_hist]
epochs = np.arange(0, net_params_lin["epochs"])

plt.figure(figsize=(15, 8))
plt.plot(epochs, train_loss, color="tab:orange", label="Training loss")
plt.plot(epochs, train_pred_loss, "--", color="tab:orange", label="Training prediction loss")
plt.plot(epochs, train_lifted_loss, ":", color="tab:orange", label="Training lifted loss")
plt.plot(epochs, val_loss, color="tab:blue", label="Validation loss")
plt.plot(epochs, val_pred_loss, "--", color="tab:blue", label="Validation prediction loss")
plt.plot(epochs, val_lifted_loss, ":", color="tab:blue", label="Validation lifted loss")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.yscale("log")
plt.show()
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 5080
# 正在生成覆盖双移线边界条件的多场景数据...
# X shape: (400, 200, 6)
# X_changed shape: (400, 200, 6)
# U shape: (400, 199, 2)
# 离线数据已保存。
# Model save path: saved_models/single_vehicle/linear/Koop_vehicle_Dim24_dt_0.02.pth
# Epoch   1: train loss: 1.3323821510, validation loss: 1.4870476837
# Epoch   2: train loss: 1.1903342351, validation loss: 1.4229791416
# Epoch   3: train loss: 1.1457995532, validation loss: 1.3829339533
# Epoch   4: train loss: 1.1137867897, validation loss: 1.3581986022
# Epoch   5: train loss: 1.0893809911, validation loss: 1.3351644245
# Epoch   6: train loss: 1.0729418589, validation loss: 1.3115032492
# Epoch   7: train loss: 1.0481808050, validation loss: 1.2925234665
# Epoch   8: train loss: 1.0336946999, validation loss: 1.2795281152
# Epoch   9: train loss: 1.0113759502, validation loss: 1.2597370298
# Epoch  10: train loss: 0.9932522202, validation loss: 1.2426844128
# Epoch  11: train loss: 0.9781932451, validation loss: 1.2314563381
# Epoch  12: train loss: 0.9615691163, validation loss: 1.2115303101
# Epoch  13: train loss: 0.9474053419, validation loss: 1.2064215096
# Epoch  14: train loss: 0.9347714992, validation loss: 1.1959375934
# Epoch  15: train loss: 0.9206765955, validation loss: 1.1833974126
# Epoch  16: train loss: 0.9079054348, validation loss: 1.1755160050
# Epoch  17: train loss: 0.8974984870, validation loss: 1.1682261397
# Epoch  18: train loss: 0.8854411377, validation loss: 1.1530558887
# Epoch  19: train loss: 0.8756778820, validation loss: 1.1514253227
# Epoch  20: train loss: 0.8671267755, validation loss: 1.1384587875
# Epoch  21: train loss: 0.8593405880, validation loss: 1.1302092851
# Epoch  22: train loss: 0.8489638551, validation loss: 1.1242297332
# Epoch  23: train loss: 0.8418653867, validation loss: 1.1315185200
# Epoch  24: train loss: 0.8356188454, validation loss: 1.1172418145
# Epoch  25: train loss: 0.8273917573, validation loss: 1.1020530680
# Epoch  26: train loss: 0.8199337200, validation loss: 1.0955250667
# Epoch  27: train loss: 0.8133627831, validation loss: 1.0831689960
# Epoch  28: train loss: 0.8081104679, validation loss: 1.0936314102
# Epoch  29: train loss: 0.8026136084, validation loss: 1.0710140944
# Epoch  30: train loss: 0.7978799530, validation loss: 1.0698979757
# Epoch  31: train loss: 0.7908670153, validation loss: 1.0755898217
# Epoch  32: train loss: 0.7872677441, validation loss: 1.0613414118
# Epoch  33: train loss: 0.7802315615, validation loss: 1.0404901391
# Epoch  34: train loss: 0.7772317772, validation loss: 1.0325683141
# Epoch  35: train loss: 0.7727217092, validation loss: 1.0408151397
# Epoch  36: train loss: 0.7674086911, validation loss: 1.0462330466
# Epoch  37: train loss: 0.7639751719, validation loss: 1.0337147602
# Epoch  38: train loss: 0.7577469152, validation loss: 1.0333504839
# Epoch  39: train loss: 0.7562833152, validation loss: 1.0046337279
# Epoch  40: train loss: 0.7529055093, validation loss: 1.0127148501
# Epoch  41: train loss: 0.7468664930, validation loss: 1.0212643799
# Epoch  42: train loss: 0.7446242915, validation loss: 1.0113834378
# Epoch  43: train loss: 0.7421035987, validation loss: 1.0028233027
# Epoch  44: train loss: 0.7396944250, validation loss: 0.9812363482
# Epoch  45: train loss: 0.7335160844, validation loss: 1.0109449951
# Epoch  46: train loss: 0.7269102923, validation loss: 0.9716078885
# Epoch  47: train loss: 0.7249483345, validation loss: 1.0189332673
# Epoch  48: train loss: 0.7244580171, validation loss: 0.9792355044
# Epoch  49: train loss: 0.7229140953, validation loss: 1.0047532568
# Epoch  50: train loss: 0.7162480982, validation loss: 0.9745871721
# Epoch  51: train loss: 0.7118004668, validation loss: 0.9611684330
# Epoch  52: train loss: 0.7102517171, validation loss: 0.9561635621
# Epoch  53: train loss: 0.7079193208, validation loss: 0.9739191307
# Epoch  54: train loss: 0.7022579704, validation loss: 0.9509259747
# Epoch  55: train loss: 0.7004582680, validation loss: 0.9790541548
# Epoch  56: train loss: 0.6973752653, validation loss: 0.9470862627
# Epoch  57: train loss: 0.6922247947, validation loss: 0.9364737784
# Epoch  58: train loss: 0.6875833652, validation loss: 0.9707646307
# Epoch  59: train loss: 0.6883619846, validation loss: 0.9193200053
# Epoch  60: train loss: 0.6837472270, validation loss: 0.9200329283
# Epoch  61: train loss: 0.6834467316, validation loss: 0.9144686955
# Epoch  62: train loss: 0.6802020515, validation loss: 0.9187466912
# Epoch  63: train loss: 0.6726055979, validation loss: 0.9403519616
# Epoch  64: train loss: 0.6743985489, validation loss: 0.9056724391
# Epoch  65: train loss: 0.6659830796, validation loss: 0.9463818185
# Epoch  66: train loss: 0.6669161952, validation loss: 0.9089767535
# Epoch  67: train loss: 0.6648594187, validation loss: 0.8950894891
# Epoch  68: train loss: 0.6621706850, validation loss: 0.9187326248
# Epoch  69: train loss: 0.6592618835, validation loss: 0.8952105544
# Epoch  70: train loss: 0.6564515533, validation loss: 0.8901418128
# Epoch  71: train loss: 0.6538145282, validation loss: 0.8959527589
# Epoch  72: train loss: 0.6537934772, validation loss: 0.8867404425
# Epoch  73: train loss: 0.6463434288, validation loss: 0.8867684044
# Epoch  74: train loss: 0.6449670823, validation loss: 0.9176281013
# Epoch  75: train loss: 0.6439609081, validation loss: 0.8800301377
# Epoch  76: train loss: 0.6380108693, validation loss: 0.9001518343
# Epoch  77: train loss: 0.6370454987, validation loss: 0.8630525939
# Epoch  78: train loss: 0.6366990866, validation loss: 0.8915397811
# Epoch  79: train loss: 0.6321035008, validation loss: 0.8674124207
# Epoch  80: train loss: 0.6298073570, validation loss: 0.8528740750
# Epoch  81: train loss: 0.6315278711, validation loss: 0.8687725668
# Epoch  82: train loss: 0.6273610733, validation loss: 0.8544836667
# Epoch  83: train loss: 0.6247985436, validation loss: 0.8580736000
# Epoch  84: train loss: 0.6181559552, validation loss: 0.8590275085
# Epoch  85: train loss: 0.6230112039, validation loss: 0.8533048914
# Epoch  86: train loss: 0.6171707483, validation loss: 0.8441140899
# Epoch  87: train loss: 0.6131561162, validation loss: 0.8428379150
# Epoch  88: train loss: 0.6142296783, validation loss: 0.8377423172
# Epoch  89: train loss: 0.6087152080, validation loss: 0.8395802206
# Epoch  90: train loss: 0.6047695689, validation loss: 0.8501223315
# Epoch  91: train loss: 0.6044473992, validation loss: 0.8576359073
# Epoch  92: train loss: 0.6014653016, validation loss: 0.8451549616
# Epoch  93: train loss: 0.5983067837, validation loss: 0.8412806071
# Epoch  94: train loss: 0.5995260047, validation loss: 0.8390090275
# Epoch  95: train loss: 0.5953553060, validation loss: 0.8285347315
# Epoch  96: train loss: 0.5909788757, validation loss: 0.8306997751
# Epoch  97: train loss: 0.5902876883, validation loss: 0.8163923008
# Epoch  98: train loss: 0.5897490515, validation loss: 0.8159127841
# Epoch  99: train loss: 0.5856918598, validation loss: 0.8302201454
# Epoch 100: train loss: 0.5827876745, validation loss: 0.8210608052
# Epoch 101: train loss: 0.5806464774, validation loss: 0.8109775623
# Epoch 102: train loss: 0.5802675633, validation loss: 0.8154707709
# Epoch 103: train loss: 0.5750547374, validation loss: 0.8061153351
# Epoch 104: train loss: 0.5731236095, validation loss: 0.8133913898
# Epoch 105: train loss: 0.5734697060, validation loss: 0.8166431929
# Epoch 106: train loss: 0.5716569795, validation loss: 0.8044181007
# Epoch 107: train loss: 0.5678237099, validation loss: 0.7979365526
# Epoch 108: train loss: 0.5653507046, validation loss: 0.8060934386
# Epoch 109: train loss: 0.5653471245, validation loss: 0.7978311235
# Epoch 110: train loss: 0.5638718769, validation loss: 0.7940380739
# Epoch 111: train loss: 0.5602792145, validation loss: 0.7950684986
# Epoch 112: train loss: 0.5571006330, validation loss: 0.7886358332
# Epoch 113: train loss: 0.5572380756, validation loss: 0.7950431616
# Epoch 114: train loss: 0.5533814408, validation loss: 0.7874837148
# Epoch 115: train loss: 0.5514118168, validation loss: 0.7808180801
# Epoch 116: train loss: 0.5493800592, validation loss: 0.7863902640
# Epoch 117: train loss: 0.5495462906, validation loss: 0.7840097942
# Epoch 118: train loss: 0.5441059017, validation loss: 0.7792263521
# Epoch 119: train loss: 0.5436465523, validation loss: 0.7857635654
# Epoch 120: train loss: 0.5444132992, validation loss: 0.7747787205
# Epoch 121: train loss: 0.5409145485, validation loss: 0.7687957657
# Epoch 122: train loss: 0.5366323789, validation loss: 0.7701524302
# Epoch 123: train loss: 0.5356794821, validation loss: 0.7748382896
# Epoch 124: train loss: 0.5334250057, validation loss: 0.7690482592
# Epoch 125: train loss: 0.5309656441, validation loss: 0.7634246037
# Epoch 126: train loss: 0.5285889080, validation loss: 0.7587467930
# Epoch 127: train loss: 0.5324967836, validation loss: 0.7666594353
# Epoch 128: train loss: 0.5255808145, validation loss: 0.7641392142
# Epoch 129: train loss: 0.5243244507, validation loss: 0.7574608475
# Epoch 130: train loss: 0.5220527583, validation loss: 0.7542454845
# Epoch 131: train loss: 0.5213307183, validation loss: 0.7573987925
# Epoch 132: train loss: 0.5231759897, validation loss: 0.7551650054
# Epoch 133: train loss: 0.5183017554, validation loss: 0.7498190352
# Epoch 134: train loss: 0.5162079439, validation loss: 0.7533107994
# Epoch 135: train loss: 0.5128748814, validation loss: 0.7504222226
# Epoch 136: train loss: 0.5138467765, validation loss: 0.7475076696
# Epoch 137: train loss: 0.5096818935, validation loss: 0.7418040874
# Epoch 138: train loss: 0.5092181539, validation loss: 0.7419735519
# Epoch 139: train loss: 0.5069219345, validation loss: 0.7461357129
# Epoch 140: train loss: 0.5052841938, validation loss: 0.7376055233
# Epoch 141: train loss: 0.5047166997, validation loss: 0.7374729779
# Epoch 142: train loss: 0.5024519653, validation loss: 0.7327254014
# Epoch 143: train loss: 0.4994400419, validation loss: 0.7349358874
# Epoch 144: train loss: 0.4990598501, validation loss: 0.7247777702
# Epoch 145: train loss: 0.4954191420, validation loss: 0.7312099211
# Epoch 146: train loss: 0.4945643578, validation loss: 0.7274832976
# Epoch 147: train loss: 0.4926108102, validation loss: 0.7240944857
# Epoch 148: train loss: 0.4909890845, validation loss: 0.7321148238
# Epoch 149: train loss: 0.4903916835, validation loss: 0.7214926969
# Epoch 150: train loss: 0.4884844519, validation loss: 0.7339630810
# Epoch 151: train loss: 0.4903497710, validation loss: 0.7175169105
# Epoch 152: train loss: 0.4851963363, validation loss: 0.7169266216
# Epoch 153: train loss: 0.4827612195, validation loss: 0.7187232286
# Epoch 154: train loss: 0.4807531870, validation loss: 0.7145549898
# Epoch 155: train loss: 0.4794535172, validation loss: 0.7130161611
# Epoch 156: train loss: 0.4769451901, validation loss: 0.7142205329
# Epoch 157: train loss: 0.4777200556, validation loss: 0.7105624201
# Epoch 158: train loss: 0.4750797687, validation loss: 0.7073095469
# Epoch 159: train loss: 0.4735936957, validation loss: 0.7065379729
# Epoch 160: train loss: 0.4734058847, validation loss: 0.7014501002
# Epoch 161: train loss: 0.4699942264, validation loss: 0.7083344895
# Epoch 162: train loss: 0.4702369530, validation loss: 0.6972937790
# Epoch 163: train loss: 0.4680293442, validation loss: 0.7029525778
# Epoch 164: train loss: 0.4662099969, validation loss: 0.6957801713
# Epoch 165: train loss: 0.4638222410, validation loss: 0.6920170847
# Epoch 166: train loss: 0.4640503752, validation loss: 0.6942132057
# Epoch 167: train loss: 0.4611408344, validation loss: 0.6904822042
# Epoch 168: train loss: 0.4593342901, validation loss: 0.6860699297
# Epoch 169: train loss: 0.4585146050, validation loss: 0.6896046372
# Epoch 170: train loss: 0.4563865306, validation loss: 0.6861926213
# Epoch 171: train loss: 0.4552984634, validation loss: 0.6892064609
# Epoch 172: train loss: 0.4533390013, validation loss: 0.6837806252
# Epoch 173: train loss: 0.4526449504, validation loss: 0.6803945681
# Epoch 174: train loss: 0.4509085597, validation loss: 0.6820185732
# Epoch 175: train loss: 0.4491419341, validation loss: 0.6873219503
# Epoch 176: train loss: 0.4479988360, validation loss: 0.6810778994
# Epoch 177: train loss: 0.4483096619, validation loss: 0.6913154836
# Epoch 178: train loss: 0.4462893808, validation loss: 0.6767600752
# Epoch 179: train loss: 0.4436395518, validation loss: 0.6767536988
# Epoch 180: train loss: 0.4433420029, validation loss: 0.6675170051
# Epoch 181: train loss: 0.4442889887, validation loss: 0.6674349500
# Epoch 182: train loss: 0.4391662233, validation loss: 0.6669507062
# Epoch 183: train loss: 0.4373014161, validation loss: 0.6665771418
# Epoch 184: train loss: 0.4366472382, validation loss: 0.6654462260
# Epoch 185: train loss: 0.4357667846, validation loss: 0.6662313773
# Epoch 186: train loss: 0.4342367827, validation loss: 0.6623495276
# Epoch 187: train loss: 0.4324449865, validation loss: 0.6588986160
# Epoch 188: train loss: 0.4299636716, validation loss: 0.6582494409
# Epoch 189: train loss: 0.4305627165, validation loss: 0.6564277960
# Epoch 190: train loss: 0.4306513872, validation loss: 0.6553585688
# Epoch 191: train loss: 0.4273204415, validation loss: 0.6544855096
# Epoch 192: train loss: 0.4259318160, validation loss: 0.6525319237
# Epoch 193: train loss: 0.4245823257, validation loss: 0.6520778276
# Epoch 194: train loss: 0.4220422628, validation loss: 0.6483840766
# Epoch 195: train loss: 0.4222940389, validation loss: 0.6494948419
# Epoch 196: train loss: 0.4229667758, validation loss: 0.6474391270
# Epoch 197: train loss: 0.4193650080, validation loss: 0.6495426221
# Epoch 198: train loss: 0.4178592566, validation loss: 0.6450223480
# Epoch 199: train loss: 0.4166319293, validation loss: 0.6425978133
# Epoch 200: train loss: 0.4150344883, validation loss: 0.6401895138
# Epoch 201: train loss: 0.4136796829, validation loss: 0.6372811949
# Epoch 202: train loss: 0.4161101146, validation loss: 0.6362628571
# Epoch 203: train loss: 0.4111184406, validation loss: 0.6322585892
# Epoch 204: train loss: 0.4100102907, validation loss: 0.6330995976
# Epoch 205: train loss: 0.4080848316, validation loss: 0.6309347974
# Epoch 206: train loss: 0.4077504900, validation loss: 0.6342902465
# Epoch 207: train loss: 0.4070744271, validation loss: 0.6317966340
# Epoch 208: train loss: 0.4046437945, validation loss: 0.6318076204
# Epoch 209: train loss: 0.4045966481, validation loss: 0.6269008524
# Epoch 210: train loss: 0.4029889096, validation loss: 0.6262995469
# Epoch 211: train loss: 0.4008909608, validation loss: 0.6231417586
# Epoch 212: train loss: 0.3990521156, validation loss: 0.6262230702
# Epoch 213: train loss: 0.3981175357, validation loss: 0.6228594034
# Epoch 214: train loss: 0.3964010452, validation loss: 0.6212170443
# Epoch 215: train loss: 0.3966993014, validation loss: 0.6245335533
# Epoch 216: train loss: 0.3946890527, validation loss: 0.6198237519
# Epoch 217: train loss: 0.3949672320, validation loss: 0.6186285662
# Epoch 218: train loss: 0.3918148404, validation loss: 0.6168695254
# Epoch 219: train loss: 0.3914869737, validation loss: 0.6113772331
# Epoch 220: train loss: 0.3903811868, validation loss: 0.6091445724
# Epoch 221: train loss: 0.3892274320, validation loss: 0.6115170635
# Epoch 222: train loss: 0.3873963910, validation loss: 0.6118625351
# Epoch 223: train loss: 0.3864846160, validation loss: 0.6089994051
# Epoch 224: train loss: 0.3854523745, validation loss: 0.6093028342
# Epoch 225: train loss: 0.3852848688, validation loss: 0.6113902305
# Epoch 226: train loss: 0.3827580770, validation loss: 0.6064727448
# Epoch 227: train loss: 0.3835175734, validation loss: 0.6051738868
# Epoch 228: train loss: 0.3801684877, validation loss: 0.6016939738
# Epoch 229: train loss: 0.3787530989, validation loss: 0.6023462100
# Epoch 230: train loss: 0.3791425961, validation loss: 0.6021646616
# Epoch 231: train loss: 0.3780362956, validation loss: 0.5984133211
# Epoch 232: train loss: 0.3749285729, validation loss: 0.5967365541
# Epoch 233: train loss: 0.3756840918, validation loss: 0.5944813519
# Epoch 234: train loss: 0.3737343484, validation loss: 0.5983117763
# Epoch 235: train loss: 0.3719911350, validation loss: 0.5943228839
# Epoch 236: train loss: 0.3707732314, validation loss: 0.5905356260
# Epoch 237: train loss: 0.3708748013, validation loss: 0.5893444226
# Epoch 238: train loss: 0.3709982553, validation loss: 0.5899930823
# Epoch 239: train loss: 0.3673183984, validation loss: 0.5866873620
# Epoch 240: train loss: 0.3655631774, validation loss: 0.5939920661
# Epoch 241: train loss: 0.3652772757, validation loss: 0.5838555612
# Epoch 242: train loss: 0.3642815869, validation loss: 0.5858493503
# Epoch 243: train loss: 0.3651787571, validation loss: 0.5847478132
# Epoch 244: train loss: 0.3619378523, validation loss: 0.5836694152
# Epoch 245: train loss: 0.3601239237, validation loss: 0.5814815348
# Epoch 246: train loss: 0.3601510494, validation loss: 0.5789796260
# Epoch 247: train loss: 0.3616881957, validation loss: 0.5815262744
# Epoch 248: train loss: 0.3571226454, validation loss: 0.5768549869
# Epoch 249: train loss: 0.3557612247, validation loss: 0.5783237947
# Epoch 250: train loss: 0.3552766544, validation loss: 0.5715266223
# Epoch 251: train loss: 0.3538426879, validation loss: 0.5743338583
# Epoch 252: train loss: 0.3530676660, validation loss: 0.5753281287
# Epoch 253: train loss: 0.3516126113, validation loss: 0.5709731712
# Epoch 254: train loss: 0.3508100617, validation loss: 0.5690721587
# Epoch 255: train loss: 0.3524663497, validation loss: 0.5721714714
# Epoch 256: train loss: 0.3486377511, validation loss: 0.5671890622
# Epoch 257: train loss: 0.3466275059, validation loss: 0.5694315462
# Epoch 258: train loss: 0.3475606742, validation loss: 0.5687884131
# Epoch 259: train loss: 0.3451950698, validation loss: 0.5639412314
# Epoch 260: train loss: 0.3443907854, validation loss: 0.5631795378
# Epoch 261: train loss: 0.3428898745, validation loss: 0.5614935174
# Epoch 262: train loss: 0.3426047565, validation loss: 0.5611858667
# Epoch 263: train loss: 0.3413908767, validation loss: 0.5629037297
# Epoch 264: train loss: 0.3408926767, validation loss: 0.5563255468
# Epoch 265: train loss: 0.3396664498, validation loss: 0.5569065641
# Epoch 266: train loss: 0.3402523786, validation loss: 0.5544010147
# Epoch 267: train loss: 0.3380627851, validation loss: 0.5546150008
# Epoch 268: train loss: 0.3361707521, validation loss: 0.5568029193
# Epoch 269: train loss: 0.3354876483, validation loss: 0.5528364033
# Epoch 270: train loss: 0.3340171983, validation loss: 0.5538325030
# Epoch 271: train loss: 0.3329354869, validation loss: 0.5553092361
# Epoch 272: train loss: 0.3318307467, validation loss: 0.5541547300
# Epoch 273: train loss: 0.3315585621, validation loss: 0.5505204107
# Epoch 274: train loss: 0.3309824092, validation loss: 0.5482757224
# Epoch 275: train loss: 0.3299117573, validation loss: 0.5453468975
# Epoch 276: train loss: 0.3294865317, validation loss: 0.5463255554
# Epoch 277: train loss: 0.3293203540, validation loss: 0.5469048519
# Epoch 278: train loss: 0.3263122006, validation loss: 0.5447316982
# Epoch 279: train loss: 0.3248401326, validation loss: 0.5430083687
# Epoch 280: train loss: 0.3244916757, validation loss: 0.5399710267
# Epoch 281: train loss: 0.3234853166, validation loss: 0.5391104869
# Epoch 282: train loss: 0.3227977398, validation loss: 0.5416615731
# Epoch 283: train loss: 0.3214672426, validation loss: 0.5375940305
# Epoch 284: train loss: 0.3215907734, validation loss: 0.5378402455
# Epoch 285: train loss: 0.3213269621, validation loss: 0.5333427966
# Epoch 286: train loss: 0.3193767854, validation loss: 0.5375151875
# Epoch 287: train loss: 0.3191461370, validation loss: 0.5362059199
# Epoch 288: train loss: 0.3164841032, validation loss: 0.5300007780
# Epoch 289: train loss: 0.3163060976, validation loss: 0.5324895256
# Epoch 290: train loss: 0.3153960231, validation loss: 0.5341401915
# Epoch 291: train loss: 0.3145442214, validation loss: 0.5314365190
# Epoch 292: train loss: 0.3147021995, validation loss: 0.5277453100
# Epoch 293: train loss: 0.3138638290, validation loss: 0.5354911693
# Epoch 294: train loss: 0.3121909981, validation loss: 0.5270695416
# Epoch 295: train loss: 0.3108672165, validation loss: 0.5290413926
# Epoch 296: train loss: 0.3099562167, validation loss: 0.5253502073
# Epoch 297: train loss: 0.3097689429, validation loss: 0.5243055556
# Epoch 298: train loss: 0.3077974780, validation loss: 0.5181454607
# Epoch 299: train loss: 0.3083678407, validation loss: 0.5200924122
# Epoch 300: train loss: 0.3076706272, validation loss: 0.5211349849
# Finished Training
