# %%
# import libraries
import math
import os
import pickle
import random
import time
import itertools
import importlib

# import numpy
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
from sklearn import preprocessing

import torch
import scipy
import scipy.io

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", DEVICE)
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# import Koopman Libraries
from core.koopman_core_linear import KoopDNN_linear, KoopmanNet_linear, KoopmanNetCtrl_linear
from core.util import fit_standardizer
from models.koop_model import model_matricies, lift_raw, lift_scaled

# ===== import Frenet-real-state dynamics file =====
import dynamics.cacalv3 as cacalv3

importlib.reload(cacalv3)
from dynamics.cacalv3 import FK_solver, single_vehicle_data_gen_multi

# control
from control_files.nmpc_osqp_adapt import NonlinearMPCController
from dynamics.learned_models_control.linear_dynamics import linear_Dynamics


# ===== helper for Frenet path =====
def build_test_frenet_path_from_xy(x_ref_path, y_ref_path):
    dx_seg = np.diff(x_ref_path)
    dy_seg = np.diff(y_ref_path)
    ds_seg = np.sqrt(dx_seg ** 2 + dy_seg ** 2)
    s_ref = np.concatenate(([0.0], np.cumsum(ds_seg)))

    dx = np.gradient(x_ref_path)
    dy = np.gradient(y_ref_path)
    psi_ref = np.unwrap(np.arctan2(dy, dx))

    ds = np.gradient(s_ref)
    curvature_ref = np.gradient(psi_ref) / np.maximum(ds, 1e-8)
    curvature_ref = np.nan_to_num(curvature_ref)

    return s_ref, psi_ref, curvature_ref


# ===== Frenet -> Cartesian for plotting =====
def frenet_to_global(s_arr, ey_arr, s_ref_path, x_ref_path, y_ref_path, psi_ref_path):
    x_center = np.interp(s_arr, s_ref_path, x_ref_path)
    y_center = np.interp(s_arr, s_ref_path, y_ref_path)
    psi_center = np.interp(s_arr, s_ref_path, psi_ref_path)

    x_global = x_center - ey_arr * np.sin(psi_center)
    y_global = y_center + ey_arr * np.cos(psi_center)
    return x_global, y_global


def to_numpy(x):
    if hasattr(x, "detach"):
        return x.detach().cpu().numpy()
    return np.array(x)


def scale_state(x_raw, standardizer_x):
    return standardizer_x.transform(np.asarray(x_raw).reshape(1, -1)).flatten()


def scale_state_batch(X_raw, standardizer_x):
    return standardizer_x.transform(np.asarray(X_raw))


def decode_scaled_to_raw(x_scaled, standardizer_x):
    return standardizer_x.inverse_transform(np.asarray(x_scaled).reshape(1, -1)).flatten()



def clip_closed_loop_state(x, s_upper=500.0):
    x = np.asarray(x, dtype=float).copy()
    x[0] = np.clip(x[0], 0.0, s_upper)   # s
    x[1] = np.clip(x[1], -5.0, 5.0)      # e_y
    x[2] = np.clip(x[2], -1.2, 1.2)      # e_psi
    x[3] = np.clip(x[3], 0.5, 8.0)       # v_x
    x[4] = np.clip(x[4], -4.0, 4.0)      # v_y
    x[5] = np.clip(x[5], -3.0, 3.0)      # r
    return x


def is_finite_vector(x):
    x = np.asarray(x, dtype=float)
    return np.all(np.isfinite(x))


def safe_FK_step(x, u, pars, SNR_DB, i, fallback_state=None, verbose=False):
    """
    对 FK_solver 做保护：
    - 若求解结果非有限，则回退到 fallback_state 或当前状态
    - 输出统一做 clip
    """
    try:
        x_next = FK_solver(
            x, u, pars,
            sensor_noise=False,
            SNR_DB=SNR_DB,
            i=i
        )
    except Exception as e:
        if verbose:
            print(f"FK_solver exception at step {i}: {e}")
        if fallback_state is None:
            fallback_state = np.asarray(x, dtype=float).copy()
        return clip_closed_loop_state(fallback_state)

    if not is_finite_vector(x_next):
        if verbose:
            print(f"Non-finite FK_solver output at step {i}")
            print("x =", x)
            print("u =", u)
            print("x_next =", x_next)
        if fallback_state is None:
            fallback_state = np.asarray(x, dtype=float).copy()
        return clip_closed_loop_state(fallback_state)

    return clip_closed_loop_state(x_next)

# =============================================================================
# 系统拟合
# =============================================================================
linear = True

# =============================================================================
# 数据生成 (针对 100m 双移线优化：丰富场景 + 物理不变性数据增强)
# =============================================================================
sys_pars_base = {}

# 6 states: x=[s, e_y, e_psi, v_x, v_y, r]
num_states = 6
num_inputs = 2
dt = 0.02

sys_pars_base["num_states"] = num_states
sys_pars_base["num_inputs"] = num_inputs
sys_pars_base["dt"] = dt

# nominal vehicle parameters
sys_pars_base["m"] = 1500.0
sys_pars_base["Iz"] = 2250.0
sys_pars_base["lf"] = 1.2
sys_pars_base["lr"] = 1.6
sys_pars_base["Cf"] = 80000.0
sys_pars_base["Cr"] = 80000.0
sys_pars_base["curvature_ref"] = 0.0
sys_pars_base["uncertainty"] = "NA"
sys_pars_base["amp"] = 0.0

sys_pars_base["road_modes"] = ['dlc']
sys_pars_base["road_mode_probs"] = [1.0]

sys_pars_base["u_modes"] = ['feedback_dominant', 'sinusoidal', 'mixed']
sys_pars_base["u_mode_probs"] = [0.40, 0.30, 0.30] # 稍微调整激励比例

# sys_pars_base["road_modes"] = ['straight', 'sin', 'const', 'dlc']
# sys_pars_base["road_mode_probs"] = [0.15, 0.15, 0.10, 0.60]
#
# sys_pars_base["u_modes"] = ['feedback_dominant', 'sinusoidal', 'mixed']
# sys_pars_base["u_mode_probs"] = [0.50, 0.30, 0.20]

sys_pars_base["alpha_u"] = 0.70
sys_pars_base["s_margin"] = 15.0
sys_pars_base["seed"] = 42

# changed vehicle parameters
sys_pars_new_base = dict(sys_pars_base)
sys_pars_new_base["m"] = 1650.0
sys_pars_new_base["Iz"] = 2400.0
sys_pars_new_base["Cf"] = 70000.0
sys_pars_new_base["Cr"] = 70000.0

# sys_pars_new_base = dict(sys_pars_base)

sensor_noise = False
SNR_DB = 30
num_snaps = 500

# # 1. 构建混合数据集配置，激发出不同强度的纵横向耦合动态
# configs = [
#     {"vx_ref": 3.0, "delta_max": 0.05, "ax_max": 0.6, "freq": 1.0},
#     {"vx_ref": 3.0, "delta_max": 0.15, "ax_max": 1.0, "freq": 0.5},  # 低频大转角，逼近 DLC
#     {"vx_ref": 3.0, "delta_max": 0.10, "ax_max": 0.8, "freq": 0.2},  # 更低频，拉大 e_y 侧移
#     {"vx_ref": 4.0, "delta_max": 0.10, "ax_max": 0.8, "freq": 0.5},  # 高速覆盖
#     {"vx_ref": 2.0, "delta_max": 0.10, "ax_max": 0.8, "freq": 0.5},  # 低速覆盖
# ]

#  修改点 2：优化激进场景配置，扩大转角和速度包络
configs = [
    {"vx_ref": 3.0, "delta_max": 0.10, "ax_max": 0.6, "freq": 1.0},
    {"vx_ref": 3.0, "delta_max": 0.20, "ax_max": 1.0, "freq": 0.5},  # 低频大转角，逼近紧急 DLC
    {"vx_ref": 4.0, "delta_max": 0.15, "ax_max": 0.8, "freq": 0.2},  # 中高速覆盖，拉大 e_y 侧移
    {"vx_ref": 5.0, "delta_max": 0.10, "ax_max": 0.8, "freq": 0.5},  # 高速覆盖
    {"vx_ref": 2.0, "delta_max": 0.25, "ax_max": 0.8, "freq": 0.5},  # 低速极大转角
]

num_traj_per_batch = 80
X_list, X_changed_list, U_list = [], [], []

print("正在生成覆盖双移线边界条件的多场景数据...")
for cfg in configs:
    sp = dict(sys_pars_base)
    sp.update(cfg)
    # sp["U_type"] = "sinusoidal"

    sp_new = dict(sys_pars_new_base)
    sp_new.update(cfg)
    # sp_new["U_type"] = "sinusoidal"

    X_b, X_changed_b, U_b = single_vehicle_data_gen_multi(
        num_traj_per_batch, num_snaps, sp, sp_new, sensor_noise, SNR_DB
    )
    X_list.append(X_b)
    X_changed_list.append(X_changed_b)
    U_list.append(U_b)

X = np.concatenate(X_list, axis=0)
X_changed = np.concatenate(X_changed_list, axis=0)
U = np.concatenate(U_list, axis=0)
num_traj = X.shape[0]  # Total 400

# 2. 【核心】数据增强 (Data Augmentation)
# 因为在直道上 (curvature_ref=0) 车辆的动态方程不受绝对纵向距离 s 和横向偏移 e_y 的影响
# 所以我们可以直接随机平移 s 和 e_y，扩大 Standardizer 的分布覆盖面，彻底解决饱和越界问题！
np.random.seed(42)
for i in range(num_traj):
    s_shift = np.random.uniform(0.0, 110.0)  # 覆盖 DLC 的 100m 长度
    ey_shift = np.random.uniform(-2.0, 2.0)  # 覆盖 DLC 的侧向偏差并留出充足泛化裕度

    X[i, :, 0] += s_shift
    X_changed[i, :, 0] += s_shift
    X[i, :, 1] += ey_shift
    X_changed[i, :, 1] += ey_shift

# 打乱数据以防止验证集切分时分布不均
indices = np.random.permutation(num_traj)
X = X[indices]
X_changed = X_changed[indices]
U = U[indices]

num_train = int(0.8 * num_traj)
num_val = num_traj - num_train

# 恢复默认的 sys_pars 用于后续代码流转基准
# sys_pars = dict(sys_pars_base)
# sys_pars.update({"vx_ref": 3.0, "delta_max": 0.05, "ax_max": 0.6, "freq": 1.0, "U_type": "sinusoidal"})
# sys_pars_new = dict(sys_pars_new_base)
# sys_pars_new.update({"vx_ref": 3.0, "delta_max": 0.05, "ax_max": 0.6, "freq": 1.0, "U_type": "sinusoidal"})

sys_pars = dict(sys_pars_base)
sys_pars.update({"vx_ref": 3.0, "delta_max": 0.05, "ax_max": 0.6, "freq": 1.0})

sys_pars_new = dict(sys_pars_new_base)
sys_pars_new.update({"vx_ref": 3.0, "delta_max": 0.05, "ax_max": 0.6, "freq": 1.0})

print("X shape:", X.shape)
print("X_changed shape:", X_changed.shape)
print("U shape:", U.shape)

os.makedirs("saved_data/single_vehicle", exist_ok=True)

np.savez_compressed(
    "saved_data/single_vehicle/offline_dataset.npz",
    X=X,
    X_changed=X_changed,
    U=U
)

with open("saved_data/single_vehicle/offline_dataset_pars.pkl", "wb") as f:
    pickle.dump({
        "sys_pars": sys_pars,
        "sys_pars_new": sys_pars_new,
        "num_traj": num_traj,
        "num_train": num_train,
        "num_val": num_val,
        "num_snaps": num_snaps,
        "sensor_noise": sensor_noise,
        "SNR_DB": SNR_DB
    }, f)

print("离线数据已保存。")



state_labels = ["s", "e_y", "e_psi", "v_x", "v_y", "r"]
input_labels = ["delta", "a_x"]
t_train = np.linspace(0, dt * (num_snaps - 1), num_snaps)

plt.figure(figsize=(18, 12))
for j in range(num_traj):
    for i in range(num_states):
        plt.subplot(num_states, 1, i + 1)
        plt.plot(t_train, X[j, :, i], alpha=0.7)
        plt.ylabel(state_labels[i])
        plt.xlabel("t")
plt.suptitle("Original Vehicle Dynamics", fontsize=20)
plt.tight_layout()
plt.show()

plt.figure(figsize=(18, 12))
for j in range(num_traj):
    for i in range(num_states):
        plt.subplot(num_states, 1, i + 1)
        plt.plot(t_train, X_changed[j, :, i], alpha=0.7)
        plt.ylabel(state_labels[i])
        plt.xlabel("t")
plt.suptitle("Changed Vehicle Dynamics", fontsize=20)
plt.tight_layout()
plt.show()

plt.figure(figsize=(18, 6))
for j in range(num_traj):
    for i in range(num_inputs):
        plt.subplot(num_inputs, 1, i + 1)
        plt.plot(t_train[:-1], U[j, :, i], alpha=0.7)
        plt.ylabel(input_labels[i])
        plt.xlabel("t")
plt.suptitle("Control Inputs", fontsize=20)
plt.tight_layout()
plt.show()

# =============================================================================
# Learning Koopman
# =============================================================================
xs_train, us_train = X[:num_train, :, :], U[:num_train, :, :]
xs_val, us_val = X[num_train:, :, :], U[num_train:, :, :]

net_params_lin = {}
net_params_lin["state_dim"] = num_states
net_params_lin["ctrl_dim"] = num_inputs
net_params_lin["encoder_hidden_width"] = 128
# 模型容量适度提升：场景增多变复杂了，给隐变量输出更多维度
net_params_lin["encoder_hidden_depth"] = 4
net_params_lin["encoder_output_dim"] = 16
net_params_lin["optimizer"] = "adam"
net_params_lin["activation_type"] = "tanh"
net_params_lin["lr"] = 1e-4
net_params_lin["epochs"] = 500
net_params_lin["batch_size"] = 256

net_params_lin["eig_loss"] = True
net_params_lin["eig_loss_coeff"] = 0.5
net_params_lin["lifted_loss_penalty"] = 0.3

net_params_lin["l2_reg"] = 5e-5
net_params_lin["l1_reg"] = 1e-7
net_params_lin["first_obs_const"] = True
net_params_lin["override_C"] = True
net_params_lin["dt"] = dt

train = True
standardize = True

os.makedirs("saved_models/single_vehicle/linear", exist_ok=True)

file_koop_linear = (
        "saved_models/single_vehicle/linear/"
        + "Koop_vehicle_Dim"
        + str(net_params_lin["encoder_output_dim"])
        + "_dt_"
        + str(dt)
        + ".pth"
)

print("Model save path:", file_koop_linear)

standardizer_u_kdnn = fit_standardizer(
    us_train, preprocessing.StandardScaler(with_mean=True)
)
standardizer_x_kdnn = fit_standardizer(
    xs_train, preprocessing.StandardScaler(with_mean=True)
)

if train:
    if standardize:
        net = KoopmanNetCtrl_linear(
            net_params_lin,
            standardizer_x=standardizer_x_kdnn,
            standardizer_u=standardizer_u_kdnn,
            device=DEVICE
        )
    else:
        net = KoopmanNetCtrl_linear(
            net_params_lin,
            device=DEVICE
        )

    model_koop_dnn_lin = KoopDNN_linear(net)
    model_koop_dnn_lin.set_datasets(
        xs_train,
        u_train=us_train,
        x_val=xs_val,
        u_val=us_val
    )
    model_koop_dnn_lin.model_pipeline(net_params_lin)
    model_koop_dnn_lin.construct_koopman_model()

    torch.save(model_koop_dnn_lin, file_koop_linear)
else:
    model_koop_dnn_lin = torch.load(file_koop_linear, map_location=DEVICE)
    model_koop_dnn_lin.net.to(DEVICE)
    model_koop_dnn_lin.net.device = DEVICE

train_loss = [l[0] for l in model_koop_dnn_lin.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn_lin.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn_lin.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn_lin.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn_lin.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn_lin.val_loss_hist]
epochs = np.arange(0, net_params_lin["epochs"])

plt.figure(figsize=(15, 8))
plt.plot(epochs, train_loss, color="tab:orange", label="Training loss")
plt.plot(epochs, train_pred_loss, "--", color="tab:orange", label="Training prediction loss")
plt.plot(epochs, train_lifted_loss, ":", color="tab:orange", label="Training lifted loss")
plt.plot(epochs, val_loss, color="tab:blue", label="Validation loss")
plt.plot(epochs, val_pred_loss, "--", color="tab:blue", label="Validation prediction loss")
plt.plot(epochs, val_lifted_loss, ":", color="tab:blue", label="Validation lifted loss")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.yscale("log")
plt.show()

# =============================================================================
# Koopman Model Parameters (Open Loop Test)
# =============================================================================
num_snaps_test = 100
T_test = np.linspace(0, (num_snaps_test - 1) * dt, num_snaps_test)

num_traj_test = 1
first_obs_const = int(net_params_lin["first_obs_const"])
override_C = net_params_lin["override_C"]
if override_C:
    n_obs_lin = int(net_params_lin["encoder_output_dim"]) + num_states + first_obs_const
else:
    n_obs_lin = int(net_params_lin["encoder_output_dim"]) + first_obs_const

x_unchanged_test, x_changed_test, u_test = single_vehicle_data_gen_multi(
    num_traj_test, num_snaps_test, sys_pars, sys_pars_new, sensor_noise, SNR_DB
)

A_lin = np.array(model_koop_dnn_lin.A)
B_lin = np.array(model_koop_dnn_lin.B)
C_lin = np.array(model_koop_dnn_lin.C)

eigvals, eigvecs = np.linalg.eig(A_lin)
eigvals_proj = np.array([
    ev if np.abs(ev) <= 0.999 else ev / np.abs(ev) * 0.999
    for ev in eigvals
])
A_lin_stable = eigvecs @ np.diag(eigvals_proj) @ np.linalg.inv(eigvecs)
A_lin_stable = np.real(A_lin_stable)

eigvals_stable = np.linalg.eigvals(A_lin_stable)
print("stable spectral radius =", np.max(np.abs(eigvals_stable)))

print("A, B, C shapes:", A_lin.shape, B_lin.shape, C_lin.shape)

eigvals = np.linalg.eigvals(A_lin)
spectral_radius = np.max(np.abs(eigvals))

print("spectral radius =", spectral_radius)
print("eigvals =", eigvals)

plt.figure(figsize=(6, 6))
plt.scatter(np.real(eigvals), np.imag(eigvals), label="eig(A)")
theta = np.linspace(0, 2 * np.pi, 400)
plt.plot(np.cos(theta), np.sin(theta), "--", label="unit circle")
plt.axhline(0)
plt.axvline(0)
plt.xlabel("Real")
plt.ylabel("Imag")
plt.legend()
plt.title("Eigenvalues of A_lin")
plt.axis("equal")
plt.show()

X_unchanged_scaled, _ = model_koop_dnn_lin.net.process(x_unchanged_test, data_u=u_test)
X_changed_scaled, _ = model_koop_dnn_lin.net.process(x_changed_test, data_u=u_test)

x_unchanged_scaled = X_unchanged_scaled[:, :num_states]
u_scaled = X_unchanged_scaled[:, num_states:num_states + num_inputs]
x_unchanged_prime_scaled = X_unchanged_scaled[:, num_states + num_inputs:]

x_changed_scaled = X_changed_scaled[:, :num_states]
x_changed_prime_scaled = X_changed_scaled[:, num_states + num_inputs:]

print("x_unchanged_scaled shape:", x_unchanged_scaled.shape)
print("u_scaled shape:", u_scaled.shape)
print("x_changed_scaled shape:", x_changed_scaled.shape)
print("x_changed_prime_scaled shape:", x_changed_prime_scaled.shape)

num_pred = x_unchanged_scaled.shape[0]

z_lin = np.zeros((num_pred, n_obs_lin))
x_est_lin = np.zeros((num_pred, num_states))

z_lin[0, :] = lift_scaled(x_unchanged_scaled[0, :], model_koop_dnn_lin, net_params_lin)
x_est_lin[0, :] = np.matmul(z_lin[0, :], C_lin.T)

for k in range(num_pred - 1):
    z_lin[k + 1, :] = np.matmul(z_lin[k, :], A_lin.T) + np.matmul(u_scaled[k, :], B_lin.T)
    x_est_lin[k + 1, :] = np.matmul(z_lin[k + 1, :], C_lin.T)

z_lin_stable = np.zeros((num_pred, n_obs_lin))
x_est_lin_stable = np.zeros((num_pred, num_states))

z_lin_stable[0, :] = lift_scaled(x_unchanged_scaled[0, :], model_koop_dnn_lin, net_params_lin)
x_est_lin_stable[0, :] = np.matmul(z_lin_stable[0, :], C_lin.T)

for k in range(num_pred - 1):
    z_lin_stable[k + 1, :] = np.matmul(z_lin_stable[k, :], A_lin_stable.T) + np.matmul(u_scaled[k, :], B_lin.T)
    x_est_lin_stable[k + 1, :] = np.matmul(z_lin_stable[k + 1, :], C_lin.T)

T_plot = np.arange(num_pred) * dt

plt.figure(figsize=(18, 12))
for i in range(num_states):
    plt.subplot(num_states, 1, i + 1)
    plt.xlabel("t")
    plt.ylabel(state_labels[i])
    plt.plot(T_plot, x_unchanged_scaled[:, i], label="True")
    plt.plot(T_plot, x_est_lin[:, i], "--", label="Open-loop Koopman")
    plt.plot(T_plot, x_est_lin_stable[:, i], "-.", label="Stable-projected Koopman")
    plt.legend()

plt.suptitle("Open-loop Prediction Comparison (scaled state space)", fontsize=20)
plt.tight_layout()
plt.show()

x_est_lin_raw = standardizer_x_kdnn.inverse_transform(x_est_lin)
x_est_lin_stable_raw = standardizer_x_kdnn.inverse_transform(x_est_lin_stable)
x_true_raw = x_unchanged_test[0, :-1, :]

plt.figure(figsize=(18, 12))
for i in range(num_states):
    plt.subplot(num_states, 1, i + 1)
    plt.xlabel("t")
    plt.ylabel(state_labels[i])
    plt.plot(T_plot, x_true_raw[:, i], label="True (raw)")
    plt.plot(T_plot, x_est_lin_raw[:, i], "--", label="Open-loop Koopman (raw)")
    plt.plot(T_plot, x_est_lin_stable_raw[:, i], "-.", label="Stable-projected Koopman (raw)")
    plt.legend()

plt.suptitle("Open-loop Prediction Comparison (raw state space)", fontsize=20)
plt.tight_layout()
plt.show()

x_one_step_pred = np.zeros_like(x_unchanged_prime_scaled)

for k in range(num_pred):
    z_k = lift_scaled(x_unchanged_scaled[k, :], model_koop_dnn_lin, net_params_lin)
    z_k1 = np.matmul(z_k, A_lin.T) + np.matmul(u_scaled[k, :], B_lin.T)
    x_one_step_pred[k, :] = np.matmul(z_k1, C_lin.T)

T_plot_1 = np.arange(x_one_step_pred.shape[0]) * dt

plt.figure(figsize=(18, 12))
for i in range(num_states):
    plt.subplot(num_states, 1, i + 1)
    plt.plot(T_plot_1, x_unchanged_prime_scaled[:, i], label="True next state")
    plt.plot(T_plot_1, x_one_step_pred[:, i], "--", label="One-step Koopman")
    plt.ylabel(state_labels[i])
    plt.legend()
plt.suptitle("One-step Prediction Performance (scaled state space)", fontsize=20)
plt.tight_layout()
plt.show()

x_one_step_pred_raw = standardizer_x_kdnn.inverse_transform(x_one_step_pred)
x_true_next_raw = x_unchanged_test[0, 1:, :]

T_plot_raw = np.arange(x_true_next_raw.shape[0]) * dt

plt.figure(figsize=(18, 12))
for i in range(num_states):
    plt.subplot(num_states, 1, i + 1)
    plt.plot(T_plot_raw, x_true_next_raw[:, i], label="True next state (raw)")
    plt.plot(T_plot_raw, x_one_step_pred_raw[:, i], "--", label="One-step Koopman (raw)")
    plt.ylabel(state_labels[i])
    plt.legend()
plt.suptitle("One-step Prediction Performance (raw state space)", fontsize=20)
plt.tight_layout()
plt.show()
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 5080
# 正在生成覆盖双移线边界条件的多场景数据...
# X shape: (400, 500, 6)
# X_changed shape: (400, 500, 6)
# U shape: (400, 499, 2)
# 离线数据已保存。
# Model save path: saved_models/single_vehicle/linear/Koop_vehicle_Dim16_dt_0.02.pth
# Epoch   1: train loss: 1.1201259882, validation loss: 1.2967800313
# Epoch   2: train loss: 1.0252944494, validation loss: 1.2612640464
# Epoch   3: train loss: 0.9948058555, validation loss: 1.2350043668
# Epoch   4: train loss: 0.9705335250, validation loss: 1.2118040328
# Epoch   5: train loss: 0.9496566436, validation loss: 1.1923261549
# Epoch   6: train loss: 0.9307184718, validation loss: 1.1741933993
# Epoch   7: train loss: 0.9149920978, validation loss: 1.1579595598
# Epoch   8: train loss: 0.9022605561, validation loss: 1.1452531706
# Epoch   9: train loss: 0.8903710473, validation loss: 1.1322661765
# Epoch  10: train loss: 0.8810485351, validation loss: 1.1210275105
# Epoch  11: train loss: 0.8724832755, validation loss: 1.1148417018
# Epoch  12: train loss: 0.8651020054, validation loss: 1.1047381950
# Epoch  13: train loss: 0.8588858011, validation loss: 1.1021844976
# Epoch  14: train loss: 0.8529316409, validation loss: 1.0945560364
# Epoch  15: train loss: 0.8471785270, validation loss: 1.0808131757
# Epoch  16: train loss: 0.8424945932, validation loss: 1.0809355718
# Epoch  17: train loss: 0.8374148674, validation loss: 1.0694272472
# Epoch  18: train loss: 0.8328976109, validation loss: 1.0653727135
# Epoch  19: train loss: 0.8281706046, validation loss: 1.0599292452
# Epoch  20: train loss: 0.8242181492, validation loss: 1.0521283512
# Epoch  21: train loss: 0.8193478391, validation loss: 1.0498861065
# Epoch  22: train loss: 0.8156368578, validation loss: 1.0436014735
# Epoch  23: train loss: 0.8113065485, validation loss: 1.0419275903
# Epoch  24: train loss: 0.8080213596, validation loss: 1.0355318119
# Epoch  25: train loss: 0.8036739091, validation loss: 1.0289545438
# Epoch  26: train loss: 0.7995346365, validation loss: 1.0259720338
# Epoch  27: train loss: 0.7964032432, validation loss: 1.0206599936
# Epoch  28: train loss: 0.7924273995, validation loss: 1.0197977898
# Epoch  29: train loss: 0.7884026470, validation loss: 1.0138916453
# Epoch  30: train loss: 0.7847975722, validation loss: 1.0063610293
# Epoch  31: train loss: 0.7826336826, validation loss: 1.0039599447
# Epoch  32: train loss: 0.7785574303, validation loss: 1.0064776042
# Epoch  33: train loss: 0.7762821164, validation loss: 0.9977828388
# Epoch  34: train loss: 0.7721849154, validation loss: 0.9923030253
# Epoch  35: train loss: 0.7697717566, validation loss: 0.9895060728
# Epoch  36: train loss: 0.7661226904, validation loss: 0.9881689432
# Epoch  37: train loss: 0.7636213768, validation loss: 0.9850971767
# Epoch  38: train loss: 0.7601297164, validation loss: 0.9801417635
# Epoch  39: train loss: 0.7574652043, validation loss: 0.9752839423
# Epoch  40: train loss: 0.7546440259, validation loss: 0.9720177843
# Epoch  41: train loss: 0.7522452461, validation loss: 0.9686365263
# Epoch  42: train loss: 0.7507000564, validation loss: 0.9671698783
# Epoch  43: train loss: 0.7465902351, validation loss: 0.9646833079
# Epoch  44: train loss: 0.7446106493, validation loss: 0.9575673253
# Epoch  45: train loss: 0.7410455518, validation loss: 0.9625123530
# Epoch  46: train loss: 0.7395090793, validation loss: 0.9525718277
# Epoch  47: train loss: 0.7358992431, validation loss: 0.9562599296
# Epoch  48: train loss: 0.7336365088, validation loss: 0.9486598856
# Epoch  49: train loss: 0.7313953904, validation loss: 0.9425966384
# Epoch  50: train loss: 0.7284466383, validation loss: 0.9410761436
# Epoch  51: train loss: 0.7274884937, validation loss: 0.9368761884
# Epoch  52: train loss: 0.7254870330, validation loss: 0.9329165494
# Epoch  53: train loss: 0.7216853550, validation loss: 0.9310710578
# Epoch  54: train loss: 0.7191398488, validation loss: 0.9329494539
# Epoch  55: train loss: 0.7170874076, validation loss: 0.9256788004
# Epoch  56: train loss: 0.7149684505, validation loss: 0.9238728340
# Epoch  57: train loss: 0.7131266193, validation loss: 0.9214922291
# Epoch  58: train loss: 0.7107358577, validation loss: 0.9180414117
# Epoch  59: train loss: 0.7087840954, validation loss: 0.9216243911
# Epoch  60: train loss: 0.7078006617, validation loss: 0.9142203643
# Epoch  61: train loss: 0.7039889716, validation loss: 0.9128806776
# Epoch  62: train loss: 0.7009509174, validation loss: 0.9112827885
# Epoch  63: train loss: 0.7006207070, validation loss: 0.9080229597
# Epoch  64: train loss: 0.6981193266, validation loss: 0.9038384651
# Epoch  65: train loss: 0.6963152029, validation loss: 0.9018975296
# Epoch  66: train loss: 0.6948640637, validation loss: 0.8989182520
# Epoch  67: train loss: 0.6950133738, validation loss: 0.8973186308
# Epoch  68: train loss: 0.6894188187, validation loss: 0.8960826258
# Epoch  69: train loss: 0.6879962268, validation loss: 0.8908199424
# Epoch  70: train loss: 0.6872745022, validation loss: 0.8924468429
# Epoch  71: train loss: 0.6844192748, validation loss: 0.8887982521
# Epoch  72: train loss: 0.6819225125, validation loss: 0.8835405526
# Epoch  73: train loss: 0.6806370631, validation loss: 0.8838218729
# Epoch  74: train loss: 0.6788367179, validation loss: 0.8809586042
# Epoch  75: train loss: 0.6777414373, validation loss: 0.8794816006
# Epoch  76: train loss: 0.6772317728, validation loss: 0.8803003008
# Epoch  77: train loss: 0.6733315442, validation loss: 0.8765909000
# Epoch  78: train loss: 0.6722346189, validation loss: 0.8736384483
# Epoch  79: train loss: 0.6698271200, validation loss: 0.8762302242
# Epoch  80: train loss: 0.6683009856, validation loss: 0.8710351882
# Epoch  81: train loss: 0.6668018587, validation loss: 0.8666537241
# Epoch  82: train loss: 0.6644168760, validation loss: 0.8672148371
# Epoch  83: train loss: 0.6630476197, validation loss: 0.8648156045
# Epoch  84: train loss: 0.6602472384, validation loss: 0.8617375936
# Epoch  85: train loss: 0.6603470518, validation loss: 0.8569268615
# Epoch  86: train loss: 0.6567683101, validation loss: 0.8564000396
# Epoch  87: train loss: 0.6558362702, validation loss: 0.8584496003
# Epoch  88: train loss: 0.6539404166, validation loss: 0.8541261301
# Epoch  89: train loss: 0.6532907847, validation loss: 0.8515716971
# Epoch  90: train loss: 0.6517592678, validation loss: 0.8474241970
# Epoch  91: train loss: 0.6492126311, validation loss: 0.8454194387
# Epoch  92: train loss: 0.6486253840, validation loss: 0.8464111448
# Epoch  93: train loss: 0.6460725256, validation loss: 0.8459618347
# Epoch  94: train loss: 0.6444596119, validation loss: 0.8430103900
# Epoch  95: train loss: 0.6434836925, validation loss: 0.8404112903
# Epoch  96: train loss: 0.6422766861, validation loss: 0.8390467563
# Epoch  97: train loss: 0.6398659887, validation loss: 0.8374859547
# Epoch  98: train loss: 0.6386282585, validation loss: 0.8399136412
# Epoch  99: train loss: 0.6384996591, validation loss: 0.8331076776
# Epoch 100: train loss: 0.6364274774, validation loss: 0.8326320618
# Epoch 101: train loss: 0.6344303511, validation loss: 0.8287768792
# Epoch 102: train loss: 0.6324317403, validation loss: 0.8311663263
# Epoch 103: train loss: 0.6312977878, validation loss: 0.8282073698
# Epoch 104: train loss: 0.6306968741, validation loss: 0.8238417610
# Epoch 105: train loss: 0.6277245775, validation loss: 0.8238259504
# Epoch 106: train loss: 0.6296956390, validation loss: 0.8227261297
# Epoch 107: train loss: 0.6244743865, validation loss: 0.8190267801
# Epoch 108: train loss: 0.6248167621, validation loss: 0.8177933807
# Epoch 109: train loss: 0.6228285134, validation loss: 0.8158803515
# Epoch 110: train loss: 0.6214103689, validation loss: 0.8154241446
# Epoch 111: train loss: 0.6204849248, validation loss: 0.8126184349
# Epoch 112: train loss: 0.6192943005, validation loss: 0.8120245051
# Epoch 113: train loss: 0.6184069351, validation loss: 0.8087414330
# Epoch 114: train loss: 0.6187481585, validation loss: 0.8068202750
# Epoch 115: train loss: 0.6161827603, validation loss: 0.8084990947
# Epoch 116: train loss: 0.6141562629, validation loss: 0.8042611105
# Epoch 117: train loss: 0.6127153627, validation loss: 0.8061386648
# Epoch 118: train loss: 0.6126157572, validation loss: 0.8024549079
# Epoch 119: train loss: 0.6096457795, validation loss: 0.8050571112
# Epoch 120: train loss: 0.6102812430, validation loss: 0.7993896350
# Epoch 121: train loss: 0.6085850238, validation loss: 0.7987456073
# Epoch 122: train loss: 0.6071155401, validation loss: 0.7969866265
# Epoch 123: train loss: 0.6055032102, validation loss: 0.7971874815
# Epoch 124: train loss: 0.6041492503, validation loss: 0.7936118517
# Epoch 125: train loss: 0.6032754280, validation loss: 0.7969093340
# Epoch 126: train loss: 0.6013507834, validation loss: 0.7920028705
# Epoch 127: train loss: 0.6007082779, validation loss: 0.7918529465
# Epoch 128: train loss: 0.5997197777, validation loss: 0.7874213362
# Epoch 129: train loss: 0.5977936127, validation loss: 0.7863840246
# Epoch 130: train loss: 0.5969420977, validation loss: 0.7863960609
# Epoch 131: train loss: 0.5955328756, validation loss: 0.7841862798
# Epoch 132: train loss: 0.5948233230, validation loss: 0.7828957932
# Epoch 133: train loss: 0.5936309209, validation loss: 0.7822926284
# Epoch 134: train loss: 0.5918371641, validation loss: 0.7798058460
# Epoch 135: train loss: 0.5917019085, validation loss: 0.7794601103
# Epoch 136: train loss: 0.5911425371, validation loss: 0.7801771894
# Epoch 137: train loss: 0.5895466064, validation loss: 0.7757381631
# Epoch 138: train loss: 0.5874201677, validation loss: 0.7748858720
# Epoch 139: train loss: 0.5872140349, validation loss: 0.7728301329
# Epoch 140: train loss: 0.5865163448, validation loss: 0.7713775811
# Epoch 141: train loss: 0.5853869089, validation loss: 0.7710742920
# Epoch 142: train loss: 0.5836162226, validation loss: 0.7715796962
# Epoch 143: train loss: 0.5832608948, validation loss: 0.7692099065
# Epoch 144: train loss: 0.5814230542, validation loss: 0.7713772910
# Epoch 145: train loss: 0.5804253545, validation loss: 0.7674703029
# Epoch 146: train loss: 0.5794239780, validation loss: 0.7666755528
# Epoch 147: train loss: 0.5787364633, validation loss: 0.7623432136
# Epoch 148: train loss: 0.5770446393, validation loss: 0.7628488655
# Epoch 149: train loss: 0.5759367200, validation loss: 0.7668816969
# Epoch 150: train loss: 0.5760906297, validation loss: 0.7609421966
# Epoch 151: train loss: 0.5742851150, validation loss: 0.7587509289
# Epoch 152: train loss: 0.5733524989, validation loss: 0.7618981872
# Epoch 153: train loss: 0.5724112239, validation loss: 0.7598724554
# Epoch 154: train loss: 0.5715971076, validation loss: 0.7590184919
# Epoch 155: train loss: 0.5714927008, validation loss: 0.7575464496
# Epoch 156: train loss: 0.5706066748, validation loss: 0.7560125392
# Epoch 157: train loss: 0.5681688093, validation loss: 0.7543471120
# Epoch 158: train loss: 0.5675937056, validation loss: 0.7511857398
# Epoch 159: train loss: 0.5670463647, validation loss: 0.7532968323
# Epoch 160: train loss: 0.5648718285, validation loss: 0.7498853931
# Epoch 161: train loss: 0.5652579452, validation loss: 0.7486775793
# Epoch 162: train loss: 0.5628131078, validation loss: 0.7484186657
# Epoch 163: train loss: 0.5624374148, validation loss: 0.7465996677
# Epoch 164: train loss: 0.5620040112, validation loss: 0.7471010786
# Epoch 165: train loss: 0.5599137977, validation loss: 0.7427211563
# Epoch 166: train loss: 0.5597085016, validation loss: 0.7434195982
# Epoch 167: train loss: 0.5601239676, validation loss: 0.7410648232
# Epoch 168: train loss: 0.5575571103, validation loss: 0.7403480348
# Epoch 169: train loss: 0.5576377866, validation loss: 0.7387692088
# Epoch 170: train loss: 0.5563761068, validation loss: 0.7376362390
# Epoch 171: train loss: 0.5552245233, validation loss: 0.7359212896
# Epoch 172: train loss: 0.5542624820, validation loss: 0.7359294632
# Epoch 173: train loss: 0.5527196429, validation loss: 0.7348751677
# Epoch 174: train loss: 0.5531877999, validation loss: 0.7332308055
# Epoch 175: train loss: 0.5509133855, validation loss: 0.7333213505
# Epoch 176: train loss: 0.5499646871, validation loss: 0.7318597953
# Epoch 177: train loss: 0.5495249341, validation loss: 0.7305804460
# Epoch 178: train loss: 0.5475626994, validation loss: 0.7289450579
# Epoch 179: train loss: 0.5471205797, validation loss: 0.7250715752
# Epoch 180: train loss: 0.5471943663, validation loss: 0.7254378550
# Epoch 181: train loss: 0.5446625019, validation loss: 0.7290988911
# Epoch 182: train loss: 0.5456316214, validation loss: 0.7234396197
# Epoch 183: train loss: 0.5436073880, validation loss: 0.7245622219
# Epoch 184: train loss: 0.5442913920, validation loss: 0.7200389596
# Epoch 185: train loss: 0.5416093026, validation loss: 0.7258564222
# Epoch 186: train loss: 0.5412792771, validation loss: 0.7209163149
# Epoch 187: train loss: 0.5401088003, validation loss: 0.7225792222
# Epoch 188: train loss: 0.5400480939, validation loss: 0.7170422628
# Epoch 189: train loss: 0.5388600058, validation loss: 0.7165791500
# Epoch 190: train loss: 0.5377419808, validation loss: 0.7143546848
# Epoch 191: train loss: 0.5364639448, validation loss: 0.7121258698
# Epoch 192: train loss: 0.5354373021, validation loss: 0.7147231341
# Epoch 193: train loss: 0.5351856456, validation loss: 0.7138623881
# Epoch 194: train loss: 0.5334592426, validation loss: 0.7104199118
# Epoch 195: train loss: 0.5328411827, validation loss: 0.7113800138
# Epoch 196: train loss: 0.5322446270, validation loss: 0.7088698296
# Epoch 197: train loss: 0.5330993884, validation loss: 0.7066394257
# Epoch 198: train loss: 0.5309116418, validation loss: 0.7062918901
# Epoch 199: train loss: 0.5300447826, validation loss: 0.7041059723
# Epoch 200: train loss: 0.5294292875, validation loss: 0.7043258382
# Epoch 201: train loss: 0.5288428154, validation loss: 0.7025854696
# Epoch 202: train loss: 0.5271957781, validation loss: 0.7014112045
# Epoch 203: train loss: 0.5258720349, validation loss: 0.7007330573
# Epoch 204: train loss: 0.5255974526, validation loss: 0.7022072528
# Epoch 205: train loss: 0.5243860551, validation loss: 0.7037895394
# Epoch 206: train loss: 0.5232344799, validation loss: 0.7010831384
# Epoch 207: train loss: 0.5228893754, validation loss: 0.6954396659
# Epoch 208: train loss: 0.5236392153, validation loss: 0.6986786313
# Epoch 209: train loss: 0.5207441524, validation loss: 0.6930727524
# Epoch 210: train loss: 0.5190611283, validation loss: 0.6967536575
# Epoch 211: train loss: 0.5191895718, validation loss: 0.6936133825
# Epoch 212: train loss: 0.5191290025, validation loss: 0.6908556093
# Epoch 213: train loss: 0.5173771351, validation loss: 0.6928356674
# Epoch 214: train loss: 0.5178083628, validation loss: 0.6884620209
# Epoch 215: train loss: 0.5155907436, validation loss: 0.6883485408
# Epoch 216: train loss: 0.5159826235, validation loss: 0.6851652833
# Epoch 217: train loss: 0.5134121377, validation loss: 0.6882516038
# Epoch 218: train loss: 0.5129690998, validation loss: 0.6860876335
# Epoch 219: train loss: 0.5123908836, validation loss: 0.6851081449
# Epoch 220: train loss: 0.5111799056, validation loss: 0.6856085010
# Epoch 221: train loss: 0.5110053247, validation loss: 0.6833228925
# Epoch 222: train loss: 0.5114943393, validation loss: 0.6790181853
# Epoch 223: train loss: 0.5098578596, validation loss: 0.6788861139
# Epoch 224: train loss: 0.5090377874, validation loss: 0.6815410454
# Epoch 225: train loss: 0.5073275623, validation loss: 0.6750313372
# Epoch 226: train loss: 0.5066881201, validation loss: 0.6793721026
# Epoch 227: train loss: 0.5056820515, validation loss: 0.6812860788
# Epoch 228: train loss: 0.5057942635, validation loss: 0.6742616986
# Epoch 229: train loss: 0.5051507001, validation loss: 0.6733540808
# Epoch 230: train loss: 0.5030176598, validation loss: 0.6713621305
# Epoch 231: train loss: 0.5024493833, validation loss: 0.6737972990
# Epoch 232: train loss: 0.5017259774, validation loss: 0.6723766049
# Epoch 233: train loss: 0.4999343245, validation loss: 0.6679166244
# Epoch 234: train loss: 0.4997333825, validation loss: 0.6677668730
# Epoch 235: train loss: 0.4986170160, validation loss: 0.6681096145
# Epoch 236: train loss: 0.4980375173, validation loss: 0.6656901467
# Epoch 237: train loss: 0.4974738420, validation loss: 0.6634049274
# Epoch 238: train loss: 0.4960890925, validation loss: 0.6659003944
# Epoch 239: train loss: 0.4952359847, validation loss: 0.6615139263
# Epoch 240: train loss: 0.4954703199, validation loss: 0.6607887950
# Epoch 241: train loss: 0.4951845056, validation loss: 0.6637689006
# Epoch 242: train loss: 0.4925919712, validation loss: 0.6591445870
# Epoch 243: train loss: 0.4925376298, validation loss: 0.6629741917
# Epoch 244: train loss: 0.4907842239, validation loss: 0.6601315848
# Epoch 245: train loss: 0.4902629933, validation loss: 0.6570935536
# Epoch 246: train loss: 0.4891176738, validation loss: 0.6547551756
# Epoch 247: train loss: 0.4889944001, validation loss: 0.6552563595
# Epoch 248: train loss: 0.4882766105, validation loss: 0.6528103787
# Epoch 249: train loss: 0.4863722566, validation loss: 0.6518589082
# Epoch 250: train loss: 0.4864658626, validation loss: 0.6505462866
# Epoch 251: train loss: 0.4849600461, validation loss: 0.6552851316
# Epoch 252: train loss: 0.4858218087, validation loss: 0.6517851496
# Epoch 253: train loss: 0.4843682041, validation loss: 0.6480523094
# Epoch 254: train loss: 0.4834070856, validation loss: 0.6454208585
# Epoch 255: train loss: 0.4818256503, validation loss: 0.6433034068
# Epoch 256: train loss: 0.4816925246, validation loss: 0.6494030048
# Epoch 257: train loss: 0.4803112422, validation loss: 0.6445085377
# Epoch 258: train loss: 0.4792005962, validation loss: 0.6430352006
# Epoch 259: train loss: 0.4803338552, validation loss: 0.6433282383
# Epoch 260: train loss: 0.4778253617, validation loss: 0.6406486692
# Epoch 261: train loss: 0.4766328619, validation loss: 0.6358249231
# Epoch 262: train loss: 0.4755692753, validation loss: 0.6382633386
# Epoch 263: train loss: 0.4759342131, validation loss: 0.6362045302
# Epoch 264: train loss: 0.4741191412, validation loss: 0.6371279431
# Epoch 265: train loss: 0.4748366944, validation loss: 0.6344924465
# Epoch 266: train loss: 0.4747383645, validation loss: 0.6360726383
# Epoch 267: train loss: 0.4724965608, validation loss: 0.6356499552
# Epoch 268: train loss: 0.4705540321, validation loss: 0.6347255171
# Epoch 269: train loss: 0.4698346151, validation loss: 0.6307042227
# Epoch 270: train loss: 0.4697700263, validation loss: 0.6273424208
# Epoch 271: train loss: 0.4705590506, validation loss: 0.6267767631
# Epoch 272: train loss: 0.4684358612, validation loss: 0.6261407145
# Epoch 273: train loss: 0.4671273442, validation loss: 0.6275220769
# Epoch 274: train loss: 0.4674516420, validation loss: 0.6262552225
# Epoch 275: train loss: 0.4665274251, validation loss: 0.6242394633
# Epoch 276: train loss: 0.4651527356, validation loss: 0.6243565489
# Epoch 277: train loss: 0.4642531432, validation loss: 0.6235041466
# Epoch 278: train loss: 0.4635686633, validation loss: 0.6199949880
# Epoch 279: train loss: 0.4622584524, validation loss: 0.6216306261
# Epoch 280: train loss: 0.4611556406, validation loss: 0.6195616312
# Epoch 281: train loss: 0.4604354427, validation loss: 0.6222721315
# Epoch 282: train loss: 0.4598495778, validation loss: 0.6185834779
# Epoch 283: train loss: 0.4590147945, validation loss: 0.6187691250
# Epoch 284: train loss: 0.4584379851, validation loss: 0.6150339686
# Epoch 285: train loss: 0.4566197708, validation loss: 0.6173776333
# Epoch 286: train loss: 0.4576139634, validation loss: 0.6140576392
# Epoch 287: train loss: 0.4556103132, validation loss: 0.6139511584
# Epoch 288: train loss: 0.4555903595, validation loss: 0.6073131863
# Epoch 289: train loss: 0.4543505105, validation loss: 0.6106994368
# Epoch 290: train loss: 0.4535639244, validation loss: 0.6065925680
# Epoch 291: train loss: 0.4524238145, validation loss: 0.6057723100
# Epoch 292: train loss: 0.4515122214, validation loss: 0.6148225703
# Epoch 293: train loss: 0.4516916542, validation loss: 0.6038542561
# Epoch 294: train loss: 0.4510691721, validation loss: 0.6087393060
# Epoch 295: train loss: 0.4493537908, validation loss: 0.6017035048
# Epoch 296: train loss: 0.4483001987, validation loss: 0.6008683491
# Epoch 297: train loss: 0.4478247698, validation loss: 0.5990715350
# Epoch 298: train loss: 0.4460907829, validation loss: 0.6005478399
# Epoch 299: train loss: 0.4468124948, validation loss: 0.5984728154
# Epoch 300: train loss: 0.4444308743, validation loss: 0.6003020749
# Epoch 301: train loss: 0.4446253549, validation loss: 0.6037716095
# Epoch 302: train loss: 0.4440509148, validation loss: 0.5970873136
# Epoch 303: train loss: 0.4433731877, validation loss: 0.5983641239
# Epoch 304: train loss: 0.4422241758, validation loss: 0.5963680051
# Epoch 305: train loss: 0.4418032421, validation loss: 0.5958210221
# Epoch 306: train loss: 0.4411099226, validation loss: 0.5952708450
# Epoch 307: train loss: 0.4395258182, validation loss: 0.5913702662
# Epoch 308: train loss: 0.4398770622, validation loss: 0.5904410447
# Epoch 309: train loss: 0.4389226568, validation loss: 0.5868334654
# Epoch 310: train loss: 0.4377272369, validation loss: 0.5911612524
# Epoch 311: train loss: 0.4371895144, validation loss: 0.5859801054
# Epoch 312: train loss: 0.4361626892, validation loss: 0.5846020874
# Epoch 313: train loss: 0.4351697116, validation loss: 0.5869989171
# Epoch 314: train loss: 0.4348824421, validation loss: 0.5854881299
# Epoch 315: train loss: 0.4336931515, validation loss: 0.5863054129
# Epoch 316: train loss: 0.4335153846, validation loss: 0.5853013630
# Epoch 317: train loss: 0.4324400350, validation loss: 0.5794836457
# Epoch 318: train loss: 0.4313630916, validation loss: 0.5804729293
# Epoch 319: train loss: 0.4309711139, validation loss: 0.5801379293
# Epoch 320: train loss: 0.4314071633, validation loss: 0.5790517899
# Epoch 321: train loss: 0.4298712378, validation loss: 0.5765793577
# Epoch 322: train loss: 0.4287233918, validation loss: 0.5772816853
# Epoch 323: train loss: 0.4268354344, validation loss: 0.5801512100
# Epoch 324: train loss: 0.4275747712, validation loss: 0.5719759635
# Epoch 325: train loss: 0.4251198544, validation loss: 0.5757227391
# Epoch 326: train loss: 0.4256571040, validation loss: 0.5694710742
# Epoch 327: train loss: 0.4250701735, validation loss: 0.5714596985
# Epoch 328: train loss: 0.4245778783, validation loss: 0.5703806692
# Epoch 329: train loss: 0.4235303295, validation loss: 0.5734427822
# Epoch 330: train loss: 0.4220439928, validation loss: 0.5695856066
# Epoch 331: train loss: 0.4219288266, validation loss: 0.5656885594
# Epoch 332: train loss: 0.4206485506, validation loss: 0.5678857965
# Epoch 333: train loss: 0.4199115136, validation loss: 0.5649408952
# Epoch 334: train loss: 0.4197001111, validation loss: 0.5626671750
# Epoch 335: train loss: 0.4185180529, validation loss: 0.5644582464
# Epoch 336: train loss: 0.4177981479, validation loss: 0.5601842667
# Epoch 337: train loss: 0.4157003164, validation loss: 0.5624934609
# Epoch 338: train loss: 0.4151126984, validation loss: 0.5649034033
# Epoch 339: train loss: 0.4166854588, validation loss: 0.5595257576
# Epoch 340: train loss: 0.4158505118, validation loss: 0.5565473497
# Epoch 341: train loss: 0.4135270795, validation loss: 0.5601864663
# Epoch 342: train loss: 0.4150138749, validation loss: 0.5559029157
# Epoch 343: train loss: 0.4132041630, validation loss: 0.5550303852
# Epoch 344: train loss: 0.4122669152, validation loss: 0.5571435188
# Epoch 345: train loss: 0.4110997289, validation loss: 0.5518638918
# Epoch 346: train loss: 0.4112967703, validation loss: 0.5545325145
# Epoch 347: train loss: 0.4103357478, validation loss: 0.5506999190
# Epoch 348: train loss: 0.4093918219, validation loss: 0.5578983642
# Epoch 349: train loss: 0.4094441902, validation loss: 0.5500618014
# Epoch 350: train loss: 0.4081923338, validation loss: 0.5476926299
# Epoch 351: train loss: 0.4070948965, validation loss: 0.5534865139
# Epoch 352: train loss: 0.4063661076, validation loss: 0.5455410980
# Epoch 353: train loss: 0.4065151311, validation loss: 0.5462603197
# Epoch 354: train loss: 0.4056304454, validation loss: 0.5458455625
# Epoch 355: train loss: 0.4035604189, validation loss: 0.5476625982
# Epoch 356: train loss: 0.4039209436, validation loss: 0.5444385755
# Epoch 357: train loss: 0.4035989824, validation loss: 0.5453290414
# Epoch 358: train loss: 0.4023348962, validation loss: 0.5444259065
# Epoch 359: train loss: 0.4012574043, validation loss: 0.5385019491
# Epoch 360: train loss: 0.4009887692, validation loss: 0.5409954480
# Epoch 361: train loss: 0.3995285886, validation loss: 0.5424053185
# Epoch 362: train loss: 0.4000649663, validation loss: 0.5426033940
# Epoch 363: train loss: 0.3994895652, validation loss: 0.5378683918
# Epoch 364: train loss: 0.3988993379, validation loss: 0.5361927718
# Epoch 365: train loss: 0.3981004341, validation loss: 0.5343685916
# Epoch 366: train loss: 0.3960406005, validation loss: 0.5334381214
# Epoch 367: train loss: 0.3970002610, validation loss: 0.5348634509
# Epoch 368: train loss: 0.3948472345, validation loss: 0.5389293200
# Epoch 369: train loss: 0.3955587289, validation loss: 0.5352404899
# Epoch 370: train loss: 0.3941169959, validation loss: 0.5313033316
# Epoch 371: train loss: 0.3922263666, validation loss: 0.5323413245
# Epoch 372: train loss: 0.3933788086, validation loss: 0.5302388630
# Epoch 373: train loss: 0.3915164072, validation loss: 0.5294862365
# Epoch 374: train loss: 0.3909823516, validation loss: 0.5279248771
# Epoch 375: train loss: 0.3908774419, validation loss: 0.5286130829
# Epoch 376: train loss: 0.3889312719, validation loss: 0.5270226030
# Epoch 377: train loss: 0.3889018608, validation loss: 0.5242885290
# Epoch 378: train loss: 0.3891105619, validation loss: 0.5249807583
# Epoch 379: train loss: 0.3879990944, validation loss: 0.5228853682
# Epoch 380: train loss: 0.3878469971, validation loss: 0.5233135563
# Epoch 381: train loss: 0.3855445096, validation loss: 0.5204242191
# Epoch 382: train loss: 0.3854250264, validation loss: 0.5253896058
# Epoch 383: train loss: 0.3847460112, validation loss: 0.5195137652
# Epoch 384: train loss: 0.3839304865, validation loss: 0.5224334717
# Epoch 385: train loss: 0.3841973402, validation loss: 0.5255785043
# Epoch 386: train loss: 0.3839779599, validation loss: 0.5159132188
# Epoch 387: train loss: 0.3819414717, validation loss: 0.5243993840
# Epoch 388: train loss: 0.3814885138, validation loss: 0.5159548638
# Epoch 389: train loss: 0.3807967389, validation loss: 0.5139964700
# Epoch 390: train loss: 0.3800016626, validation loss: 0.5151309938
# Epoch 391: train loss: 0.3800062935, validation loss: 0.5174634799
# Epoch 392: train loss: 0.3790460628, validation loss: 0.5164068634
# Epoch 393: train loss: 0.3783167389, validation loss: 0.5174198056
# Epoch 394: train loss: 0.3799138697, validation loss: 0.5123709995
# Epoch 395: train loss: 0.3766404498, validation loss: 0.5109028953
# Epoch 396: train loss: 0.3765709361, validation loss: 0.5121144397
# Epoch 397: train loss: 0.3752748852, validation loss: 0.5120887996
# Epoch 398: train loss: 0.3751573076, validation loss: 0.5063511071
# Epoch 399: train loss: 0.3746745468, validation loss: 0.5062156458
# Epoch 400: train loss: 0.3732663821, validation loss: 0.5077017744
# Epoch 401: train loss: 0.3730183471, validation loss: 0.5057819958
# Epoch 402: train loss: 0.3728114753, validation loss: 0.5078833791
# Epoch 403: train loss: 0.3724140789, validation loss: 0.5039854652
# Epoch 404: train loss: 0.3718830336, validation loss: 0.5062645672
# Epoch 405: train loss: 0.3707323936, validation loss: 0.5013681444
# Epoch 406: train loss: 0.3692817167, validation loss: 0.5060720836
# Epoch 407: train loss: 0.3686387520, validation loss: 0.5009108533
# Epoch 408: train loss: 0.3691049095, validation loss: 0.4974879401
# Epoch 409: train loss: 0.3683464591, validation loss: 0.4968349108
# Epoch 410: train loss: 0.3675029808, validation loss: 0.5040177776
# Epoch 411: train loss: 0.3667080307, validation loss: 0.4952010033
# Epoch 412: train loss: 0.3649605373, validation loss: 0.4973099096
# Epoch 413: train loss: 0.3650765674, validation loss: 0.4959760630
# Epoch 414: train loss: 0.3653653184, validation loss: 0.4955852765
# Epoch 415: train loss: 0.3632344645, validation loss: 0.4964758306
# Epoch 416: train loss: 0.3642618546, validation loss: 0.4983986549
# Epoch 417: train loss: 0.3643630810, validation loss: 0.4921389708
# Epoch 418: train loss: 0.3624264723, validation loss: 0.4888523474
# Epoch 419: train loss: 0.3618640376, validation loss: 0.4899241404
# Epoch 420: train loss: 0.3616231287, validation loss: 0.4923296911
# Epoch 421: train loss: 0.3616061077, validation loss: 0.4868311850
# Epoch 422: train loss: 0.3600883174, validation loss: 0.4906366171
# Epoch 423: train loss: 0.3594879646, validation loss: 0.4878961889
# Epoch 424: train loss: 0.3589075793, validation loss: 0.4907308523
# Epoch 425: train loss: 0.3582560593, validation loss: 0.4835208242
# Epoch 426: train loss: 0.3576447521, validation loss: 0.4893880775
# Epoch 427: train loss: 0.3559408967, validation loss: 0.4875131095
# Epoch 428: train loss: 0.3576179903, validation loss: 0.4835655661
# Epoch 429: train loss: 0.3548633576, validation loss: 0.4859193549
# Epoch 430: train loss: 0.3555427501, validation loss: 0.4852805026
# Epoch 431: train loss: 0.3549534982, validation loss: 0.4889535457
# Epoch 432: train loss: 0.3543455641, validation loss: 0.4874725620
# Epoch 433: train loss: 0.3543087697, validation loss: 0.4851237533
# Epoch 434: train loss: 0.3532148329, validation loss: 0.4789069211
# Epoch 435: train loss: 0.3529761648, validation loss: 0.4778534519
# Epoch 436: train loss: 0.3517504745, validation loss: 0.4830304677
# Epoch 437: train loss: 0.3509973401, validation loss: 0.4811540941
# Epoch 438: train loss: 0.3502405723, validation loss: 0.4756188062
# Epoch 439: train loss: 0.3493975723, validation loss: 0.4770190060
# Epoch 440: train loss: 0.3490533902, validation loss: 0.4757189619
# Epoch 441: train loss: 0.3492382173, validation loss: 0.4755553411
# Epoch 442: train loss: 0.3472465304, validation loss: 0.4761189854
# Epoch 443: train loss: 0.3471109207, validation loss: 0.4759563310
# Epoch 444: train loss: 0.3472455994, validation loss: 0.4714677182
# Epoch 445: train loss: 0.3460989189, validation loss: 0.4717876860
# Epoch 446: train loss: 0.3453996516, validation loss: 0.4851189760
# Epoch 447: train loss: 0.3475350403, validation loss: 0.4692911168
# Epoch 448: train loss: 0.3434464846, validation loss: 0.4721993365
# Epoch 449: train loss: 0.3439574582, validation loss: 0.4683676737
# Epoch 450: train loss: 0.3427058196, validation loss: 0.4667314684
# Epoch 451: train loss: 0.3440887750, validation loss: 0.4657877145
# Epoch 452: train loss: 0.3430744730, validation loss: 0.4672410108
# Epoch 453: train loss: 0.3410727389, validation loss: 0.4724262585
# Epoch 454: train loss: 0.3420940150, validation loss: 0.4623015822
# Epoch 455: train loss: 0.3410105173, validation loss: 0.4625380290
# Epoch 456: train loss: 0.3403696825, validation loss: 0.4631269431
# Epoch 457: train loss: 0.3385659278, validation loss: 0.4641346186
# Epoch 458: train loss: 0.3391346753, validation loss: 0.4678724115
# Epoch 459: train loss: 0.3378780850, validation loss: 0.4603070995
# Epoch 460: train loss: 0.3378364895, validation loss: 0.4592177572
# Epoch 461: train loss: 0.3387684240, validation loss: 0.4605142552
# Epoch 462: train loss: 0.3363136493, validation loss: 0.4640010761
# Epoch 463: train loss: 0.3355226994, validation loss: 0.4591889434
# Epoch 464: train loss: 0.3357044325, validation loss: 0.4591803544
# Epoch 465: train loss: 0.3353282397, validation loss: 0.4655206274
# Epoch 466: train loss: 0.3350680177, validation loss: 0.4575262136
# Epoch 467: train loss: 0.3344841204, validation loss: 0.4585671107
# Epoch 468: train loss: 0.3340161921, validation loss: 0.4554810217
# Epoch 469: train loss: 0.3336373766, validation loss: 0.4555305542
# Epoch 470: train loss: 0.3321106797, validation loss: 0.4543939060
# Epoch 471: train loss: 0.3310151546, validation loss: 0.4515091906
# Epoch 472: train loss: 0.3316373492, validation loss: 0.4547865923
# Epoch 473: train loss: 0.3310570349, validation loss: 0.4522207939
# Epoch 474: train loss: 0.3303203208, validation loss: 0.4635236542
# Epoch 475: train loss: 0.3297381114, validation loss: 0.4490843760
# Epoch 476: train loss: 0.3289784262, validation loss: 0.4476251445
# Epoch 477: train loss: 0.3275949500, validation loss: 0.4491824347
# Epoch 478: train loss: 0.3271779158, validation loss: 0.4531280191
# Epoch 479: train loss: 0.3281137696, validation loss: 0.4502363471
# Epoch 480: train loss: 0.3274998756, validation loss: 0.4440239747
# Epoch 481: train loss: 0.3273697021, validation loss: 0.4457853915
# Epoch 482: train loss: 0.3254586831, validation loss: 0.4538652053
# Epoch 483: train loss: 0.3262532031, validation loss: 0.4500511200
# Epoch 484: train loss: 0.3247111091, validation loss: 0.4490788875
# Epoch 485: train loss: 0.3243440270, validation loss: 0.4472173172
# Epoch 486: train loss: 0.3240620261, validation loss: 0.4455198211
# Epoch 487: train loss: 0.3232296508, validation loss: 0.4468265798
# Epoch 488: train loss: 0.3218760673, validation loss: 0.4444119328
# Epoch 489: train loss: 0.3222212953, validation loss: 0.4385007837
# Epoch 490: train loss: 0.3215600774, validation loss: 0.4416734475
# Epoch 491: train loss: 0.3228367960, validation loss: 0.4406552928
# Epoch 492: train loss: 0.3220132779, validation loss: 0.4405162335
# Epoch 493: train loss: 0.3201948227, validation loss: 0.4372134932
# Epoch 494: train loss: 0.3195891694, validation loss: 0.4434351880
# Epoch 495: train loss: 0.3190504517, validation loss: 0.4411866178
# Epoch 496: train loss: 0.3191379206, validation loss: 0.4422427579
# Epoch 497: train loss: 0.3187507273, validation loss: 0.4409226638
# Epoch 498: train loss: 0.3179814102, validation loss: 0.4485425662
# Epoch 499: train loss: 0.3176044057, validation loss: 0.4365247977
# Epoch 500: train loss: 0.3164093721, validation loss: 0.4363564221
# Finished Training
# stable spectral radius = 0.9990003
# A, B, C shapes: (23, 23) (23, 2) (6, 23)
# spectral radius = 1.0024564
# eigvals = [0.76654154+3.0787662e-01j 0.76654154-3.0787662e-01j
#  0.87597597+1.7616147e-01j 0.87597597-1.7616147e-01j
#  0.84049624+6.5213129e-02j 0.84049624-6.5213129e-02j
#  0.9513859 +0.0000000e+00j 0.9846085 +3.9029052e-03j
#  0.9846085 -3.9029052e-03j 0.999047  +5.9596375e-03j
#  0.999047  -5.9596375e-03j 0.997254  +1.7641593e-03j
#  0.997254  -1.7641593e-03j 1.002456  +9.5821585e-04j
#  1.002456  -9.5821585e-04j 1.0021323 +4.3448980e-04j
#  1.0021323 -4.3448980e-04j 0.9993632 +1.2210496e-04j
#  0.9993632 -1.2210496e-04j 1.0004145 +0.0000000e+00j
#  0.99993575+1.1704522e-04j 0.99993575-1.1704522e-04j
#  1.        +0.0000000e+00j]
# x_unchanged_scaled shape: (99, 6)
# u_scaled shape: (99, 2)
# x_changed_scaled shape: (99, 6)
# x_changed_prime_scaled shape: (99, 6)

# %%
# =============================================================================
# Testing - 100m Double Lane Change Baseline
# =============================================================================

# =========================
# Reference path generation
# =========================
path_length = 100.0

vx_nom = 3.0
T_traj = path_length / vx_nom
t_ref = np.arange(0, T_traj + dt, dt)
traj_length = t_ref.size
x_path = vx_nom * t_ref

A1 = 0.4
A2 = -0.4
x1 = 30.0
x2 = 70.0
sigma1 = 16.0
sigma2 = 16.0

y_ref_path = (
        A1 * np.exp(-0.5 * ((x_path - x1) / sigma1) ** 2)
        + A2 * np.exp(-0.5 * ((x_path - x2) / sigma2) ** 2)
)

s_ref_path, psi_ref_path, curvature_ref_path = build_test_frenet_path_from_xy(
    x_path, y_ref_path
)

x_ref_raw = np.zeros((num_states, traj_length))
x_ref_raw[0, :] = s_ref_path
x_ref_raw[1, :] = 0.0
x_ref_raw[2, :] = 0.0
x_ref_raw[3, :] = vx_nom
x_ref_raw[4, :] = 0.0
x_ref_raw[5, :] = vx_nom * curvature_ref_path

x_ref_scaled = standardizer_x_kdnn.transform(x_ref_raw.T).T

plt.figure(figsize=(18, 12))
plt.subplot(3, 1, 1)
plt.plot(x_path, y_ref_path)
plt.ylabel("y_ref [m]")
plt.title("Reference Path")

plt.subplot(3, 1, 2)
plt.plot(t_ref, psi_ref_path)
plt.ylabel("psi_ref [rad]")

plt.subplot(3, 1, 3)
plt.plot(t_ref, curvature_ref_path)
plt.ylabel("kappa_ref [1/m]")
plt.xlabel("t [s]")
plt.tight_layout()
plt.show()

# =========================
# Solver settings
# =========================
solver_settings = {}
solver_settings["gen_embedded_ctrl"] = False
solver_settings["warm_start"] = True
solver_settings["polish"] = True
solver_settings["polish_refine_iter"] = 5
solver_settings["scaling"] = True
solver_settings["adaptive_rho"] = True
solver_settings["check_termination"] = 25
solver_settings["max_iter"] = 30000
solver_settings["eps_abs"] = 5e-4
solver_settings["eps_rel"] = 5e-4
solver_settings["eps_prim_inf"] = 1e-3
solver_settings["eps_dual_inf"] = 1e-3

# =========================
# MPC horizon / ref preview
# =========================
N_lin_noadapt = 80
max_iter_lin = 5

x_ref_mpc = np.hstack((
    x_ref_scaled,
    np.tile(x_ref_scaled[:, -1].reshape(-1, 1), N_lin_noadapt + 2)
))

# =========================
# 【调整】等效放大的 MPC 权重
# =========================
# 因为上面通过数据增强放大了 e_y 和 e_psi 的真实分布方差，
# 导致 Standardizer 放缩后，相同的缩放单位代表了更为巨大的物理误差。
# 为保证在缩放空间 (Scaled Space) 中仍具备同样强势的轨迹贴合度，必须大幅调高侧偏相关项的惩罚！


##====================== 权重 ======================
# Q_mpc_lin_noadapt = scipy.sparse.diags([
#     0.0,  # s
#     1800.0,  # e_y (原为 60.0，等效放大)
#     600.0,  # e_psi (原为 20.0)
#     8.0,  # v_x
#     1.0,  # v_y
#     1.0  # r
# ])
#
# QN_mpc_lin_noadapt = scipy.sparse.diags([
#     0.0,  # s
#     2500.0,  # e_y (原为 80.0)
#     1200.0,  # e_psi (原为 30.0)
#     10.0,  # v_x
#     1.0,  # v_y
#     1.0  # r
# ])
#
# R_mpc_lin_noadapt = scipy.sparse.diags([
#     120.0,  # delta (原为 30.0)
#     12.0  # a_x (原为 8.0)
# ])

# =========================
# Relaxed raw bounds -> scaled bounds
# =========================
xmin_raw = np.array([-10.0, -5.0, -1.2, 0.5, -4.0, -3.0])
xmax_raw = np.array([500.0, 5.0, 1.2, 8.0, 4.0, 3.0])

xmin_lin_noadapt = standardizer_x_kdnn.transform(xmin_raw.reshape(1, -1)).flatten()
xmax_lin_noadapt = standardizer_x_kdnn.transform(xmax_raw.reshape(1, -1)).flatten()

umax_lin_noadapt = np.array([0.08, 1.0])
umin_lin_noadapt = -umax_lin_noadapt

# =========================
# Closed-loop arrays in raw space
# =========================
xt_actual_lin_noadapt = np.zeros((traj_length, num_states))
xt_actual_lin_noadapt[0, :] = np.array([0.0, 0.0, 0.0, vx_nom, 0.0, 0.0])

u_lin_noadapt = np.zeros((traj_length - 1, num_inputs))

z_lin_noadapt = np.zeros((traj_length, n_obs_lin))
n_lift = A_lin.shape[0]

# =========================
# Initial guesses
# =========================
x_init_lin_noadapt_raw = np.tile(xt_actual_lin_noadapt[0, :], (N_lin_noadapt + 1, 1))
u_init_lin_noadapt = np.zeros((N_lin_noadapt, num_inputs))
z_init_lin_noadapt = np.zeros((N_lin_noadapt + 1, n_lift))

for ii in range(N_lin_noadapt + 1):
    xii_scaled = scale_state(x_init_lin_noadapt_raw[ii, :], standardizer_x_kdnn)
    z_init_lin_noadapt[ii, :] = lift_scaled(
        xii_scaled, model_koop_dnn_lin, net_params_lin
    )
# =========================
# Controller
# =========================
linear_model_no_adapt = linear_Dynamics(
    scipy.sparse.csc_matrix(A_lin_stable),
    scipy.sparse.csc_matrix(B_lin),
    C_lin
)

# 使用基础权重初始化控制器（后面会动态覆盖）
controller_nmpc_lin_noadapt = NonlinearMPCController(
    linear_model_no_adapt,
    N_lin_noadapt, dt, umin_lin_noadapt, umax_lin_noadapt,
    xmin_lin_noadapt, xmax_lin_noadapt,
    Q_base_lin, R_mpc_lin_noadapt, QN_base_lin,   # 保持原样
    solver_settings
)

# controller_nmpc_lin_noadapt = NonlinearMPCController(
#     linear_model_no_adapt,
#     N_lin_noadapt, dt, umin_lin_noadapt, umax_lin_noadapt,
#     xmin_lin_noadapt, xmax_lin_noadapt,
#     Q_base_lin,          # ← 改这里
#     R_mpc_lin_noadapt,
#     QN_base_lin,         # ← 改这里
#     solver_settings
# )

controller_nmpc_lin_noadapt.construct_controller(
    z_init_lin_noadapt, u_init_lin_noadapt, x_ref_scaled[:, 0]
)
# # =========================
# # Controller
# # =========================
# linear_model_no_adapt = linear_Dynamics(
#     scipy.sparse.csc_matrix(A_lin_stable),
#     scipy.sparse.csc_matrix(B_lin),
#     C_lin
# )
#
# controller_nmpc_lin_noadapt = NonlinearMPCController(
#     linear_model_no_adapt,
#     N_lin_noadapt, dt, umin_lin_noadapt, umax_lin_noadapt,
#     xmin_lin_noadapt, xmax_lin_noadapt,
#     Q_mpc_lin_noadapt, R_mpc_lin_noadapt, QN_mpc_lin_noadapt,
#     solver_settings
# )
#
# controller_nmpc_lin_noadapt.construct_controller(
#     z_init_lin_noadapt, u_init_lin_noadapt, x_ref_scaled[:, 0]
# )
# ====================== 新增：权重自适应模块 ======================
# ====================== 权重自适应模块（已修复）======================
# def adaptive_mpc_weights(error_ey, error_epsi, base_Q, base_QN, base_R,
#                          ey_scale=0.8, epsi_scale=0.9,
#                          max_mult=2.8, min_mult=0.85):
#     """
#     温和自适应版 + 轻微 R 自适应（误差大时允许更大控制动作）
#     """
#     ey_norm = min(abs(error_ey) / 1.8, 1.0)
#     epsi_norm = min(abs(error_epsi) / 0.7, 1.0)
#
#     mult_ey = 1.0 + (max_mult - 1.0) * (ey_norm ** 1.1)   # 非常柔和
#     mult_epsi = 1.0 + (max_mult - 1.0) * (epsi_norm ** 1.1)
#
#     mult_ey = np.clip(mult_ey * ey_scale, min_mult, max_mult)
#     mult_epsi = np.clip(mult_epsi * epsi_scale, min_mult, max_mult)
#
#     # Q / QN 自适应
#     Q_diag = base_Q.diagonal().copy()
#     QN_diag = base_QN.diagonal().copy()
#
#     Q_diag[1] *= mult_ey
#     Q_diag[2] *= mult_epsi
#     QN_diag[1] *= mult_ey * 1.25
#     QN_diag[2] *= mult_epsi * 1.25
#
#     Q_adapt = scipy.sparse.diags(Q_diag, offsets=0, format='dia')
#     QN_adapt = scipy.sparse.diags(QN_diag, offsets=0, format='dia')
#
#     # R 轻微自适应（误差大时降低 R，让控制更主动）
#     R_diag = base_R.diagonal().copy()
#     mult_r = 1.0 - 0.25 * (max(mult_ey, mult_epsi) - 1.0)   # 最多降低25%
#     R_diag = R_diag * np.clip(mult_r, 0.75, 1.0)
#
#     R_adapt = scipy.sparse.diags(R_diag, offsets=0, format='dia')
#
#     return Q_adapt, QN_adapt, R_adapt

def adaptive_mpc_weights(error_ey, error_epsi, base_Q, base_QN, base_R,
                         ey_scale=0.8, epsi_scale=0.9,
                         max_mult=2.8, min_mult=0.85):
    ey_norm   = min(abs(error_ey)   / 1.8, 1.0)
    epsi_norm = min(abs(error_epsi) / 0.7, 1.0)

    mult_ey   = 1.0 + (max_mult - 1.0) * (ey_norm   ** 1.1)
    mult_epsi = 1.0 + (max_mult - 1.0) * (epsi_norm ** 1.1)

    mult_ey   = np.clip(mult_ey   * ey_scale,   min_mult, max_mult)
    mult_epsi = np.clip(mult_epsi * epsi_scale,  min_mult, max_mult)

    Q_diag  = base_Q.diagonal().copy()
    QN_diag = base_QN.diagonal().copy()

    Q_diag[1]  *= mult_ey
    Q_diag[2]  *= mult_epsi
    QN_diag[1] *= mult_ey   * 1.25
    QN_diag[2] *= mult_epsi * 1.25

    Q_adapt  = scipy.sparse.diags(Q_diag,  offsets=0, format='dia')
    QN_adapt = scipy.sparse.diags(QN_diag, offsets=0, format='dia')

    # R 轻微自适应（误差大时降低 R，让控制更主动）
    R_diag  = base_R.diagonal().copy()
    mult_r  = 1.0 - 0.25 * (max(mult_ey, mult_epsi) - 1.0)
    R_diag  = R_diag * np.clip(mult_r, 0.75, 1.0)
    R_adapt = scipy.sparse.diags(R_diag, offsets=0, format='dia')

    return Q_adapt, QN_adapt, R_adapt
# def adaptive_mpc_weights(error_ey, error_epsi, base_Q, base_QN,
#                          ey_scale=1.0, epsi_scale=1.2,
#                          max_mult=12.0, min_mult=0.6):
#     """
#     根据当前横向误差动态调整Q和QN中 e_y / e_psi 的权重
#     """
#     # 归一化误差（基于物理合理范围）
#     ey_norm = min(abs(error_ey) / 2.0, 1.0)
#     epsi_norm = min(abs(error_epsi) / 0.8, 1.0)
#
#     # 计算乘数（误差越大，权重越大，非线性放大）
#     mult_ey = 1.0 + (max_mult - 1.0) * (ey_norm ** 1.2)
#     mult_epsi = 1.0 + (max_mult - 1.0) * (epsi_norm ** 1.2)
#
#     # 限制范围
#     mult_ey = np.clip(mult_ey * ey_scale, min_mult, max_mult)
#     mult_epsi = np.clip(mult_epsi * epsi_scale, min_mult, max_mult)
#
#     # ==================== 核心修复部分 ====================
#     # 把稀疏矩阵转为对角线数组，更安全地重建
#     Q_diag = base_Q.diagonal().copy()      # 提取原始对角线值
#     QN_diag = base_QN.diagonal().copy()
#
#     # 只修改 e_y (索引1) 和 e_psi (索引2)
#     Q_diag[1] *= mult_ey
#     Q_diag[2] *= mult_epsi
#     QN_diag[1] *= mult_ey * 1.4
#     QN_diag[2] *= mult_epsi * 1.4
#
#     # 重新构造稀疏对角矩阵（推荐写法）
#     Q_adapt = scipy.sparse.diags(Q_diag, offsets=0, format='dia')
#     QN_adapt = scipy.sparse.diags(QN_diag, offsets=0, format='dia')
#
#     return Q_adapt, QN_adapt


# ====================== 使用示例：准备基础权重 ======================
# 把你原来的固定权重改成“基础权重”
Q_base_lin = scipy.sparse.diags([
    0.0,   # s
    1800.0,  # e_y base
    600.0,   # e_psi base
    8.0,     # v_x
    1.0,     # v_y
    1.0      # r
])

QN_base_lin = scipy.sparse.diags([
    0.0,
    2500.0,
    1200.0,
    10.0,
    1.0,
    1.0
])

R_mpc_lin_noadapt = scipy.sparse.diags([120.0, 12.0])  # R通常不自适应

# # =========================
# # Closed-loop simulation
# # =========================
# delta_alpha = 0.6
# ax_alpha = 0.50
#
# sys_pars_ctrl = dict(sys_pars_new)
# sys_pars_ctrl["vx_ref"] = vx_nom
# sys_pars_ctrl["uncertainty"] = "NA"
# sys_pars_ctrl["amp"] = 0.0
# sys_pars_ctrl["freq"] = 1.0
# sys_pars_ctrl["s_ref"] = s_ref_path
# sys_pars_ctrl["curvature_ref"] = curvature_ref_path
#
#
# begin_linear_noadapt = time.time()
# time_excess = 0.0
# fail_count = 0
# nonfinite_count = 0
# terminated_early = False
#
# for k in range(traj_length - 1):
#     xk_raw = xt_actual_lin_noadapt[k, :].copy()
#
#     # -------------------------------------------------
#     # 0) 进入缩放前做保护
#     # -------------------------------------------------
#     if not is_finite_vector(xk_raw):
#         print(f"[STOP] Non-finite state before scaling at step {k}")
#         print("xk_raw =", xk_raw)
#         terminated_early = True
#         break
#
#     xk_raw = clip_closed_loop_state(xk_raw, s_upper=500.0)
#     xt_actual_lin_noadapt[k, :] = xk_raw
#
#         # ==================== 新增：自适应权重计算 ====================
#     # current_ey = xt_actual_lin_noadapt[k, 1]
#     # current_epsi = xt_actual_lin_noadapt[k, 2]
#     current_ey = xt_actual_lin_noadapt[k, 1]
#     current_epsi = xt_actual_lin_noadapt[k, 2]
#
#     if abs(current_ey) > 0.05 or abs(current_epsi) > 0.03:
#         Q_mpc_adapt, QN_mpc_adapt = adaptive_mpc_weights(...)
#     else:
#         Q_mpc_adapt = Q_base_lin
#         QN_mpc_adapt = QN_base_lin
#
#     controller_nmpc_lin_noadapt.Q = Q_mpc_adapt
#     controller_nmpc_lin_noadapt.QN = QN_mpc_adapt
#
#     Q_mpc_adapt, QN_mpc_adapt = adaptive_mpc_weights(
#         error_ey=current_ey,
#         error_epsi=current_epsi,
#         base_Q=Q_base_lin,
#         base_QN=QN_base_lin,
#         ey_scale=0.6,      # 你可以调这个系数进一步放大侧向惩罚
#         epsi_scale=0.8,
#         max_mult=3.5,     # 最大允许放大到12倍
#         min_mult=0.7
#     )
#
#     # ==================== 更新控制器权重 ====================
#     controller_nmpc_lin_noadapt.Q = Q_mpc_adapt
#     controller_nmpc_lin_noadapt.QN = QN_mpc_adapt
#     # R一般保持固定，也可以做轻微自适应
#
#     try:
#         xk_scaled = scale_state(xk_raw, standardizer_x_kdnn)
#     except Exception as e:
#         print(f"[STOP] scale_state failed at step {k}: {e}")
#         print("xk_raw =", xk_raw)
#         terminated_early = True
#         break
#
#     if not is_finite_vector(xk_scaled):
#         print(f"[STOP] Non-finite scaled state at step {k}")
#         print("xk_raw =", xk_raw)
#         print("xk_scaled =", xk_scaled)
#         terminated_early = True
#         break
#
#     # -------------------------------------------------
#     # 1) 提升到 Koopman 空间
#     # -------------------------------------------------
#     try:
#         z_lin_noadapt[k, :] = lift_scaled(
#             xk_scaled, model_koop_dnn_lin, net_params_lin
#         )
#     except Exception as e:
#         print(f"[STOP] lift_scaled failed at step {k}: {e}")
#         print("xk_scaled =", xk_scaled)
#         terminated_early = True
#         break
#
#     if not is_finite_vector(z_lin_noadapt[k, :]):
#         print(f"[STOP] Non-finite lifted state at step {k}")
#         print("z =", z_lin_noadapt[k, :])
#         terminated_early = True
#         break
#
#     # -------------------------------------------------
#     # 2) 取参考窗口
#     # -------------------------------------------------
#     xref_win = x_ref_mpc[:, k + 1:k + N_lin_noadapt + 2]
#
#     # -------------------------------------------------
#     # 3) 求解 MPC
#     # -------------------------------------------------
#     mpc_ok = True
#     try:
#         controller_nmpc_lin_noadapt.solve_to_convergence(
#             xref_win,
#             z_lin_noadapt[k, :],
#             controller_nmpc_lin_noadapt.z_init,
#             controller_nmpc_lin_noadapt.u_init,
#             max_iter=max_iter_lin,
#             eps=1e-3
#         )
#         controller_nmpc_lin_noadapt.update_initial_guess_()
#
#         delta_fb_mpc = float(controller_nmpc_lin_noadapt.cur_u[0, 0])
#         ax_cmd = float(controller_nmpc_lin_noadapt.cur_u[0, 1])
#
#         if not np.isfinite(delta_fb_mpc) or not np.isfinite(ax_cmd):
#             raise ValueError("MPC returned non-finite control")
#     except Exception as e:
#         fail_count += 1
#         mpc_ok = False
#         print(f"[WARN] MPC fallback at step {k}: {e}")
#
#         if k > 0:
#             delta_fb_mpc = float(u_lin_noadapt[k - 1, 0])
#             ax_cmd = float(u_lin_noadapt[k - 1, 1])
#         else:
#             delta_fb_mpc = 0.0
#             ax_cmd = 0.0
#
#     # -------------------------------------------------
#     # 4) 前馈 + 裁剪
#     # -------------------------------------------------
#     ff_gain = 0.8
#     delta_ff = ff_gain * (sys_pars["lf"] + sys_pars["lr"]) * curvature_ref_path[k]
#     delta_cmd_raw = delta_fb_mpc + delta_ff
#
#     delta_cmd_raw = np.clip(delta_cmd_raw, umin_lin_noadapt[0], umax_lin_noadapt[0])
#     ax_cmd = np.clip(ax_cmd, umin_lin_noadapt[1], umax_lin_noadapt[1])
#
#     # -------------------------------------------------
#     # 5) 输入平滑
#     # -------------------------------------------------
#     if k == 0:
#         delta_applied = delta_cmd_raw
#         ax_applied = ax_cmd
#     else:
#         delta_applied = delta_alpha * u_lin_noadapt[k - 1, 0] + (1.0 - delta_alpha) * delta_cmd_raw
#         ax_applied = ax_alpha * u_lin_noadapt[k - 1, 1] + (1.0 - ax_alpha) * ax_cmd
#
#     delta_applied = np.clip(delta_applied, umin_lin_noadapt[0], umax_lin_noadapt[0])
#     ax_applied = np.clip(ax_applied, umin_lin_noadapt[1], umax_lin_noadapt[1])
#
#     # 末端冻结几步，避免终点附近乱抖
#     if k >= traj_length - 5 and k > 0:
#         u_lin_noadapt[k, :] = u_lin_noadapt[k - 1, :]
#     else:
#         u_lin_noadapt[k, 0] = delta_applied
#         u_lin_noadapt[k, 1] = ax_applied
#
#     # -------------------------------------------------
#     # 6) 推进一步真实系统（安全版本）
#     # -------------------------------------------------
#     t1 = time.time()
#
#     if k > 0:
#         fallback_state = xt_actual_lin_noadapt[k, :].copy()
#     else:
#         fallback_state = np.array([0.0, 0.0, 0.0, vx_nom, 0.0, 0.0], dtype=float)
#
#     x_next = safe_FK_step(
#         xt_actual_lin_noadapt[k, :],
#         u_lin_noadapt[k, :],
#         sys_pars_ctrl,
#         SNR_DB=SNR_DB,
#         i=k,
#         fallback_state=fallback_state,
#         verbose=True
#     )
#
#     t2 = time.time()
#     time_excess += (t2 - t1)
#
#     if not is_finite_vector(x_next):
#         nonfinite_count += 1
#         print(f"[STOP] x_next still non-finite at step {k}")
#         print("x_now =", xt_actual_lin_noadapt[k, :])
#         print("u_now =", u_lin_noadapt[k, :])
#         terminated_early = True
#         break
#
#     xt_actual_lin_noadapt[k + 1, :] = x_next
#
# end_linear_noadapt = time.time()
#
# effective_steps = max(1, np.sum(np.any(np.abs(u_lin_noadapt) > 0, axis=1)))
# time_linear_noadapt = (end_linear_noadapt - begin_linear_noadapt - time_excess) / max(1, traj_length - 1)
#
# print("Average MPC solve time per step =", time_linear_noadapt)
# print("Total MPC failures =", fail_count)
# print("Total non-finite next-state events =", nonfinite_count)
# print("Terminated early =", terminated_early)


# =========================
# Closed-loop simulation
# =========================
delta_alpha = 0.6
ax_alpha = 0.50

sys_pars_ctrl = dict(sys_pars_new)
sys_pars_ctrl["vx_ref"] = vx_nom
sys_pars_ctrl["uncertainty"] = "NA"
sys_pars_ctrl["amp"] = 0.0
sys_pars_ctrl["freq"] = 1.0
sys_pars_ctrl["s_ref"] = s_ref_path
sys_pars_ctrl["curvature_ref"] = curvature_ref_path

begin_linear_noadapt = time.time()
time_excess = 0.0
fail_count = 0
nonfinite_count = 0
terminated_early = False

for k in range(traj_length - 1):
    xk_raw = xt_actual_lin_noadapt[k, :].copy()

    if not is_finite_vector(xk_raw):
        print(f"[STOP] Non-finite state before scaling at step {k}")
        print("xk_raw =", xk_raw)
        terminated_early = True
        break

    xk_raw = clip_closed_loop_state(xk_raw, s_upper=500.0)
    xt_actual_lin_noadapt[k, :] = xk_raw

    # ==================== 自适应权重计算（本次重点调整） ====================
    current_ey = xt_actual_lin_noadapt[k, 1]
    current_epsi = xt_actual_lin_noadapt[k, 2]

    # 误差阈值放宽一点，让自适应更早介入
    if abs(current_ey) > 0.04 or abs(current_epsi) > 0.025:
        Q_mpc_adapt, QN_mpc_adapt, R_mpc_adapt = adaptive_mpc_weights(
            error_ey=current_ey,
            error_epsi=current_epsi,
            base_Q=Q_base_lin,
            base_QN=QN_base_lin,
            base_R=R_mpc_lin_noadapt,
            ey_scale=0.8,
            epsi_scale=0.9,
            max_mult=2.8,      # 这次调到5.0，动态范围更大
            min_mult=0.85
        )
    else:
        Q_mpc_adapt = Q_base_lin
        QN_mpc_adapt = QN_base_lin
        R_mpc_adapt  = R_mpc_lin_noadapt

    # 更新权重
    controller_nmpc_lin_noadapt.Q  = Q_mpc_adapt
    controller_nmpc_lin_noadapt.QN = QN_mpc_adapt
    controller_nmpc_lin_noadapt.R  = R_mpc_adapt
    # -------------------------------------------------
    # scale state
    # -------------------------------------------------
    try:
        xk_scaled = scale_state(xk_raw, standardizer_x_kdnn)
    except Exception as e:
        print(f"[STOP] scale_state failed at step {k}: {e}")
        print("xk_raw =", xk_raw)
        terminated_early = True
        break

    if not is_finite_vector(xk_scaled):
        print(f"[STOP] Non-finite scaled state at step {k}")
        print("xk_raw =", xk_raw)
        print("xk_scaled =", xk_scaled)
        terminated_early = True
        break

    # -------------------------------------------------
    # 1) 提升到 Koopman 空间
    # -------------------------------------------------
    try:
        z_lin_noadapt[k, :] = lift_scaled(
            xk_scaled, model_koop_dnn_lin, net_params_lin
        )
    except Exception as e:
        print(f"[STOP] lift_scaled failed at step {k}: {e}")
        print("xk_scaled =", xk_scaled)
        terminated_early = True
        break

    if not is_finite_vector(z_lin_noadapt[k, :]):
        print(f"[STOP] Non-finite lifted state at step {k}")
        print("z =", z_lin_noadapt[k, :])
        terminated_early = True
        break

    # -------------------------------------------------
    # 2) 取参考窗口
    # -------------------------------------------------
    xref_win = x_ref_mpc[:, k + 1:k + N_lin_noadapt + 2]

    # -------------------------------------------------
    # 3) 求解 MPC
    # -------------------------------------------------
    mpc_ok = True
    try:
        controller_nmpc_lin_noadapt.solve_to_convergence(
            xref_win,
            z_lin_noadapt[k, :],
            controller_nmpc_lin_noadapt.z_init,
            controller_nmpc_lin_noadapt.u_init,
            max_iter=max_iter_lin,
            eps=1e-3
        )
        controller_nmpc_lin_noadapt.update_initial_guess_()

        delta_fb_mpc = float(controller_nmpc_lin_noadapt.cur_u[0, 0])
        ax_cmd = float(controller_nmpc_lin_noadapt.cur_u[0, 1])

        if not np.isfinite(delta_fb_mpc) or not np.isfinite(ax_cmd):
            raise ValueError("MPC returned non-finite control")
    except Exception as e:
        fail_count += 1
        print(f"[WARN] MPC fallback at step {k}: {e}")

        if k > 0:
            delta_fb_mpc = float(u_lin_noadapt[k - 1, 0])
            ax_cmd = float(u_lin_noadapt[k - 1, 1])
        else:
            delta_fb_mpc = 0.0
            ax_cmd = 0.0

    # -------------------------------------------------
    # 4) 前馈 + 裁剪
    # -------------------------------------------------
    ff_gain = 0.8
    delta_ff = ff_gain * (sys_pars["lf"] + sys_pars["lr"]) * curvature_ref_path[k]
    delta_cmd_raw = delta_fb_mpc + delta_ff

    delta_cmd_raw = np.clip(delta_cmd_raw, umin_lin_noadapt[0], umax_lin_noadapt[0])
    ax_cmd = np.clip(ax_cmd, umin_lin_noadapt[1], umax_lin_noadapt[1])

    # -------------------------------------------------
    # 5) 输入平滑
    # -------------------------------------------------
    if k == 0:
        delta_applied = delta_cmd_raw
        ax_applied = ax_cmd
    else:
        delta_applied = delta_alpha * u_lin_noadapt[k - 1, 0] + (1.0 - delta_alpha) * delta_cmd_raw
        ax_applied = ax_alpha * u_lin_noadapt[k - 1, 1] + (1.0 - ax_alpha) * ax_cmd

    delta_applied = np.clip(delta_applied, umin_lin_noadapt[0], umax_lin_noadapt[0])
    ax_applied = np.clip(ax_applied, umin_lin_noadapt[1], umax_lin_noadapt[1])

    if k >= traj_length - 5 and k > 0:
        u_lin_noadapt[k, :] = u_lin_noadapt[k - 1, :]
    else:
        u_lin_noadapt[k, 0] = delta_applied
        u_lin_noadapt[k, 1] = ax_applied

    # -------------------------------------------------
    # 6) 推进一步真实系统
    # -------------------------------------------------
    t1 = time.time()

    if k > 0:
        fallback_state = xt_actual_lin_noadapt[k, :].copy()
    else:
        fallback_state = np.array([0.0, 0.0, 0.0, vx_nom, 0.0, 0.0], dtype=float)

    x_next = safe_FK_step(
        xt_actual_lin_noadapt[k, :],
        u_lin_noadapt[k, :],
        sys_pars_ctrl,
        SNR_DB=SNR_DB,
        i=k,
        fallback_state=fallback_state,
        verbose=True
    )

    t2 = time.time()
    time_excess += (t2 - t1)

    if not is_finite_vector(x_next):
        nonfinite_count += 1
        print(f"[STOP] x_next still non-finite at step {k}")
        print("x_now =", xt_actual_lin_noadapt[k, :])
        print("u_now =", u_lin_noadapt[k, :])
        terminated_early = True
        break

    xt_actual_lin_noadapt[k + 1, :] = x_next

end_linear_noadapt = time.time()

effective_steps = max(1, np.sum(np.any(np.abs(u_lin_noadapt) > 0, axis=1)))
time_linear_noadapt = (end_linear_noadapt - begin_linear_noadapt - time_excess) / max(1, traj_length - 1)

print("Average MPC solve time per step =", time_linear_noadapt)
print("Total MPC failures =", fail_count)
print("Total non-finite next-state events =", nonfinite_count)
print("Terminated early =", terminated_early)

# =========================
# Plotting
# =========================
# s_actual_noadapt = xt_actual_lin_noadapt[:, 0]
# ey_actual_noadapt = xt_actual_lin_noadapt[:, 1]
# x_actual_path_noadapt, y_actual_path_noadapt = frenet_to_global(
#     s_actual_noadapt, ey_actual_noadapt, s_ref_path, x_path, y_ref_path, psi_ref_path
# )

valid_len = traj_length
for idx in range(traj_length):
    if not is_finite_vector(xt_actual_lin_noadapt[idx, :]):
        valid_len = idx
        break

s_actual_noadapt = xt_actual_lin_noadapt[:valid_len, 0]
ey_actual_noadapt = xt_actual_lin_noadapt[:valid_len, 1]

x_actual_path_noadapt, y_actual_path_noadapt = frenet_to_global(
    s_actual_noadapt, ey_actual_noadapt, s_ref_path, x_path, y_ref_path, psi_ref_path
)
plt.plot(x_path, y_ref_path, label="Reference Path", linewidth=2)
plt.plot(x_actual_path_noadapt, y_actual_path_noadapt, "--", label="No-adapt Path", linewidth=2)
plt.xlabel("x [m]")
plt.ylabel("y [m]")
plt.title("Double Lane Change Path Tracking (Optimized Koopman)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 4))
plt.plot(t_ref[:valid_len], xt_actual_lin_noadapt[:valid_len, 1], "--", label="No-adapt $e_y$")
plt.xlabel("t [s]")
plt.ylabel("e_y [m]")
plt.title("Lateral Tracking Error (Optimized Koopman)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Average MPC solve time per step = 0.06579642404534534
# Total MPC failures = 0
# Total non-finite next-state events = 0
# Terminated early = False

# %%
plt.figure(figsize=(12, 6))
for i in range(num_inputs):
    plt.subplot(num_inputs, 1, i + 1)
    plt.plot(t_ref[:-1], u_lin_noadapt[:, i], '--', label='no-adapt')
    # plt.plot(t_ref[:-1], u_lin_adapt[:, i], '-.', label='adapt')
    plt.ylabel(input_labels[i])
    plt.xlabel("t")
    plt.legend()

plt.suptitle("Control Inputs", fontsize=20)
plt.tight_layout()
plt.show()
