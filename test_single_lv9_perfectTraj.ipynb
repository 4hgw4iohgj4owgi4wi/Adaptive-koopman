# %%
# import libraries
import math
import os
import pickle
import random
import time
import itertools
import importlib

# import numpy
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
from sklearn import preprocessing

import torch
import scipy
import scipy.io

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", DEVICE)
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# import Koopman Libraries
from core.koopman_core_linear import KoopDNN_linear, KoopmanNet_linear, KoopmanNetCtrl_linear
from core.util import fit_standardizer
from models.koop_model import model_matricies, lift_raw, lift_scaled

# ===== import Frenet-real-state dynamics file =====
import dynamics.cacalv3 as cacalv3

importlib.reload(cacalv3)
from dynamics.cacalv3 import FK_solver, single_vehicle_data_gen_multi

# control
from control_files.nmpc_osqp_adapt import NonlinearMPCController
from dynamics.learned_models_control.linear_dynamics import linear_Dynamics
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 5080

# %%
# ===== helper for Frenet path =====
def build_test_frenet_path_from_xy(x_ref_path, y_ref_path):
    dx_seg = np.diff(x_ref_path)
    dy_seg = np.diff(y_ref_path)
    ds_seg = np.sqrt(dx_seg ** 2 + dy_seg ** 2)
    s_ref = np.concatenate(([0.0], np.cumsum(ds_seg)))

    dx = np.gradient(x_ref_path)
    dy = np.gradient(y_ref_path)
    psi_ref = np.unwrap(np.arctan2(dy, dx))

    ds = np.gradient(s_ref)
    curvature_ref = np.gradient(psi_ref) / np.maximum(ds, 1e-8)
    curvature_ref = np.nan_to_num(curvature_ref)

    return s_ref, psi_ref, curvature_ref


# ===== Frenet -> Cartesian for plotting =====
def frenet_to_global(s_arr, ey_arr, s_ref_path, x_ref_path, y_ref_path, psi_ref_path):
    x_center = np.interp(s_arr, s_ref_path, x_ref_path)
    y_center = np.interp(s_arr, s_ref_path, y_ref_path)
    psi_center = np.interp(s_arr, s_ref_path, psi_ref_path)

    x_global = x_center - ey_arr * np.sin(psi_center)
    y_global = y_center + ey_arr * np.cos(psi_center)
    return x_global, y_global


def to_numpy(x):
    if hasattr(x, "detach"):
        return x.detach().cpu().numpy()
    return np.array(x)


def scale_state(x_raw, standardizer_x):
    return standardizer_x.transform(np.asarray(x_raw).reshape(1, -1)).flatten()


def scale_state_batch(X_raw, standardizer_x):
    return standardizer_x.transform(np.asarray(X_raw))


def decode_scaled_to_raw(x_scaled, standardizer_x):
    return standardizer_x.inverse_transform(np.asarray(x_scaled).reshape(1, -1)).flatten()


def clip_closed_loop_state(x, s_upper=500.0):
    x = np.asarray(x, dtype=float).copy()
    x[0] = np.clip(x[0], 0.0, s_upper)  # s
    x[1] = np.clip(x[1], -5.0, 5.0)  # e_y
    x[2] = np.clip(x[2], -1.2, 1.2)  # e_psi
    x[3] = np.clip(x[3], 0.5, 8.0)  # v_x
    x[4] = np.clip(x[4], -4.0, 4.0)  # v_y
    x[5] = np.clip(x[5], -3.0, 3.0)  # r
    return x


def is_finite_vector(x):
    x = np.asarray(x, dtype=float)
    return np.all(np.isfinite(x))


def safe_FK_step(x, u, pars, SNR_DB, i, fallback_state=None, verbose=False):
    """
    对 FK_solver 做保护：
    - 若求解结果非有限，则回退到 fallback_state 或当前状态
    - 输出统一做 clip
    """
    try:
        x_next = FK_solver(
            x, u, pars,
            sensor_noise=False,
            SNR_DB=SNR_DB,
            i=i
        )
    except Exception as e:
        if verbose:
            print(f"FK_solver exception at step {i}: {e}")
        if fallback_state is None:
            fallback_state = np.asarray(x, dtype=float).copy()
        return clip_closed_loop_state(fallback_state)

    if not is_finite_vector(x_next):
        if verbose:
            print(f"Non-finite FK_solver output at step {i}")
            print("x =", x)
            print("u =", u)
            print("x_next =", x_next)
        if fallback_state is None:
            fallback_state = np.asarray(x, dtype=float).copy()
        return clip_closed_loop_state(fallback_state)

    return clip_closed_loop_state(x_next)

# %%
# =============================================================================
# 系统拟合
# =============================================================================
linear = True

# =============================================================================
# 数据生成 (针对 100m 双移线优化：丰富场景 + 物理不变性数据增强)
# =============================================================================
sys_pars_base = {}

# 6 states: x=[s, e_y, e_psi, v_x, v_y, r]
num_states = 6
num_inputs = 2
dt = 0.02

sys_pars_base["num_states"] = num_states
sys_pars_base["num_inputs"] = num_inputs
sys_pars_base["dt"] = dt

# nominal vehicle parameters
sys_pars_base["m"] = 1500.0
sys_pars_base["Iz"] = 2250.0
sys_pars_base["lf"] = 1.2
sys_pars_base["lr"] = 1.6
sys_pars_base["Cf"] = 80000.0
sys_pars_base["Cr"] = 80000.0
sys_pars_base["curvature_ref"] = 0.0
sys_pars_base["uncertainty"] = "NA"
sys_pars_base["amp"] = 0.0

sys_pars_base["road_modes"] = ['dlc']
sys_pars_base["road_mode_probs"] = [1.0]

sys_pars_base["u_modes"] = ['feedback_dominant', 'sinusoidal', 'mixed']
sys_pars_base["u_mode_probs"] = [0.40, 0.30, 0.30]  # 稍微调整激励比例

# sys_pars_base["road_modes"] = ['straight', 'sin', 'const', 'dlc']
# sys_pars_base["road_mode_probs"] = [0.15, 0.15, 0.10, 0.60]
#
# sys_pars_base["u_modes"] = ['feedback_dominant', 'sinusoidal', 'mixed']
# sys_pars_base["u_mode_probs"] = [0.50, 0.30, 0.20]

sys_pars_base["alpha_u"] = 0.70
sys_pars_base["s_margin"] = 15.0
sys_pars_base["seed"] = 42

# changed vehicle parameters
sys_pars_new_base = dict(sys_pars_base)
sys_pars_new_base["m"] = 1650.0
sys_pars_new_base["Iz"] = 2400.0
sys_pars_new_base["Cf"] = 70000.0
sys_pars_new_base["Cr"] = 70000.0

# sys_pars_new_base = dict(sys_pars_base)

sensor_noise = False
SNR_DB = 30
num_snaps = 500

# # 1. 构建混合数据集配置，激发出不同强度的纵横向耦合动态
# configs = [
#     {"vx_ref": 3.0, "delta_max": 0.05, "ax_max": 0.6, "freq": 1.0},
#     {"vx_ref": 3.0, "delta_max": 0.15, "ax_max": 1.0, "freq": 0.5},  # 低频大转角，逼近 DLC
#     {"vx_ref": 3.0, "delta_max": 0.10, "ax_max": 0.8, "freq": 0.2},  # 更低频，拉大 e_y 侧移
#     {"vx_ref": 4.0, "delta_max": 0.10, "ax_max": 0.8, "freq": 0.5},  # 高速覆盖
#     {"vx_ref": 2.0, "delta_max": 0.10, "ax_max": 0.8, "freq": 0.5},  # 低速覆盖
# ]

#  修改点 2：优化激进场景配置，扩大转角和速度包络
configs = [
    {"vx_ref": 3.0, "delta_max": 0.10, "ax_max": 0.6, "freq": 1.0},
    {"vx_ref": 3.0, "delta_max": 0.20, "ax_max": 1.0, "freq": 0.5},  # 低频大转角，逼近紧急 DLC
    {"vx_ref": 4.0, "delta_max": 0.15, "ax_max": 0.8, "freq": 0.2},  # 中高速覆盖，拉大 e_y 侧移
    {"vx_ref": 5.0, "delta_max": 0.10, "ax_max": 0.8, "freq": 0.5},  # 高速覆盖
    {"vx_ref": 2.0, "delta_max": 0.25, "ax_max": 0.8, "freq": 0.5},  # 低速极大转角
]

num_traj_per_batch = 80
X_list, X_changed_list, U_list = [], [], []

print("正在生成覆盖双移线边界条件的多场景数据...")
for cfg in configs:
    sp = dict(sys_pars_base)
    sp.update(cfg)
    # sp["U_type"] = "sinusoidal"

    sp_new = dict(sys_pars_new_base)
    sp_new.update(cfg)
    # sp_new["U_type"] = "sinusoidal"

    X_b, X_changed_b, U_b = single_vehicle_data_gen_multi(
        num_traj_per_batch, num_snaps, sp, sp_new, sensor_noise, SNR_DB
    )
    X_list.append(X_b)
    X_changed_list.append(X_changed_b)
    U_list.append(U_b)

X = np.concatenate(X_list, axis=0)
X_changed = np.concatenate(X_changed_list, axis=0)
U = np.concatenate(U_list, axis=0)
num_traj = X.shape[0]  # Total 400

# 2. 【核心】数据增强 (Data Augmentation)
# 因为在直道上 (curvature_ref=0) 车辆的动态方程不受绝对纵向距离 s 和横向偏移 e_y 的影响
# 所以我们可以直接随机平移 s 和 e_y，扩大 Standardizer 的分布覆盖面，彻底解决饱和越界问题！
np.random.seed(42)
for i in range(num_traj):
    s_shift = np.random.uniform(0.0, 110.0)  # 覆盖 DLC 的 100m 长度
    ey_shift = np.random.uniform(-2.0, 2.0)  # 覆盖 DLC 的侧向偏差并留出充足泛化裕度

    X[i, :, 0] += s_shift
    X_changed[i, :, 0] += s_shift
    X[i, :, 1] += ey_shift
    X_changed[i, :, 1] += ey_shift

# 打乱数据以防止验证集切分时分布不均
indices = np.random.permutation(num_traj)
X = X[indices]
X_changed = X_changed[indices]
U = U[indices]

num_train = int(0.8 * num_traj)
num_val = num_traj - num_train

# 恢复默认的 sys_pars 用于后续代码流转基准
# sys_pars = dict(sys_pars_base)
# sys_pars.update({"vx_ref": 3.0, "delta_max": 0.05, "ax_max": 0.6, "freq": 1.0, "U_type": "sinusoidal"})
# sys_pars_new = dict(sys_pars_new_base)
# sys_pars_new.update({"vx_ref": 3.0, "delta_max": 0.05, "ax_max": 0.6, "freq": 1.0, "U_type": "sinusoidal"})

sys_pars = dict(sys_pars_base)
sys_pars.update({"vx_ref": 3.0, "delta_max": 0.05, "ax_max": 0.6, "freq": 1.0})

sys_pars_new = dict(sys_pars_new_base)
sys_pars_new.update({"vx_ref": 3.0, "delta_max": 0.05, "ax_max": 0.6, "freq": 1.0})

print("X shape:", X.shape)
print("X_changed shape:", X_changed.shape)
print("U shape:", U.shape)

os.makedirs("saved_data/single_vehicle", exist_ok=True)

np.savez_compressed(
    "saved_data/single_vehicle/offline_dataset.npz",
    X=X,
    X_changed=X_changed,
    U=U
)

with open("saved_data/single_vehicle/offline_dataset_pars.pkl", "wb") as f:
    pickle.dump({
        "sys_pars": sys_pars,
        "sys_pars_new": sys_pars_new,
        "num_traj": num_traj,
        "num_train": num_train,
        "num_val": num_val,
        "num_snaps": num_snaps,
        "sensor_noise": sensor_noise,
        "SNR_DB": SNR_DB
    }, f)

print("离线数据已保存。")

state_labels = ["s", "e_y", "e_psi", "v_x", "v_y", "r"]
input_labels = ["delta", "a_x"]
t_train = np.linspace(0, dt * (num_snaps - 1), num_snaps)

plt.figure(figsize=(18, 12))
for j in range(num_traj):
    for i in range(num_states):
        plt.subplot(num_states, 1, i + 1)
        plt.plot(t_train, X[j, :, i], alpha=0.7)
        plt.ylabel(state_labels[i])
        plt.xlabel("t")
plt.suptitle("Original Vehicle Dynamics", fontsize=20)
plt.tight_layout()
plt.show()

plt.figure(figsize=(18, 12))
for j in range(num_traj):
    for i in range(num_states):
        plt.subplot(num_states, 1, i + 1)
        plt.plot(t_train, X_changed[j, :, i], alpha=0.7)
        plt.ylabel(state_labels[i])
        plt.xlabel("t")
plt.suptitle("Changed Vehicle Dynamics", fontsize=20)
plt.tight_layout()
plt.show()

plt.figure(figsize=(18, 6))
for j in range(num_traj):
    for i in range(num_inputs):
        plt.subplot(num_inputs, 1, i + 1)
        plt.plot(t_train[:-1], U[j, :, i], alpha=0.7)
        plt.ylabel(input_labels[i])
        plt.xlabel("t")
plt.suptitle("Control Inputs", fontsize=20)
plt.tight_layout()
plt.show()
# Out:
# 正在生成覆盖双移线边界条件的多场景数据...
# X shape: (400, 500, 6)
# X_changed shape: (400, 500, 6)
# U shape: (400, 499, 2)
# 离线数据已保存。

# %%
# =============================================================================
# Learning Koopman
# =============================================================================
xs_train, us_train = X[:num_train, :, :], U[:num_train, :, :]
xs_val, us_val = X[num_train:, :, :], U[num_train:, :, :]

net_params_lin = {}
net_params_lin["state_dim"] = num_states
net_params_lin["ctrl_dim"] = num_inputs
net_params_lin["encoder_hidden_width"] = 128
# 模型容量适度提升：场景增多变复杂了，给隐变量输出更多维度
net_params_lin["encoder_hidden_depth"] = 4
net_params_lin["encoder_output_dim"] = 16
net_params_lin["optimizer"] = "adam"
net_params_lin["activation_type"] = "tanh"
net_params_lin["lr"] = 1e-4
net_params_lin["epochs"] = 500
net_params_lin["batch_size"] = 256

net_params_lin["eig_loss"] = True
net_params_lin["eig_loss_coeff"] = 0.5
net_params_lin["lifted_loss_penalty"] = 0.3

net_params_lin["l2_reg"] = 5e-5
net_params_lin["l1_reg"] = 1e-7
net_params_lin["first_obs_const"] = True
net_params_lin["override_C"] = True
net_params_lin["dt"] = dt

train = True
standardize = True

os.makedirs("saved_models/single_vehicle/linear", exist_ok=True)

file_koop_linear = (
        "saved_models/single_vehicle/linear/"
        + "Koop_vehicle_Dim"
        + str(net_params_lin["encoder_output_dim"])
        + "_dt_"
        + str(dt)
        + ".pth"
)

print("Model save path:", file_koop_linear)

standardizer_u_kdnn = fit_standardizer(
    us_train, preprocessing.StandardScaler(with_mean=True)
)
standardizer_x_kdnn = fit_standardizer(
    xs_train, preprocessing.StandardScaler(with_mean=True)
)

if train:
    if standardize:
        net = KoopmanNetCtrl_linear(
            net_params_lin,
            standardizer_x=standardizer_x_kdnn,
            standardizer_u=standardizer_u_kdnn,
            device=DEVICE
        )
    else:
        net = KoopmanNetCtrl_linear(
            net_params_lin,
            device=DEVICE
        )

    model_koop_dnn_lin = KoopDNN_linear(net)
    model_koop_dnn_lin.set_datasets(
        xs_train,
        u_train=us_train,
        x_val=xs_val,
        u_val=us_val
    )
    model_koop_dnn_lin.model_pipeline(net_params_lin)
    model_koop_dnn_lin.construct_koopman_model()

    torch.save(model_koop_dnn_lin, file_koop_linear)
else:
    model_koop_dnn_lin = torch.load(file_koop_linear, map_location=DEVICE)
    model_koop_dnn_lin.net.to(DEVICE)
    model_koop_dnn_lin.net.device = DEVICE

train_loss = [l[0] for l in model_koop_dnn_lin.train_loss_hist]
train_pred_loss = [l[1] for l in model_koop_dnn_lin.train_loss_hist]
train_lifted_loss = [l[2] for l in model_koop_dnn_lin.train_loss_hist]
val_loss = [l[0] for l in model_koop_dnn_lin.val_loss_hist]
val_pred_loss = [l[1] for l in model_koop_dnn_lin.val_loss_hist]
val_lifted_loss = [l[2] for l in model_koop_dnn_lin.val_loss_hist]
epochs = np.arange(0, net_params_lin["epochs"])

plt.figure(figsize=(15, 8))
plt.plot(epochs, train_loss, color="tab:orange", label="Training loss")
plt.plot(epochs, train_pred_loss, "--", color="tab:orange", label="Training prediction loss")
plt.plot(epochs, train_lifted_loss, ":", color="tab:orange", label="Training lifted loss")
plt.plot(epochs, val_loss, color="tab:blue", label="Validation loss")
plt.plot(epochs, val_pred_loss, "--", color="tab:blue", label="Validation prediction loss")
plt.plot(epochs, val_lifted_loss, ":", color="tab:blue", label="Validation lifted loss")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.yscale("log")
plt.show()
# Out:
# Model save path: saved_models/single_vehicle/linear/Koop_vehicle_Dim16_dt_0.02.pth
# Epoch   1: train loss: 1.1286514263, validation loss: 1.2958182160
# Epoch   2: train loss: 1.0278447738, validation loss: 1.2532467317
# Epoch   3: train loss: 0.9959748493, validation loss: 1.2279163507
# Epoch   4: train loss: 0.9715227714, validation loss: 1.2050593931
# Epoch   5: train loss: 0.9502245313, validation loss: 1.1853168379
# Epoch   6: train loss: 0.9328476469, validation loss: 1.1693004292
# Epoch   7: train loss: 0.9145080813, validation loss: 1.1501057085
# Epoch   8: train loss: 0.8993823797, validation loss: 1.1346788756
# Epoch   9: train loss: 0.8863044690, validation loss: 1.1228553525
# Epoch  10: train loss: 0.8766836424, validation loss: 1.1119577864
# Epoch  11: train loss: 0.8673034448, validation loss: 1.1055397619
# Epoch  12: train loss: 0.8599017763, validation loss: 1.0966687675
# Epoch  13: train loss: 0.8535358334, validation loss: 1.0911880410
# Epoch  14: train loss: 0.8502352052, validation loss: 1.0815813003
# Epoch  15: train loss: 0.8434190595, validation loss: 1.0779211020
# Epoch  16: train loss: 0.8383288462, validation loss: 1.0724968133
# Epoch  17: train loss: 0.8344051772, validation loss: 1.0674043590
# Epoch  18: train loss: 0.8301610423, validation loss: 1.0622479135
# Epoch  19: train loss: 0.8267940715, validation loss: 1.0573878100
# Epoch  20: train loss: 0.8231540622, validation loss: 1.0559651777
# Epoch  21: train loss: 0.8190286217, validation loss: 1.0504174454
# Epoch  22: train loss: 0.8155849604, validation loss: 1.0455202889
# Epoch  23: train loss: 0.8128170821, validation loss: 1.0411825922
# Epoch  24: train loss: 0.8085083740, validation loss: 1.0435871464
# Epoch  25: train loss: 0.8054078525, validation loss: 1.0389044726
# Epoch  26: train loss: 0.8023758231, validation loss: 1.0327878821
# Epoch  27: train loss: 0.7987938760, validation loss: 1.0300719827
# Epoch  28: train loss: 0.7957523066, validation loss: 1.0247709593
# Epoch  29: train loss: 0.7922588054, validation loss: 1.0250474270
# Epoch  30: train loss: 0.7892436014, validation loss: 1.0211390847
# Epoch  31: train loss: 0.7886035273, validation loss: 1.0150966330
# Epoch  32: train loss: 0.7827366891, validation loss: 1.0138022191
# Epoch  33: train loss: 0.7809517859, validation loss: 1.0108584942
# Epoch  34: train loss: 0.7771072869, validation loss: 1.0051921943
# Epoch  35: train loss: 0.7746983932, validation loss: 1.0058699658
# Epoch  36: train loss: 0.7727822069, validation loss: 1.0011224908
# Epoch  37: train loss: 0.7691527761, validation loss: 0.9971406226
# Epoch  38: train loss: 0.7665527935, validation loss: 0.9963452439
# Epoch  39: train loss: 0.7650465452, validation loss: 0.9924103491
# Epoch  40: train loss: 0.7607908806, validation loss: 0.9863177508
# Epoch  41: train loss: 0.7584049607, validation loss: 0.9845006459
# Epoch  42: train loss: 0.7555454560, validation loss: 0.9822148552
# Epoch  43: train loss: 0.7537365893, validation loss: 0.9770346007
# Epoch  44: train loss: 0.7509354114, validation loss: 0.9732450555
# Epoch  45: train loss: 0.7482494446, validation loss: 0.9714682072
# Epoch  46: train loss: 0.7451823761, validation loss: 0.9644650447
# Epoch  47: train loss: 0.7433656195, validation loss: 0.9659462207
# Epoch  48: train loss: 0.7422617936, validation loss: 0.9622728384
# Epoch  49: train loss: 0.7392694178, validation loss: 0.9615484509
# Epoch  50: train loss: 0.7352699023, validation loss: 0.9645154526
# Epoch  51: train loss: 0.7338354304, validation loss: 0.9602033397
# Epoch  52: train loss: 0.7324490663, validation loss: 0.9534557479
# Epoch  53: train loss: 0.7287767404, validation loss: 0.9489358500
# Epoch  54: train loss: 0.7271618910, validation loss: 0.9425567078
# Epoch  55: train loss: 0.7250622840, validation loss: 0.9421450540
# Epoch  56: train loss: 0.7227459954, validation loss: 0.9417711767
# Epoch  57: train loss: 0.7204687566, validation loss: 0.9377055617
# Epoch  58: train loss: 0.7181338510, validation loss: 0.9346369455
# Epoch  59: train loss: 0.7154506644, validation loss: 0.9326373836
# Epoch  60: train loss: 0.7142917926, validation loss: 0.9288464114
# Epoch  61: train loss: 0.7113214888, validation loss: 0.9261050341
# Epoch  62: train loss: 0.7102952527, validation loss: 0.9256082832
# Epoch  63: train loss: 0.7073259088, validation loss: 0.9222005656
# Epoch  64: train loss: 0.7061586031, validation loss: 0.9192524345
# Epoch  65: train loss: 0.7025601763, validation loss: 0.9186693713
# Epoch  66: train loss: 0.7012237155, validation loss: 0.9119016879
# Epoch  67: train loss: 0.6997824053, validation loss: 0.9167818547
# Epoch  68: train loss: 0.6981554330, validation loss: 0.9099000578
# Epoch  69: train loss: 0.6952010899, validation loss: 0.9052484521
# Epoch  70: train loss: 0.6928483744, validation loss: 0.9070385530
# Epoch  71: train loss: 0.6926481740, validation loss: 0.9038535426
# Epoch  72: train loss: 0.6890890978, validation loss: 0.9003649445
# Epoch  73: train loss: 0.6870037248, validation loss: 0.8983006666
# Epoch  74: train loss: 0.6862693820, validation loss: 0.8915812957
# Epoch  75: train loss: 0.6831859221, validation loss: 0.8941759753
# Epoch  76: train loss: 0.6804833374, validation loss: 0.8918414661
# Epoch  77: train loss: 0.6801998607, validation loss: 0.8870193078
# Epoch  78: train loss: 0.6777675917, validation loss: 0.8889261729
# Epoch  79: train loss: 0.6770970576, validation loss: 0.8810385676
# Epoch  80: train loss: 0.6737757136, validation loss: 0.8785145592
# Epoch  81: train loss: 0.6721289302, validation loss: 0.8785498868
# Epoch  82: train loss: 0.6710581111, validation loss: 0.8752415566
# Epoch  83: train loss: 0.6677105943, validation loss: 0.8754052316
# Epoch  84: train loss: 0.6673569334, validation loss: 0.8715837737
# Epoch  85: train loss: 0.6650587905, validation loss: 0.8667696301
# Epoch  86: train loss: 0.6631671903, validation loss: 0.8664636827
# Epoch  87: train loss: 0.6603475523, validation loss: 0.8664185226
# Epoch  88: train loss: 0.6596150981, validation loss: 0.8623112738
# Epoch  89: train loss: 0.6579701910, validation loss: 0.8609552385
# Epoch  90: train loss: 0.6563436552, validation loss: 0.8585692227
# Epoch  91: train loss: 0.6539468551, validation loss: 0.8563453720
# Epoch  92: train loss: 0.6522002996, validation loss: 0.8547891881
# Epoch  93: train loss: 0.6509909796, validation loss: 0.8516509492
# Epoch  94: train loss: 0.6496469630, validation loss: 0.8495481116
# Epoch  95: train loss: 0.6471144203, validation loss: 0.8465299276
# Epoch  96: train loss: 0.6449637154, validation loss: 0.8521537360
# Epoch  97: train loss: 0.6439004082, validation loss: 0.8450210838
# Epoch  98: train loss: 0.6426613258, validation loss: 0.8412802938
# Epoch  99: train loss: 0.6408635826, validation loss: 0.8415693289
# Epoch 100: train loss: 0.6388229218, validation loss: 0.8369239500
# Epoch 101: train loss: 0.6372061822, validation loss: 0.8355333217
# Epoch 102: train loss: 0.6357102802, validation loss: 0.8364936539
# Epoch 103: train loss: 0.6342429177, validation loss: 0.8329131787
# Epoch 104: train loss: 0.6320017380, validation loss: 0.8297371198
# Epoch 105: train loss: 0.6321128739, validation loss: 0.8255955086
# Epoch 106: train loss: 0.6293486698, validation loss: 0.8259112831
# Epoch 107: train loss: 0.6274628765, validation loss: 0.8285595191
# Epoch 108: train loss: 0.6257509901, validation loss: 0.8267995759
# Epoch 109: train loss: 0.6244553195, validation loss: 0.8197539290
# Epoch 110: train loss: 0.6239369541, validation loss: 0.8190065972
# Epoch 111: train loss: 0.6218596334, validation loss: 0.8184438144
# Epoch 112: train loss: 0.6211268613, validation loss: 0.8165429199
# Epoch 113: train loss: 0.6203229369, validation loss: 0.8124005992
# Epoch 114: train loss: 0.6178072696, validation loss: 0.8123688229
# Epoch 115: train loss: 0.6155614798, validation loss: 0.8110211914
# Epoch 116: train loss: 0.6153598238, validation loss: 0.8109154481
# Epoch 117: train loss: 0.6131390698, validation loss: 0.8083485040
# Epoch 118: train loss: 0.6124827220, validation loss: 0.8053233128
# Epoch 119: train loss: 0.6103475056, validation loss: 0.8027429286
# Epoch 120: train loss: 0.6088828155, validation loss: 0.8031357438
# Epoch 121: train loss: 0.6073302723, validation loss: 0.7989328063
# Epoch 122: train loss: 0.6056844023, validation loss: 0.7971753002
# Epoch 123: train loss: 0.6048956792, validation loss: 0.7960327293
# Epoch 124: train loss: 0.6026393579, validation loss: 0.7957826683
# Epoch 125: train loss: 0.6039592837, validation loss: 0.7955945389
# Epoch 126: train loss: 0.5993386051, validation loss: 0.7965696706
# Epoch 127: train loss: 0.6000658978, validation loss: 0.7896339078
# Epoch 128: train loss: 0.5989804963, validation loss: 0.7896452609
# Epoch 129: train loss: 0.5975361882, validation loss: 0.7902351517
# Epoch 130: train loss: 0.5956741137, validation loss: 0.7864344833
# Epoch 131: train loss: 0.5941898722, validation loss: 0.7820031657
# Epoch 132: train loss: 0.5919612903, validation loss: 0.7862692465
# Epoch 133: train loss: 0.5922200487, validation loss: 0.7797329821
# Epoch 134: train loss: 0.5905785380, validation loss: 0.7796695020
# Epoch 135: train loss: 0.5888565841, validation loss: 0.7768971140
# Epoch 136: train loss: 0.5874190521, validation loss: 0.7807218373
# Epoch 137: train loss: 0.5863444694, validation loss: 0.7728988589
# Epoch 138: train loss: 0.5851451062, validation loss: 0.7729013790
# Epoch 139: train loss: 0.5839193874, validation loss: 0.7758513422
# Epoch 140: train loss: 0.5828923436, validation loss: 0.7725930853
# Epoch 141: train loss: 0.5824644273, validation loss: 0.7705248121
# Epoch 142: train loss: 0.5802645255, validation loss: 0.7672636906
# Epoch 143: train loss: 0.5793015630, validation loss: 0.7664069245
# Epoch 144: train loss: 0.5785192542, validation loss: 0.7648674355
# Epoch 145: train loss: 0.5769319728, validation loss: 0.7619000215
# Epoch 146: train loss: 0.5773791643, validation loss: 0.7634366280
# Epoch 147: train loss: 0.5747712173, validation loss: 0.7613863811
# Epoch 148: train loss: 0.5738824175, validation loss: 0.7588908635
# Epoch 149: train loss: 0.5732148728, validation loss: 0.7555091834
# Epoch 150: train loss: 0.5721582228, validation loss: 0.7566512861
# Epoch 151: train loss: 0.5707523085, validation loss: 0.7535240784
# Epoch 152: train loss: 0.5697274623, validation loss: 0.7524421375
# Epoch 153: train loss: 0.5675867979, validation loss: 0.7543515973
# Epoch 154: train loss: 0.5667256009, validation loss: 0.7655431003
# Epoch 155: train loss: 0.5670900777, validation loss: 0.7477699975
# Epoch 156: train loss: 0.5644352641, validation loss: 0.7486934436
# Epoch 157: train loss: 0.5632244452, validation loss: 0.7445030077
# Epoch 158: train loss: 0.5626204835, validation loss: 0.7458934874
# Epoch 159: train loss: 0.5608611129, validation loss: 0.7434258985
# Epoch 160: train loss: 0.5603631362, validation loss: 0.7421563072
# Epoch 161: train loss: 0.5591903872, validation loss: 0.7419194724
# Epoch 162: train loss: 0.5575746156, validation loss: 0.7408450262
# Epoch 163: train loss: 0.5582395556, validation loss: 0.7390771834
# Epoch 164: train loss: 0.5570352117, validation loss: 0.7366606851
# Epoch 165: train loss: 0.5551268324, validation loss: 0.7356849582
# Epoch 166: train loss: 0.5543987113, validation loss: 0.7340934480
# Epoch 167: train loss: 0.5531244776, validation loss: 0.7329438917
# Epoch 168: train loss: 0.5521310075, validation loss: 0.7344908670
# Epoch 169: train loss: 0.5507682878, validation loss: 0.7352604290
# Epoch 170: train loss: 0.5505787975, validation loss: 0.7289776300
# Epoch 171: train loss: 0.5493956812, validation loss: 0.7294783963
# Epoch 172: train loss: 0.5481264585, validation loss: 0.7274817226
# Epoch 173: train loss: 0.5469706732, validation loss: 0.7258547053
# Epoch 174: train loss: 0.5466056278, validation loss: 0.7259891524
# Epoch 175: train loss: 0.5451524844, validation loss: 0.7244986382
# Epoch 176: train loss: 0.5437655517, validation loss: 0.7256606370
# Epoch 177: train loss: 0.5440564219, validation loss: 0.7218478107
# Epoch 178: train loss: 0.5421541330, validation loss: 0.7193604223
# Epoch 179: train loss: 0.5420296516, validation loss: 0.7203045611
# Epoch 180: train loss: 0.5398241020, validation loss: 0.7167199791
# Epoch 181: train loss: 0.5390860755, validation loss: 0.7148738207
# Epoch 182: train loss: 0.5396229955, validation loss: 0.7157285070
# Epoch 183: train loss: 0.5374568978, validation loss: 0.7151188202
# Epoch 184: train loss: 0.5366396630, validation loss: 0.7127794879
# Epoch 185: train loss: 0.5353246070, validation loss: 0.7132085459
# Epoch 186: train loss: 0.5343066351, validation loss: 0.7144432395
# Epoch 187: train loss: 0.5343420341, validation loss: 0.7119151814
# Epoch 188: train loss: 0.5324507142, validation loss: 0.7086486407
# Epoch 189: train loss: 0.5316333559, validation loss: 0.7124463606
# Epoch 190: train loss: 0.5314759768, validation loss: 0.7162553784
# Epoch 191: train loss: 0.5309060326, validation loss: 0.7089003129
# Epoch 192: train loss: 0.5282528997, validation loss: 0.7041980836
# Epoch 193: train loss: 0.5281732173, validation loss: 0.7050115818
# Epoch 194: train loss: 0.5276713733, validation loss: 0.7075779182
# Epoch 195: train loss: 0.5264964536, validation loss: 0.7054006244
# Epoch 196: train loss: 0.5269532126, validation loss: 0.7002188788
# Epoch 197: train loss: 0.5240770183, validation loss: 0.7038629941
# Epoch 198: train loss: 0.5232340634, validation loss: 0.7020048562
# Epoch 199: train loss: 0.5225184704, validation loss: 0.6965530506
# Epoch 200: train loss: 0.5222227299, validation loss: 0.6965745063
# Epoch 201: train loss: 0.5206378528, validation loss: 0.6967439802
# Epoch 202: train loss: 0.5194518974, validation loss: 0.6948485254
# Epoch 203: train loss: 0.5198464237, validation loss: 0.6930573409
# Epoch 204: train loss: 0.5187866299, validation loss: 0.6983548455
# Epoch 205: train loss: 0.5170923259, validation loss: 0.6912134742
# Epoch 206: train loss: 0.5161227653, validation loss: 0.6906374617
# Epoch 207: train loss: 0.5155030145, validation loss: 0.6901652080
# Epoch 208: train loss: 0.5149034646, validation loss: 0.6863900441
# Epoch 209: train loss: 0.5133219623, validation loss: 0.6879736222
# Epoch 210: train loss: 0.5130463445, validation loss: 0.6871898375
# Epoch 211: train loss: 0.5123515183, validation loss: 0.6855568222
# Epoch 212: train loss: 0.5110618830, validation loss: 0.6876663963
# Epoch 213: train loss: 0.5096632998, validation loss: 0.6811907921
# Epoch 214: train loss: 0.5090875892, validation loss: 0.6800719941
# Epoch 215: train loss: 0.5090250938, validation loss: 0.6783101615
# Epoch 216: train loss: 0.5073134865, validation loss: 0.6816276747
# Epoch 217: train loss: 0.5066284441, validation loss: 0.6821201668
# Epoch 218: train loss: 0.5049832404, validation loss: 0.6751067789
# Epoch 219: train loss: 0.5068639693, validation loss: 0.6795423409
# Epoch 220: train loss: 0.5040190235, validation loss: 0.6785909076
# Epoch 221: train loss: 0.5037014288, validation loss: 0.6730099523
# Epoch 222: train loss: 0.5024433933, validation loss: 0.6733651707
# Epoch 223: train loss: 0.5012355812, validation loss: 0.6740559378
# Epoch 224: train loss: 0.5007887128, validation loss: 0.6718585603
# Epoch 225: train loss: 0.5004881748, validation loss: 0.6701812844
# Epoch 226: train loss: 0.4990580075, validation loss: 0.6711919709
# Epoch 227: train loss: 0.4977609283, validation loss: 0.6682293160
# Epoch 228: train loss: 0.4981660564, validation loss: 0.6723162325
# Epoch 229: train loss: 0.4962445012, validation loss: 0.6690279161
# Epoch 230: train loss: 0.4961018176, validation loss: 0.6656281734
# Epoch 231: train loss: 0.4952313550, validation loss: 0.6638682763
# Epoch 232: train loss: 0.4942689184, validation loss: 0.6605658100
# Epoch 233: train loss: 0.4935534313, validation loss: 0.6629902230
# Epoch 234: train loss: 0.4906814764, validation loss: 0.6633420073
# Epoch 235: train loss: 0.4915225427, validation loss: 0.6621411470
# Epoch 236: train loss: 0.4920155345, validation loss: 0.6628080738
# Epoch 237: train loss: 0.4902717176, validation loss: 0.6601198672
# Epoch 238: train loss: 0.4885841793, validation loss: 0.6563482984
# Epoch 239: train loss: 0.4881763150, validation loss: 0.6579683639
# Epoch 240: train loss: 0.4876077955, validation loss: 0.6554473864
# Epoch 241: train loss: 0.4860125196, validation loss: 0.6593329676
# Epoch 242: train loss: 0.4872407248, validation loss: 0.6553467583
# Epoch 243: train loss: 0.4844907740, validation loss: 0.6518227327
# Epoch 244: train loss: 0.4839674968, validation loss: 0.6519620824
# Epoch 245: train loss: 0.4834428176, validation loss: 0.6514486634
# Epoch 246: train loss: 0.4830596776, validation loss: 0.6474452903
# Epoch 247: train loss: 0.4816490313, validation loss: 0.6464143727
# Epoch 248: train loss: 0.4821087507, validation loss: 0.6461043874
# Epoch 249: train loss: 0.4803643789, validation loss: 0.6472477106
# Epoch 250: train loss: 0.4795880830, validation loss: 0.6448250854
# Epoch 251: train loss: 0.4790711565, validation loss: 0.6485645742
# Epoch 252: train loss: 0.4772571160, validation loss: 0.6444460791
# Epoch 253: train loss: 0.4771636543, validation loss: 0.6419700666
# Epoch 254: train loss: 0.4754031753, validation loss: 0.6484805221
# Epoch 255: train loss: 0.4770722870, validation loss: 0.6415053290
# Epoch 256: train loss: 0.4750317851, validation loss: 0.6439695242
# Epoch 257: train loss: 0.4739143258, validation loss: 0.6430345178
# Epoch 258: train loss: 0.4739971844, validation loss: 0.6453798863
# Epoch 259: train loss: 0.4739420756, validation loss: 0.6366756313
# Epoch 260: train loss: 0.4717664431, validation loss: 0.6363159556
# Epoch 261: train loss: 0.4703840356, validation loss: 0.6340265430
# Epoch 262: train loss: 0.4709617250, validation loss: 0.6361606719
# Epoch 263: train loss: 0.4684839850, validation loss: 0.6335550152
# Epoch 264: train loss: 0.4688831568, validation loss: 0.6366405680
# Epoch 265: train loss: 0.4682482934, validation loss: 0.6313810822
# Epoch 266: train loss: 0.4672709037, validation loss: 0.6292604503
# Epoch 267: train loss: 0.4658148319, validation loss: 0.6278185986
# Epoch 268: train loss: 0.4655716160, validation loss: 0.6299540678
# Epoch 269: train loss: 0.4641759006, validation loss: 0.6292237640
# Epoch 270: train loss: 0.4631416159, validation loss: 0.6264540196
# Epoch 271: train loss: 0.4642711740, validation loss: 0.6273345898
# Epoch 272: train loss: 0.4627838798, validation loss: 0.6240844380
# Epoch 273: train loss: 0.4613961784, validation loss: 0.6237359074
# Epoch 274: train loss: 0.4620166175, validation loss: 0.6217978476
# Epoch 275: train loss: 0.4606455988, validation loss: 0.6221893038
# Epoch 276: train loss: 0.4589711644, validation loss: 0.6220800157
# Epoch 277: train loss: 0.4593118743, validation loss: 0.6177879537
# Epoch 278: train loss: 0.4575112423, validation loss: 0.6252449262
# Epoch 279: train loss: 0.4565857902, validation loss: 0.6213362239
# Epoch 280: train loss: 0.4566757873, validation loss: 0.6182703147
# Epoch 281: train loss: 0.4558070422, validation loss: 0.6183449436
# Epoch 282: train loss: 0.4540323082, validation loss: 0.6213318415
# Epoch 283: train loss: 0.4541728359, validation loss: 0.6160764843
# Epoch 284: train loss: 0.4541895311, validation loss: 0.6132333153
# Epoch 285: train loss: 0.4526970136, validation loss: 0.6130350094
# Epoch 286: train loss: 0.4521860801, validation loss: 0.6147356062
# Epoch 287: train loss: 0.4504566473, validation loss: 0.6143024775
# Epoch 288: train loss: 0.4504841748, validation loss: 0.6118529246
# Epoch 289: train loss: 0.4503193665, validation loss: 0.6084479533
# Epoch 290: train loss: 0.4486805119, validation loss: 0.6109385233
# Epoch 291: train loss: 0.4488747918, validation loss: 0.6082556744
# Epoch 292: train loss: 0.4478738045, validation loss: 0.6046563081
# Epoch 293: train loss: 0.4477035920, validation loss: 0.6038356723
# Epoch 294: train loss: 0.4467424225, validation loss: 0.6032049176
# Epoch 295: train loss: 0.4446155190, validation loss: 0.6025024018
# Epoch 296: train loss: 0.4445294922, validation loss: 0.6054749426
# Epoch 297: train loss: 0.4439023805, validation loss: 0.6013132628
# Epoch 298: train loss: 0.4422192412, validation loss: 0.6022011669
# Epoch 299: train loss: 0.4425437959, validation loss: 0.6002997333
# Epoch 300: train loss: 0.4413238786, validation loss: 0.5973573370
# Epoch 301: train loss: 0.4405759848, validation loss: 0.6034546575
# Epoch 302: train loss: 0.4413893500, validation loss: 0.5963938320
# Epoch 303: train loss: 0.4392899133, validation loss: 0.5987654023
# Epoch 304: train loss: 0.4396295940, validation loss: 0.5941200202
# Epoch 305: train loss: 0.4375870216, validation loss: 0.5922458814
# Epoch 306: train loss: 0.4377913274, validation loss: 0.5900338285
# Epoch 307: train loss: 0.4367342476, validation loss: 0.5913692123
# Epoch 308: train loss: 0.4360146195, validation loss: 0.5930007998
# Epoch 309: train loss: 0.4347538941, validation loss: 0.5972109417
# Epoch 310: train loss: 0.4345420179, validation loss: 0.5918014752
# Epoch 311: train loss: 0.4344053779, validation loss: 0.5880978743
# Epoch 312: train loss: 0.4326088809, validation loss: 0.5865325713
# Epoch 313: train loss: 0.4319422223, validation loss: 0.5910803636
# Epoch 314: train loss: 0.4315628452, validation loss: 0.5863131748
# Epoch 315: train loss: 0.4303999236, validation loss: 0.5866356174
# Epoch 316: train loss: 0.4306082361, validation loss: 0.5884195515
# Epoch 317: train loss: 0.4293450136, validation loss: 0.5817967500
# Epoch 318: train loss: 0.4287030152, validation loss: 0.5831135790
# Epoch 319: train loss: 0.4275937288, validation loss: 0.5804162551
# Epoch 320: train loss: 0.4267238221, validation loss: 0.5834923650
# Epoch 321: train loss: 0.4264944402, validation loss: 0.5827742432
# Epoch 322: train loss: 0.4267212425, validation loss: 0.5777540132
# Epoch 323: train loss: 0.4252783367, validation loss: 0.5795172225
# Epoch 324: train loss: 0.4240748549, validation loss: 0.5772824473
# Epoch 325: train loss: 0.4237711501, validation loss: 0.5782719788
# Epoch 326: train loss: 0.4227429413, validation loss: 0.5768330639
# Epoch 327: train loss: 0.4218052829, validation loss: 0.5814690403
# Epoch 328: train loss: 0.4207761695, validation loss: 0.5758672246
# Epoch 329: train loss: 0.4213086250, validation loss: 0.5736683662
# Epoch 330: train loss: 0.4196500178, validation loss: 0.5740328450
# Epoch 331: train loss: 0.4185179604, validation loss: 0.5704510472
# Epoch 332: train loss: 0.4178742089, validation loss: 0.5690453144
# Epoch 333: train loss: 0.4181114786, validation loss: 0.5712213139
# Epoch 334: train loss: 0.4170193329, validation loss: 0.5719489453
# Epoch 335: train loss: 0.4186232777, validation loss: 0.5690284530
# Epoch 336: train loss: 0.4157442580, validation loss: 0.5675479961
# Epoch 337: train loss: 0.4148090599, validation loss: 0.5651231021
# Epoch 338: train loss: 0.4143944329, validation loss: 0.5653672083
# Epoch 339: train loss: 0.4146341299, validation loss: 0.5616877711
# Epoch 340: train loss: 0.4120044108, validation loss: 0.5634820288
# Epoch 341: train loss: 0.4132620220, validation loss: 0.5603712784
# Epoch 342: train loss: 0.4110755801, validation loss: 0.5637654154
# Epoch 343: train loss: 0.4121810867, validation loss: 0.5608519369
# Epoch 344: train loss: 0.4106779505, validation loss: 0.5622844340
# Epoch 345: train loss: 0.4109241744, validation loss: 0.5625643482
# Epoch 346: train loss: 0.4102099597, validation loss: 0.5573247855
# Epoch 347: train loss: 0.4077690417, validation loss: 0.5553198284
# Epoch 348: train loss: 0.4088070942, validation loss: 0.5610243139
# Epoch 349: train loss: 0.4068092533, validation loss: 0.5533501239
# Epoch 350: train loss: 0.4056126342, validation loss: 0.5529772396
# Epoch 351: train loss: 0.4059125645, validation loss: 0.5560907463
# Epoch 352: train loss: 0.4050462372, validation loss: 0.5550933948
# Epoch 353: train loss: 0.4041541206, validation loss: 0.5490566082
# Epoch 354: train loss: 0.4033192469, validation loss: 0.5553058245
# Epoch 355: train loss: 0.4034173378, validation loss: 0.5541779259
# Epoch 356: train loss: 0.4022112156, validation loss: 0.5469771403
# Epoch 357: train loss: 0.4021682653, validation loss: 0.5489471075
# Epoch 358: train loss: 0.4002993505, validation loss: 0.5475327855
# Epoch 359: train loss: 0.4014562082, validation loss: 0.5474087477
# Epoch 360: train loss: 0.3997150588, validation loss: 0.5453844301
# Epoch 361: train loss: 0.3998658395, validation loss: 0.5505384598
# Epoch 362: train loss: 0.3982511784, validation loss: 0.5455181875
# Epoch 363: train loss: 0.3974323724, validation loss: 0.5476667173
# Epoch 364: train loss: 0.3968606651, validation loss: 0.5444863104
# Epoch 365: train loss: 0.3965665224, validation loss: 0.5438694257
# Epoch 366: train loss: 0.3956934797, validation loss: 0.5428165719
# Epoch 367: train loss: 0.3955898677, validation loss: 0.5434428852
# Epoch 368: train loss: 0.3953426384, validation loss: 0.5392863521
# Epoch 369: train loss: 0.3930912060, validation loss: 0.5414179104
# Epoch 370: train loss: 0.3935932919, validation loss: 0.5375165898
# Epoch 371: train loss: 0.3928790752, validation loss: 0.5394933707
# Epoch 372: train loss: 0.3913806267, validation loss: 0.5403409173
# Epoch 373: train loss: 0.3918361064, validation loss: 0.5340429230
# Epoch 374: train loss: 0.3907838268, validation loss: 0.5376868592
# Epoch 375: train loss: 0.3886715305, validation loss: 0.5354744799
# Epoch 376: train loss: 0.3890037616, validation loss: 0.5346427257
# Epoch 377: train loss: 0.3888284214, validation loss: 0.5386816218
# Epoch 378: train loss: 0.3878721435, validation loss: 0.5372999590
# Epoch 379: train loss: 0.3865056435, validation loss: 0.5358901503
# Epoch 380: train loss: 0.3865320821, validation loss: 0.5306689928
# Epoch 381: train loss: 0.3865467525, validation loss: 0.5293373953
# Epoch 382: train loss: 0.3846868309, validation loss: 0.5323733347
# Epoch 383: train loss: 0.3845432503, validation loss: 0.5261355351
# Epoch 384: train loss: 0.3842668470, validation loss: 0.5253138527
# Epoch 385: train loss: 0.3838088505, validation loss: 0.5227900682
# Epoch 386: train loss: 0.3817581709, validation loss: 0.5324563567
# Epoch 387: train loss: 0.3819266979, validation loss: 0.5268980070
# Epoch 388: train loss: 0.3806220402, validation loss: 0.5232130911
# Epoch 389: train loss: 0.3819365062, validation loss: 0.5194975392
# Epoch 390: train loss: 0.3795634073, validation loss: 0.5240061182
# Epoch 391: train loss: 0.3802410407, validation loss: 0.5199951763
# Epoch 392: train loss: 0.3784516047, validation loss: 0.5193369965
# Epoch 393: train loss: 0.3793930245, validation loss: 0.5177655459
# Epoch 394: train loss: 0.3778578257, validation loss: 0.5200250734
# Epoch 395: train loss: 0.3758782105, validation loss: 0.5191482926
# Epoch 396: train loss: 0.3768731432, validation loss: 0.5143403607
# Epoch 397: train loss: 0.3758986606, validation loss: 0.5132495237
# Epoch 398: train loss: 0.3741446263, validation loss: 0.5163055703
# Epoch 399: train loss: 0.3732915209, validation loss: 0.5132309163
# Epoch 400: train loss: 0.3742184136, validation loss: 0.5127848250
# Epoch 401: train loss: 0.3732675937, validation loss: 0.5111774291
# Epoch 402: train loss: 0.3718306199, validation loss: 0.5133850808
# Epoch 403: train loss: 0.3720593490, validation loss: 0.5121189096
# Epoch 404: train loss: 0.3710330931, validation loss: 0.5115946555
# Epoch 405: train loss: 0.3700248155, validation loss: 0.5115704684
# Epoch 406: train loss: 0.3698430955, validation loss: 0.5085611305
# Epoch 407: train loss: 0.3704806407, validation loss: 0.5068246226
# Epoch 408: train loss: 0.3694309570, validation loss: 0.5038657061
# Epoch 409: train loss: 0.3680268799, validation loss: 0.5068006449
# Epoch 410: train loss: 0.3667961097, validation loss: 0.5066024971
# Epoch 411: train loss: 0.3662039442, validation loss: 0.5043933851
# Epoch 412: train loss: 0.3670728150, validation loss: 0.5052650135
# Epoch 413: train loss: 0.3652871445, validation loss: 0.5082468925
# Epoch 414: train loss: 0.3641630001, validation loss: 0.5013667747
# Epoch 415: train loss: 0.3648318304, validation loss: 0.5065359293
# Epoch 416: train loss: 0.3630956431, validation loss: 0.5025488409
# Epoch 417: train loss: 0.3636650111, validation loss: 0.5100348951
# Epoch 418: train loss: 0.3629018871, validation loss: 0.5033473965
# Epoch 419: train loss: 0.3621922551, validation loss: 0.4962353487
# Epoch 420: train loss: 0.3604926381, validation loss: 0.4971310849
# Epoch 421: train loss: 0.3619387891, validation loss: 0.4985261882
# Epoch 422: train loss: 0.3598270043, validation loss: 0.4986659151
# Epoch 423: train loss: 0.3595122114, validation loss: 0.4980556478
# Epoch 424: train loss: 0.3588860067, validation loss: 0.4913051816
# Epoch 425: train loss: 0.3573382818, validation loss: 0.4934388375
# Epoch 426: train loss: 0.3576937586, validation loss: 0.4898752738
# Epoch 427: train loss: 0.3576113230, validation loss: 0.4929988617
# Epoch 428: train loss: 0.3565262416, validation loss: 0.4917677566
# Epoch 429: train loss: 0.3562515244, validation loss: 0.4916462508
# Epoch 430: train loss: 0.3551377117, validation loss: 0.4903190634
# Epoch 431: train loss: 0.3544458411, validation loss: 0.4932595231
# Epoch 432: train loss: 0.3540358152, validation loss: 0.4922913947
# Epoch 433: train loss: 0.3539523501, validation loss: 0.4866612553
# Epoch 434: train loss: 0.3525720324, validation loss: 0.4833157116
# Epoch 435: train loss: 0.3516510841, validation loss: 0.4889737170
# Epoch 436: train loss: 0.3520590529, validation loss: 0.4869626086
# Epoch 437: train loss: 0.3531779801, validation loss: 0.4830584536
# Epoch 438: train loss: 0.3506685008, validation loss: 0.4841802161
# Epoch 439: train loss: 0.3509876514, validation loss: 0.4863895961
# Epoch 440: train loss: 0.3493474959, validation loss: 0.4842279521
# Epoch 441: train loss: 0.3489497162, validation loss: 0.4840206513
# Epoch 442: train loss: 0.3485846070, validation loss: 0.4820246084
# Epoch 443: train loss: 0.3472658024, validation loss: 0.4818469801
# Epoch 444: train loss: 0.3479953494, validation loss: 0.4779695772
# Epoch 445: train loss: 0.3467010699, validation loss: 0.4749431378
# Epoch 446: train loss: 0.3471860744, validation loss: 0.4773612504
# Epoch 447: train loss: 0.3449236072, validation loss: 0.4745837067
# Epoch 448: train loss: 0.3436983657, validation loss: 0.4875447587
# Epoch 449: train loss: 0.3436491735, validation loss: 0.4764534253
# Epoch 450: train loss: 0.3441901125, validation loss: 0.4754991169
# Epoch 451: train loss: 0.3436818119, validation loss: 0.4736337426
# Epoch 452: train loss: 0.3424916941, validation loss: 0.4770735183
# Epoch 453: train loss: 0.3419296004, validation loss: 0.4767350516
# Epoch 454: train loss: 0.3400655516, validation loss: 0.4738568353
# Epoch 455: train loss: 0.3411245570, validation loss: 0.4839179865
# Epoch 456: train loss: 0.3407876472, validation loss: 0.4700392061
# Epoch 457: train loss: 0.3404230347, validation loss: 0.4685969827
# Epoch 458: train loss: 0.3383348025, validation loss: 0.4658246761
# Epoch 459: train loss: 0.3405699312, validation loss: 0.4662222342
# Epoch 460: train loss: 0.3379298176, validation loss: 0.4683585969
# Epoch 461: train loss: 0.3373111622, validation loss: 0.4730991853
# Epoch 462: train loss: 0.3376462413, validation loss: 0.4686273294
# Epoch 463: train loss: 0.3363217095, validation loss: 0.4717331144
# Epoch 464: train loss: 0.3354900272, validation loss: 0.4651153079
# Epoch 465: train loss: 0.3346715941, validation loss: 0.4681373634
# Epoch 466: train loss: 0.3357589989, validation loss: 0.4637909335
# Epoch 467: train loss: 0.3343829589, validation loss: 0.4645447957
# Epoch 468: train loss: 0.3348237737, validation loss: 0.4659754866
# Epoch 469: train loss: 0.3327205637, validation loss: 0.4595135793
# Epoch 470: train loss: 0.3319356758, validation loss: 0.4643840788
# Epoch 471: train loss: 0.3317227076, validation loss: 0.4620203545
# Epoch 472: train loss: 0.3317979689, validation loss: 0.4590734944
# Epoch 473: train loss: 0.3307163886, validation loss: 0.4636974790
# Epoch 474: train loss: 0.3304011357, validation loss: 0.4644893362
# Epoch 475: train loss: 0.3298652199, validation loss: 0.4636089601
# Epoch 476: train loss: 0.3307548140, validation loss: 0.4624794144
# Epoch 477: train loss: 0.3289974033, validation loss: 0.4552231192
# Epoch 478: train loss: 0.3293460395, validation loss: 0.4482816662
# Epoch 479: train loss: 0.3273542139, validation loss: 0.4585490104
# Epoch 480: train loss: 0.3269948760, validation loss: 0.4556271999
# Epoch 481: train loss: 0.3263848794, validation loss: 0.4538952373
# Epoch 482: train loss: 0.3236353975, validation loss: 0.4550514517
# Epoch 483: train loss: 0.3256530257, validation loss: 0.4494452872
# Epoch 484: train loss: 0.3250200950, validation loss: 0.4538227231
# Epoch 485: train loss: 0.3240732529, validation loss: 0.4486591149
# Epoch 486: train loss: 0.3242229777, validation loss: 0.4544945311
# Epoch 487: train loss: 0.3222180547, validation loss: 0.4421315451
# Epoch 488: train loss: 0.3227194305, validation loss: 0.4465268505
# Epoch 489: train loss: 0.3232049780, validation loss: 0.4478438156
# Epoch 490: train loss: 0.3213828483, validation loss: 0.4432573327
# Epoch 491: train loss: 0.3201628472, validation loss: 0.4459080702
# Epoch 492: train loss: 0.3211298103, validation loss: 0.4452554248
# Epoch 493: train loss: 0.3204504545, validation loss: 0.4453049757
# Epoch 494: train loss: 0.3195957913, validation loss: 0.4449053811
# Epoch 495: train loss: 0.3202610999, validation loss: 0.4423115035
# Epoch 496: train loss: 0.3184450625, validation loss: 0.4419597928
# Epoch 497: train loss: 0.3183073413, validation loss: 0.4436498319
# Epoch 498: train loss: 0.3175457366, validation loss: 0.4394217075
# Epoch 499: train loss: 0.3165555797, validation loss: 0.4448711962
# Epoch 500: train loss: 0.3171811676, validation loss: 0.4396262072
# Finished Training

# %%
# =============================================================================
# Koopman Model Parameters (Open Loop Test)
# =============================================================================
num_snaps_test = 100
T_test = np.linspace(0, (num_snaps_test - 1) * dt, num_snaps_test)

num_traj_test = 1
first_obs_const = int(net_params_lin["first_obs_const"])
override_C = net_params_lin["override_C"]
if override_C:
    n_obs_lin = int(net_params_lin["encoder_output_dim"]) + num_states + first_obs_const
else:
    n_obs_lin = int(net_params_lin["encoder_output_dim"]) + first_obs_const

x_unchanged_test, x_changed_test, u_test = single_vehicle_data_gen_multi(
    num_traj_test, num_snaps_test, sys_pars, sys_pars_new, sensor_noise, SNR_DB
)

A_lin = np.array(model_koop_dnn_lin.A)
B_lin = np.array(model_koop_dnn_lin.B)
C_lin = np.array(model_koop_dnn_lin.C)

eigvals, eigvecs = np.linalg.eig(A_lin)
eigvals_proj = np.array([
    ev if np.abs(ev) <= 0.999 else ev / np.abs(ev) * 0.999
    for ev in eigvals
])
A_lin_stable = eigvecs @ np.diag(eigvals_proj) @ np.linalg.inv(eigvecs)
A_lin_stable = np.real(A_lin_stable)

eigvals_stable = np.linalg.eigvals(A_lin_stable)
print("stable spectral radius =", np.max(np.abs(eigvals_stable)))

print("A, B, C shapes:", A_lin.shape, B_lin.shape, C_lin.shape)

eigvals = np.linalg.eigvals(A_lin)
spectral_radius = np.max(np.abs(eigvals))

print("spectral radius =", spectral_radius)
print("eigvals =", eigvals)

plt.figure(figsize=(6, 6))
plt.scatter(np.real(eigvals), np.imag(eigvals), label="eig(A)")
theta = np.linspace(0, 2 * np.pi, 400)
plt.plot(np.cos(theta), np.sin(theta), "--", label="unit circle")
plt.axhline(0)
plt.axvline(0)
plt.xlabel("Real")
plt.ylabel("Imag")
plt.legend()
plt.title("Eigenvalues of A_lin")
plt.axis("equal")
plt.show()

X_unchanged_scaled, _ = model_koop_dnn_lin.net.process(x_unchanged_test, data_u=u_test)
X_changed_scaled, _ = model_koop_dnn_lin.net.process(x_changed_test, data_u=u_test)

x_unchanged_scaled = X_unchanged_scaled[:, :num_states]
u_scaled = X_unchanged_scaled[:, num_states:num_states + num_inputs]
x_unchanged_prime_scaled = X_unchanged_scaled[:, num_states + num_inputs:]

x_changed_scaled = X_changed_scaled[:, :num_states]
x_changed_prime_scaled = X_changed_scaled[:, num_states + num_inputs:]

print("x_unchanged_scaled shape:", x_unchanged_scaled.shape)
print("u_scaled shape:", u_scaled.shape)
print("x_changed_scaled shape:", x_changed_scaled.shape)
print("x_changed_prime_scaled shape:", x_changed_prime_scaled.shape)

num_pred = x_unchanged_scaled.shape[0]

z_lin = np.zeros((num_pred, n_obs_lin))
x_est_lin = np.zeros((num_pred, num_states))

z_lin[0, :] = lift_scaled(x_unchanged_scaled[0, :], model_koop_dnn_lin, net_params_lin)
x_est_lin[0, :] = np.matmul(z_lin[0, :], C_lin.T)

for k in range(num_pred - 1):
    z_lin[k + 1, :] = np.matmul(z_lin[k, :], A_lin.T) + np.matmul(u_scaled[k, :], B_lin.T)
    x_est_lin[k + 1, :] = np.matmul(z_lin[k + 1, :], C_lin.T)

z_lin_stable = np.zeros((num_pred, n_obs_lin))
x_est_lin_stable = np.zeros((num_pred, num_states))

z_lin_stable[0, :] = lift_scaled(x_unchanged_scaled[0, :], model_koop_dnn_lin, net_params_lin)
x_est_lin_stable[0, :] = np.matmul(z_lin_stable[0, :], C_lin.T)

for k in range(num_pred - 1):
    z_lin_stable[k + 1, :] = np.matmul(z_lin_stable[k, :], A_lin_stable.T) + np.matmul(u_scaled[k, :], B_lin.T)
    x_est_lin_stable[k + 1, :] = np.matmul(z_lin_stable[k + 1, :], C_lin.T)

T_plot = np.arange(num_pred) * dt

plt.figure(figsize=(18, 12))
for i in range(num_states):
    plt.subplot(num_states, 1, i + 1)
    plt.xlabel("t")
    plt.ylabel(state_labels[i])
    plt.plot(T_plot, x_unchanged_scaled[:, i], label="True")
    plt.plot(T_plot, x_est_lin[:, i], "--", label="Open-loop Koopman")
    plt.plot(T_plot, x_est_lin_stable[:, i], "-.", label="Stable-projected Koopman")
    plt.legend()

plt.suptitle("Open-loop Prediction Comparison (scaled state space)", fontsize=20)
plt.tight_layout()
plt.show()

x_est_lin_raw = standardizer_x_kdnn.inverse_transform(x_est_lin)
x_est_lin_stable_raw = standardizer_x_kdnn.inverse_transform(x_est_lin_stable)
x_true_raw = x_unchanged_test[0, :-1, :]

plt.figure(figsize=(18, 12))
for i in range(num_states):
    plt.subplot(num_states, 1, i + 1)
    plt.xlabel("t")
    plt.ylabel(state_labels[i])
    plt.plot(T_plot, x_true_raw[:, i], label="True (raw)")
    plt.plot(T_plot, x_est_lin_raw[:, i], "--", label="Open-loop Koopman (raw)")
    plt.plot(T_plot, x_est_lin_stable_raw[:, i], "-.", label="Stable-projected Koopman (raw)")
    plt.legend()

plt.suptitle("Open-loop Prediction Comparison (raw state space)", fontsize=20)
plt.tight_layout()
plt.show()

x_one_step_pred = np.zeros_like(x_unchanged_prime_scaled)

for k in range(num_pred):
    z_k = lift_scaled(x_unchanged_scaled[k, :], model_koop_dnn_lin, net_params_lin)
    z_k1 = np.matmul(z_k, A_lin.T) + np.matmul(u_scaled[k, :], B_lin.T)
    x_one_step_pred[k, :] = np.matmul(z_k1, C_lin.T)

T_plot_1 = np.arange(x_one_step_pred.shape[0]) * dt

plt.figure(figsize=(18, 12))
for i in range(num_states):
    plt.subplot(num_states, 1, i + 1)
    plt.plot(T_plot_1, x_unchanged_prime_scaled[:, i], label="True next state")
    plt.plot(T_plot_1, x_one_step_pred[:, i], "--", label="One-step Koopman")
    plt.ylabel(state_labels[i])
    plt.legend()
plt.suptitle("One-step Prediction Performance (scaled state space)", fontsize=20)
plt.tight_layout()
plt.show()

x_one_step_pred_raw = standardizer_x_kdnn.inverse_transform(x_one_step_pred)
x_true_next_raw = x_unchanged_test[0, 1:, :]

T_plot_raw = np.arange(x_true_next_raw.shape[0]) * dt

plt.figure(figsize=(18, 12))
for i in range(num_states):
    plt.subplot(num_states, 1, i + 1)
    plt.plot(T_plot_raw, x_true_next_raw[:, i], label="True next state (raw)")
    plt.plot(T_plot_raw, x_one_step_pred_raw[:, i], "--", label="One-step Koopman (raw)")
    plt.ylabel(state_labels[i])
    plt.legend()
plt.suptitle("One-step Prediction Performance (raw state space)", fontsize=20)
plt.tight_layout()
plt.show()
# Out:
# stable spectral radius = 0.9990004
# A, B, C shapes: (23, 23) (23, 2) (6, 23)
# spectral radius = 1.0086701
# eigvals = [0.7610058 +0.3067766j  0.7610058 -0.3067766j  0.87764025+0.17519179j
#  0.87764025-0.17519179j 0.8336691 +0.06985187j 0.8336691 -0.06985187j
#  0.9539122 +0.j         0.9829678 +0.j         0.98827404+0.j
#  1.0086701 +0.j         1.0012845 +0.00368928j 1.0012845 -0.00368928j
#  1.0021485 +0.j         0.9982327 +0.j         0.999192  +0.00148267j
#  0.999192  -0.00148267j 0.9995132 +0.00062472j 0.9995132 -0.00062472j
#  1.00069   +0.00064137j 1.00069   -0.00064137j 1.0004292 +0.j
#  0.9999355 +0.j         1.        +0.j        ]
# x_unchanged_scaled shape: (99, 6)
# u_scaled shape: (99, 2)
# x_changed_scaled shape: (99, 6)
# x_changed_prime_scaled shape: (99, 6)

# %%
# =============================================================================
# Testing - 100m Double Lane Change Baseline
# =============================================================================

# =========================
# Reference path generation
# =========================
path_length = 100.0

vx_nom = 3.0
T_traj = path_length / vx_nom
t_ref = np.arange(0, T_traj + dt, dt)
traj_length = t_ref.size
x_path = vx_nom * t_ref

A1 = 0.4
A2 = -0.4
x1 = 30.0
x2 = 70.0
sigma1 = 16.0
sigma2 = 16.0

y_ref_path = (
        A1 * np.exp(-0.5 * ((x_path - x1) / sigma1) ** 2)
        + A2 * np.exp(-0.5 * ((x_path - x2) / sigma2) ** 2)
)

s_ref_path, psi_ref_path, curvature_ref_path = build_test_frenet_path_from_xy(
    x_path, y_ref_path
)

x_ref_raw = np.zeros((num_states, traj_length))
x_ref_raw[0, :] = s_ref_path
x_ref_raw[1, :] = 0.0
x_ref_raw[2, :] = 0.0
x_ref_raw[3, :] = vx_nom
x_ref_raw[4, :] = 0.0
x_ref_raw[5, :] = vx_nom * curvature_ref_path

x_ref_scaled = standardizer_x_kdnn.transform(x_ref_raw.T).T

plt.figure(figsize=(18, 12))
plt.subplot(3, 1, 1)
plt.plot(x_path, y_ref_path)
plt.ylabel("y_ref [m]")
plt.title("Reference Path")

plt.subplot(3, 1, 2)
plt.plot(t_ref, psi_ref_path)
plt.ylabel("psi_ref [rad]")

plt.subplot(3, 1, 3)
plt.plot(t_ref, curvature_ref_path)
plt.ylabel("kappa_ref [1/m]")
plt.xlabel("t [s]")
plt.tight_layout()
plt.show()

# %%
# =========================
# Solver settings
# =========================
solver_settings = {}
solver_settings["gen_embedded_ctrl"] = False
solver_settings["warm_start"] = True
solver_settings["polish"] = True
solver_settings["polish_refine_iter"] = 5
solver_settings["scaling"] = True
solver_settings["adaptive_rho"] = True
solver_settings["check_termination"] = 25
solver_settings["max_iter"] = 30000
solver_settings["eps_abs"] = 5e-4
solver_settings["eps_rel"] = 5e-4
solver_settings["eps_prim_inf"] = 1e-3
solver_settings["eps_dual_inf"] = 1e-3

# %%
# =========================
# MPC horizon / ref preview
# =========================
N_lin_noadapt = 80
max_iter_lin = 5

x_ref_mpc = np.hstack((
    x_ref_scaled,
    np.tile(x_ref_scaled[:, -1].reshape(-1, 1), N_lin_noadapt + 2)
))

# =========================
# 【调整】等效放大的 MPC 权重
# =========================
# 因为上面通过数据增强放大了 e_y 和 e_psi 的真实分布方差，
# 导致 Standardizer 放缩后，相同的缩放单位代表了更为巨大的物理误差。
# 为保证在缩放空间 (Scaled Space) 中仍具备同样强势的轨迹贴合度，必须大幅调高侧偏相关项的惩罚！
Q_mpc_lin_noadapt = scipy.sparse.diags([
    0.0,  # s
    1800.0,  # e_y (原为 60.0，等效放大)
    600.0,  # e_psi (原为 20.0)
    8.0,  # v_x
    1.0,  # v_y
    1.0  # r
])

QN_mpc_lin_noadapt = scipy.sparse.diags([
    0.0,  # s
    2500.0,  # e_y (原为 80.0)
    1200.0,  # e_psi (原为 30.0)
    10.0,  # v_x
    1.0,  # v_y
    1.0  # r
])

R_mpc_lin_noadapt = scipy.sparse.diags([
    120.0,  # delta (原为 30.0)
    12.0  # a_x (原为 8.0)
])

# =========================
# Relaxed raw bounds -> scaled bounds
# =========================
xmin_raw = np.array([-10.0, -5.0, -1.2, 0.5, -4.0, -3.0])
xmax_raw = np.array([500.0, 5.0, 1.2, 8.0, 4.0, 3.0])

xmin_lin_noadapt = standardizer_x_kdnn.transform(xmin_raw.reshape(1, -1)).flatten()
xmax_lin_noadapt = standardizer_x_kdnn.transform(xmax_raw.reshape(1, -1)).flatten()

umax_lin_noadapt = np.array([0.08, 1.0])
umin_lin_noadapt = -umax_lin_noadapt

# =========================
# Closed-loop arrays in raw space
# =========================
xt_actual_lin_noadapt = np.zeros((traj_length, num_states))
xt_actual_lin_noadapt[0, :] = np.array([0.0, 0.0, 0.0, vx_nom, 0.0, 0.0])

u_lin_noadapt = np.zeros((traj_length - 1, num_inputs))

z_lin_noadapt = np.zeros((traj_length, n_obs_lin))
n_lift = A_lin.shape[0]

# =========================
# Initial guesses
# =========================
x_init_lin_noadapt_raw = np.tile(xt_actual_lin_noadapt[0, :], (N_lin_noadapt + 1, 1))
u_init_lin_noadapt = np.zeros((N_lin_noadapt, num_inputs))
z_init_lin_noadapt = np.zeros((N_lin_noadapt + 1, n_lift))

for ii in range(N_lin_noadapt + 1):
    xii_scaled = scale_state(x_init_lin_noadapt_raw[ii, :], standardizer_x_kdnn)
    z_init_lin_noadapt[ii, :] = lift_scaled(
        xii_scaled, model_koop_dnn_lin, net_params_lin
    )

# =========================
# Controller
# =========================
linear_model_no_adapt = linear_Dynamics(
    scipy.sparse.csc_matrix(A_lin_stable),
    scipy.sparse.csc_matrix(B_lin),
    C_lin
)

controller_nmpc_lin_noadapt = NonlinearMPCController(
    linear_model_no_adapt,
    N_lin_noadapt, dt, umin_lin_noadapt, umax_lin_noadapt,
    xmin_lin_noadapt, xmax_lin_noadapt,
    Q_mpc_lin_noadapt, R_mpc_lin_noadapt, QN_mpc_lin_noadapt,
    solver_settings
)

controller_nmpc_lin_noadapt.construct_controller(
    z_init_lin_noadapt, u_init_lin_noadapt, x_ref_scaled[:, 0]
)

# =========================
# Closed-loop simulation
# =========================
delta_alpha = 0.6
ax_alpha = 0.50

sys_pars_ctrl = dict(sys_pars_new)
sys_pars_ctrl["vx_ref"] = vx_nom
sys_pars_ctrl["uncertainty"] = "NA"
sys_pars_ctrl["amp"] = 0.0
sys_pars_ctrl["freq"] = 1.0
sys_pars_ctrl["s_ref"] = s_ref_path
sys_pars_ctrl["curvature_ref"] = curvature_ref_path

begin_linear_noadapt = time.time()
time_excess = 0.0
fail_count = 0
nonfinite_count = 0
terminated_early = False

for k in range(traj_length - 1):
    xk_raw = xt_actual_lin_noadapt[k, :].copy()

    # -------------------------------------------------
    # 0) 进入缩放前做保护
    # -------------------------------------------------
    if not is_finite_vector(xk_raw):
        print(f"[STOP] Non-finite state before scaling at step {k}")
        print("xk_raw =", xk_raw)
        terminated_early = True
        break

    xk_raw = clip_closed_loop_state(xk_raw, s_upper=500.0)
    xt_actual_lin_noadapt[k, :] = xk_raw

    try:
        xk_scaled = scale_state(xk_raw, standardizer_x_kdnn)
    except Exception as e:
        print(f"[STOP] scale_state failed at step {k}: {e}")
        print("xk_raw =", xk_raw)
        terminated_early = True
        break

    if not is_finite_vector(xk_scaled):
        print(f"[STOP] Non-finite scaled state at step {k}")
        print("xk_raw =", xk_raw)
        print("xk_scaled =", xk_scaled)
        terminated_early = True
        break

    # -------------------------------------------------
    # 1) 提升到 Koopman 空间
    # -------------------------------------------------
    try:
        z_lin_noadapt[k, :] = lift_scaled(
            xk_scaled, model_koop_dnn_lin, net_params_lin
        )
    except Exception as e:
        print(f"[STOP] lift_scaled failed at step {k}: {e}")
        print("xk_scaled =", xk_scaled)
        terminated_early = True
        break

    if not is_finite_vector(z_lin_noadapt[k, :]):
        print(f"[STOP] Non-finite lifted state at step {k}")
        print("z =", z_lin_noadapt[k, :])
        terminated_early = True
        break

    # -------------------------------------------------
    # 2) 取参考窗口
    # -------------------------------------------------
    xref_win = x_ref_mpc[:, k + 1:k + N_lin_noadapt + 2]

    # -------------------------------------------------
    # 3) 求解 MPC
    # -------------------------------------------------
    mpc_ok = True
    try:
        controller_nmpc_lin_noadapt.solve_to_convergence(
            xref_win,
            z_lin_noadapt[k, :],
            controller_nmpc_lin_noadapt.z_init,
            controller_nmpc_lin_noadapt.u_init,
            max_iter=max_iter_lin,
            eps=1e-3
        )
        controller_nmpc_lin_noadapt.update_initial_guess_()

        delta_fb_mpc = float(controller_nmpc_lin_noadapt.cur_u[0, 0])
        ax_cmd = float(controller_nmpc_lin_noadapt.cur_u[0, 1])

        if not np.isfinite(delta_fb_mpc) or not np.isfinite(ax_cmd):
            raise ValueError("MPC returned non-finite control")
    except Exception as e:
        fail_count += 1
        mpc_ok = False
        print(f"[WARN] MPC fallback at step {k}: {e}")

        if k > 0:
            delta_fb_mpc = float(u_lin_noadapt[k - 1, 0])
            ax_cmd = float(u_lin_noadapt[k - 1, 1])
        else:
            delta_fb_mpc = 0.0
            ax_cmd = 0.0

    # -------------------------------------------------
    # 4) 前馈 + 裁剪
    # -------------------------------------------------
    ff_gain = 0.8
    delta_ff = ff_gain * (sys_pars["lf"] + sys_pars["lr"]) * curvature_ref_path[k]
    delta_cmd_raw = delta_fb_mpc + delta_ff

    delta_cmd_raw = np.clip(delta_cmd_raw, umin_lin_noadapt[0], umax_lin_noadapt[0])
    ax_cmd = np.clip(ax_cmd, umin_lin_noadapt[1], umax_lin_noadapt[1])

    # -------------------------------------------------
    # 5) 输入平滑
    # -------------------------------------------------
    if k == 0:
        delta_applied = delta_cmd_raw
        ax_applied = ax_cmd
    else:
        delta_applied = delta_alpha * u_lin_noadapt[k - 1, 0] + (1.0 - delta_alpha) * delta_cmd_raw
        ax_applied = ax_alpha * u_lin_noadapt[k - 1, 1] + (1.0 - ax_alpha) * ax_cmd

    delta_applied = np.clip(delta_applied, umin_lin_noadapt[0], umax_lin_noadapt[0])
    ax_applied = np.clip(ax_applied, umin_lin_noadapt[1], umax_lin_noadapt[1])

    # 末端冻结几步，避免终点附近乱抖
    if k >= traj_length - 5 and k > 0:
        u_lin_noadapt[k, :] = u_lin_noadapt[k - 1, :]
    else:
        u_lin_noadapt[k, 0] = delta_applied
        u_lin_noadapt[k, 1] = ax_applied

    # -------------------------------------------------
    # 6) 推进一步真实系统（安全版本）
    # -------------------------------------------------
    t1 = time.time()

    if k > 0:
        fallback_state = xt_actual_lin_noadapt[k, :].copy()
    else:
        fallback_state = np.array([0.0, 0.0, 0.0, vx_nom, 0.0, 0.0], dtype=float)

    x_next = safe_FK_step(
        xt_actual_lin_noadapt[k, :],
        u_lin_noadapt[k, :],
        sys_pars_ctrl,
        SNR_DB=SNR_DB,
        i=k,
        fallback_state=fallback_state,
        verbose=True
    )

    t2 = time.time()
    time_excess += (t2 - t1)

    if not is_finite_vector(x_next):
        nonfinite_count += 1
        print(f"[STOP] x_next still non-finite at step {k}")
        print("x_now =", xt_actual_lin_noadapt[k, :])
        print("u_now =", u_lin_noadapt[k, :])
        terminated_early = True
        break

    xt_actual_lin_noadapt[k + 1, :] = x_next

end_linear_noadapt = time.time()

effective_steps = max(1, np.sum(np.any(np.abs(u_lin_noadapt) > 0, axis=1)))
time_linear_noadapt = (end_linear_noadapt - begin_linear_noadapt - time_excess) / max(1, traj_length - 1)

print("Average MPC solve time per step =", time_linear_noadapt)
print("Total MPC failures =", fail_count)
print("Total non-finite next-state events =", nonfinite_count)
print("Terminated early =", terminated_early)

# =========================
# Plotting
# =========================
# s_actual_noadapt = xt_actual_lin_noadapt[:, 0]
# ey_actual_noadapt = xt_actual_lin_noadapt[:, 1]
# x_actual_path_noadapt, y_actual_path_noadapt = frenet_to_global(
#     s_actual_noadapt, ey_actual_noadapt, s_ref_path, x_path, y_ref_path, psi_ref_path
# )

valid_len = traj_length
for idx in range(traj_length):
    if not is_finite_vector(xt_actual_lin_noadapt[idx, :]):
        valid_len = idx
        break

s_actual_noadapt = xt_actual_lin_noadapt[:valid_len, 0]
ey_actual_noadapt = xt_actual_lin_noadapt[:valid_len, 1]

x_actual_path_noadapt, y_actual_path_noadapt = frenet_to_global(
    s_actual_noadapt, ey_actual_noadapt, s_ref_path, x_path, y_ref_path, psi_ref_path
)

plt.figure(figsize=(10, 5))
plt.plot(x_path, y_ref_path, label="Reference Path", linewidth=2)
plt.plot(x_actual_path_noadapt, y_actual_path_noadapt, "--", label="No-adapt Path", linewidth=2)
plt.xlabel("x [m]")
plt.ylabel("y [m]")
plt.title("Double Lane Change Path Tracking (Optimized Koopman)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 4))
plt.plot(t_ref[:valid_len], xt_actual_lin_noadapt[:valid_len, 1], "--", label="No-adapt $e_y$")
plt.xlabel("t [s]")
plt.ylabel("e_y [m]")
plt.title("Lateral Tracking Error (Optimized Koopman)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
plt.figure(figsize=(12, 6))
for i in range(num_inputs):
    plt.subplot(num_inputs, 1, i + 1)
    plt.plot(t_ref[:-1], u_lin_noadapt[:, i], '--', label='no-adapt')
    # plt.plot(t_ref[:-1], u_lin_adapt[:, i], '-.', label='adapt')
    plt.ylabel(input_labels[i])
    plt.xlabel("t")
    plt.legend()

plt.suptitle("Control Inputs", fontsize=20)
plt.tight_layout()
plt.show()
# Out:
# Average MPC solve time per step = 0.08561845074603854
# Total MPC failures = 0
# Total non-finite next-state events = 0
# Terminated early = False
